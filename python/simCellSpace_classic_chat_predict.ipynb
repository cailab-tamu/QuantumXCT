# %%
import numpy as np
import pandas as pd
import scanpy as sc 

np.random.seed(42)

adata = sc.read_h5ad("simCellsSpace/sim_cells_datasets_co_mo_simulated_classical.h5ad")
# Data prep
#sc.pp.normalize_total(adata, target_sum=1e4) # You can adjust target_sum # Seems not to help
#sc.pp.log1p(adata)
adata.X = adata.layers['counts']
adata
# Out:
# AnnData object with n_obs × n_vars = 4000 × 120
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pp.normalize_total(adata, target_sum=1e4) # You can adjust target_sum # Seems not to help
sc.pp.log1p(adata)
#sc.experimental.pp.normalize_pearson_residuals(adata, theta=100, clip=True, inplace=True)
# Out:
# adata.X seems to be already log-transformed.

# %%
# Manual Targeted Setup
# We want to trace the flow:
# A (50) -> B (60 -> 70 -> 71, 72, 80) -> A (80 -> 90)

# Sources: The genes initiating signals or regulation
# The "Cause" List
gl_source = [
    "Gene_50", # Source from A 
    "Gene_90"  # Target in A (Spatial Feedback)
]

# The "Effect" List
gl_recv = [
    "Gene_60", # Target in B (Spatial)
    "Gene_70", # GRN in B (Internal)
    "Gene_71", # GRN in B (Internal)
    "Gene_72", # GRN in B (Internal)
    "Gene_80", # Soruce in B
]

# %%
adata.obs['cell_type'].unique()
# Out:
# ['Type_A_Interact', 'Type_B_Lone', 'Type_A_Lone', 'Type_B_Interact']
# Categories (4, object): ['Type_A_Interact', 'Type_A_Lone', 'Type_B_Interact', 'Type_B_Lone']

# %%
# This case we have 120 genes, but want to identify the functional ones!
from scipy.sparse import issparse

ict1 = (adata.obs["cell_type"] == 'Type_A_Interact') 
ict2 = (adata.obs["cell_type"] == 'Type_B_Interact') 

adata_ct1_co = adata[ict1, gl_source].copy()
adata_ct2_co = adata[ict2, gl_recv].copy()
#adata_ct1_co = sc.external.pp.magic(adata_ct1_co, name_list=gl_source, knn=5, random_state=42)
#adata_ct2_co = sc.external.pp.magic(adata_ct2_co, name_list=gl_recv, knn=5, random_state=42)

print(adata_ct1_co)
print(adata_ct2_co)

if issparse(adata_ct1_co.X):
    Xct1_co = adata_ct1_co.X.toarray()
else:
    Xct1_co = adata_ct1_co.X

if issparse(adata_ct2_co.X):
    Xct2_co = adata_ct2_co.X.toarray()
else:
    Xct2_co = adata_ct2_co.X

# Assuming Xct1_co and Xct2 are your log-transformed expression matrices
Xct1means = np.mean(Xct1_co, axis=0) *0
Xct2means = np.mean(Xct2_co, axis=0) *0
print("CT1 (Co) mean expression:", Xct1means)
print("CT2 (Co) mean expression:", Xct2means)

# Binarize Xct1
Xct1_binary_co = (Xct1_co > Xct1means).astype(int)
# Binarize Xct2
Xct2_binary_co = (Xct2_co > Xct2means).astype(int)
# Out:
# AnnData object with n_obs × n_vars = 1000 × 2
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# AnnData object with n_obs × n_vars = 1000 × 5
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# CT1 (Co) mean expression: [0. 0.]
# CT2 (Co) mean expression: [0. 0. 0. 0. 0.]

# %%
adata.obs['cell_type'].unique()
# Out:
# ['Type_A_Interact', 'Type_B_Lone', 'Type_A_Lone', 'Type_B_Interact']
# Categories (4, object): ['Type_A_Interact', 'Type_A_Lone', 'Type_B_Interact', 'Type_B_Lone']

# %%
ict1 = (adata.obs["cell_type"] == 'Type_A_Lone')
ict2 = (adata.obs["cell_type"] == 'Type_B_Lone') 

adata_ct1_mo = adata[ict1, gl_source]
adata_ct2_mo = adata[ict2, gl_recv]
#adata_ct1_mo = sc.external.pp.magic(adata_ct1_mo, name_list=gl_source, knn=5, random_state=42)
#adata_ct2_mo = sc.external.pp.magic(adata_ct2_mo, name_list=gl_recv, knn=5, random_state=42)

print(adata_ct1_mo)
print(adata_ct2_mo)

if issparse(adata_ct1_mo.X):
    Xct1_mo = adata_ct1_mo.X.toarray()
else:
    Xct1_mo = adata_ct1_mo.X

if issparse(adata_ct2_mo.X):
    Xct2_mo = adata_ct2_mo.X.toarray()
else:
    Xct2_mo = adata_ct2_mo.X

# Utilize the mono cultured means here
# Binarize Xct1
Xct1_binary_mo = (Xct1_mo > Xct1means).astype(int)
# Binarize Xct2
Xct2_binary_mo = (Xct2_mo > Xct2means).astype(int)
# Out:
# View of AnnData object with n_obs × n_vars = 1000 × 2
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 1000 × 5
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
import sys
import os

# Replace with your actual path
cc_grn_functions_path = r"C:\Users\ssromerogon\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions"
#cc_grn_functions_path = r"C:\Users\selim\Documents\vs_working_dir\QuantumXCT\python\cc_grn_functions"
sys.path.append(cc_grn_functions_path)

from histogram_functions import create_joint_histogram, plot_joint_histogram, create_percent_joint_histogram, count_boolean_vector_occurrences

# %%
joint_counts_ct1_co, bit_strings_ct1_co = create_joint_histogram(Xct1_binary_co)
#joint_counts_ct1_co, bit_strings_ct1_co = create_percent_joint_histogram(Xct1_binary_co)

num_qubits = Xct1_binary_co.shape[1] 
plot_joint_histogram(joint_counts_ct1_co, num_qubits = num_qubits, figsize = (5,4), title='Data Joint Histogram Co-CT1' )  # Pass num_qubits
#plot_joint_histogram(histogram_data, figsize=(5,4), filename = 'hist_cc_3_4pi.svg', title= r'Histogram $Ry(3\pi/4)$' )

print("Joint Counts:", joint_counts_ct1_co)
print("Bit Strings:", bit_strings_ct1_co)
# Out:
# Joint Counts: Counter({'10': 296, '11': 281, '01': 213, '00': 210})
# Bit Strings: ['00', '01', '10', '11']

# %%
joint_counts_ct1_mo, bit_strings_ct1_mo = create_joint_histogram(Xct1_binary_mo)
#joint_counts_ct1_mo, bit_strings_ct1_mo = create_percent_joint_histogram(Xct1_binary_mo)

num_qubits = Xct1_binary_mo.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct1_mo, num_qubits = num_qubits, features=gl_source, figsize = (5,4), filename = 'joint_counts_mo_ct1.svg', title='Data Joint Histogram Mo-CT1' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct1_mo)
print("Bit Strings:", bit_strings_ct1_mo)
# Out:
# Joint Counts: Counter({'01': 482, '00': 445, '11': 40, '10': 33})
# Bit Strings: ['00', '01', '10', '11']

# %%
joint_counts_ct2_co, bit_strings_ct2_co = create_joint_histogram(Xct2_binary_co)
#joint_counts_ct2_co, bit_strings_ct2_co = create_percent_joint_histogram(Xct2_binary_co)

num_qubits2 = Xct2_binary_co.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct2_co, num_qubits = num_qubits2, features=gl_recv, figsize = (5,4), filename = 'joint_counts_co_ct2.svg', title='Data Joint Histogram Co-CT2' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct2_co)
print("Bit Strings:", bit_strings_ct2_co)
# Out:
# Joint Counts: Counter({'10001': 109, '10101': 94, '10000': 78, '00101': 75, '10111': 70, '10100': 69, '00000': 64, '00001': 64, '10011': 62, '00100': 59, '10010': 48, '00111': 47, '00110': 47, '00011': 44, '10110': 42, '00010': 26, '01001': 2})
# Bit Strings: ['00000', '00001', '00010', '00011', '00100', '00101', '00110', '00111', '01001', '10000', '10001', '10010', '10011', '10100', '10101', '10110', '10111']

# %%
joint_counts_ct2_mo, bit_strings_ct2_mo = create_joint_histogram(Xct2_binary_mo)
#joint_counts_ct2_mo, bit_strings_ct2_mo = create_percent_joint_histogram(Xct2_binary_mo)

num_qubits2 = Xct2_binary_mo.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct2_mo, num_qubits = num_qubits2, features=gl_recv, figsize = (5,4), filename = 'joint_counts_mo_ct2.svg', title='Data Joint Histogram Mo-CT2' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct2_mo)
print("Bit Strings:", bit_strings_ct2_mo)
# Out:
# Joint Counts: Counter({'00000': 664, '10000': 75, '00010': 68, '00001': 54, '01000': 51, '00100': 45, '01010': 8, '10100': 6, '11000': 6, '10001': 4, '00110': 4, '01001': 3, '00101': 2, '10010': 2, '11100': 2, '00011': 2, '10111': 1, '11001': 1, '11010': 1, '01100': 1})
# Bit Strings: ['00000', '00001', '00010', '00011', '00100', '00101', '00110', '01000', '01001', '01010', '01100', '10000', '10001', '10010', '10100', '10111', '11000', '11001', '11010', '11100']

# %%
from quantum_functions import vector_normalize_dictionary_values, create_initial_circuit2

import numpy as np
# --- Apply and Print ---
print("--- New Dictionary Definitions ---")
print("State Set CT1 MO:", joint_counts_ct1_mo)
print("State Set CT2 MO:", joint_counts_ct2_mo)
print("Interacted State Set CT1 CO:", joint_counts_ct1_co)
print("Interacted State Set CT2 CO:", joint_counts_ct2_co)

# Apply vector normalization to the new dictionaries
normalized_joint_counts_ct1_mo = vector_normalize_dictionary_values(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = vector_normalize_dictionary_values(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = vector_normalize_dictionary_values(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = vector_normalize_dictionary_values(joint_counts_ct2_co)

print("\n--- Vector Normalized Dictionary Definitions ---")
print("Normalized State Set CT1 Mo (Vector Norm):", normalized_joint_counts_ct1_mo)
print("Normalized State Set CT2 Mo (Vector Norm):", normalized_joint_counts_ct2_mo)
print("Normalized Interacted State Set CT1 Co (Vector Norm):", normalized_joint_counts_ct1_co)
print("Normalized Interacted State Set CT2 Co (Vector Norm):", normalized_joint_counts_ct2_co)
# 1. Define initial circuits for concatenation
circ1 = create_initial_circuit2(normalized_joint_counts_ct1_mo)
circ2 = create_initial_circuit2(normalized_joint_counts_ct2_mo)
# Out:
# --- New Dictionary Definitions ---
# State Set CT1 MO: Counter({'01': 482, '00': 445, '11': 40, '10': 33})
# State Set CT2 MO: Counter({'00000': 664, '10000': 75, '00010': 68, '00001': 54, '01000': 51, '00100': 45, '01010': 8, '10100': 6, '11000': 6, '10001': 4, '00110': 4, '01001': 3, '00101': 2, '10010': 2, '11100': 2, '00011': 2, '10111': 1, '11001': 1, '11010': 1, '01100': 1})
# Interacted State Set CT1 CO: Counter({'10': 296, '11': 281, '01': 213, '00': 210})
# Interacted State Set CT2 CO: Counter({'10001': 109, '10101': 94, '10000': 78, '00101': 75, '10111': 70, '10100': 69, '00000': 64, '00001': 64, '10011': 62, '00100': 59, '10010': 48, '00111': 47, '00110': 47, '00011': 44, '10110': 42, '00010': 26, '01001': 2})
#
# --- Vector Normalized Dictionary Definitions ---
# Normalized State Set CT1 Mo (Vector Norm): {'01': 0.7324602048445463, '00': 0.6762340065473509, '10': 0.05014769037317433, '11': 0.060785079240211315}
# Normalized State Set CT2 Mo (Vector Norm): {'00000': 0.9802043414011962, '10100': 0.008857268145191532, '00001': 0.07971541330672378, '10000': 0.11071585181489416, '00010': 0.10038237231217069, '00100': 0.0664295110889365, '01000': 0.07528677923412802, '00101': 0.002952422715063844, '01010': 0.011809690860255377, '10010': 0.002952422715063844, '10111': 0.001476211357531922, '11100': 0.002952422715063844, '01001': 0.004428634072595766, '11000': 0.008857268145191532, '00011': 0.002952422715063844, '10001': 0.005904845430127688, '00110': 0.005904845430127688, '11001': 0.001476211357531922, '11010': 0.001476211357531922, '01100': 0.001476211357531922}
# Normalized Interacted State Set CT1 Co (Vector Norm): {'00': 0.41501165836823395, '10': 0.5849688136999869, '11': 0.5553251238165416, '01': 0.42094039634492303}
# Normalized Interacted State Set CT2 Co (Vector Norm): {'10100': 0.2632399248899471, '00011': 0.16786314050953147, '10010': 0.18312342601039797, '10000': 0.29757556726689666, '00000': 0.24416456801386394, '00001': 0.24416456801386394, '10101': 0.35861670927036265, '10001': 0.415842779898612, '10011': 0.2365344252634307, '00111': 0.17930835463518133, '00100': 0.22508921113778083, '00101': 0.2861303531412468, '10111': 0.2670549962651637, '10110': 0.16023299775909822, '00110': 0.17930835463518133, '00010': 0.09919185575563223, '01001': 0.007630142750433248}

# %%
from quantum_functions import concatenate_circuits_with_separate_measurements, add_cnots_and_measurements_to_circuit, score_circuit_kl_divergences

def test_specific_topology(
    circ1, 
    circ2, 
    cnot_topology, 
    state_vec_probs_target1, 
    state_vec_probs_target2, 
    nshots=5000
):
    """
    Manually injects a specific CNOT topology and evaluates the KL divergence.
    """
    ng_circ1 = circ1.num_qubits
    
    # 1. Concatenate the two base circuits
    base_combined = concatenate_circuits_with_separate_measurements(circ1, circ2)
    
    # 2. Add your specific CNOTs and the measurement gates
    # Note: Using your existing 'add_cnots_and_measurements_to_circuit'
    circuit_to_test = add_cnots_and_measurements_to_circuit(
        base_combined, 
        ng_circ1, 
        cnot_topology
    )
    
    # 3. Score it
    kl_div1, kl_div2 = score_circuit_kl_divergences(
        circuit_to_test,
        state_vec_probs_target1,
        state_vec_probs_target2,
        nshots
    )
    
    total_kl = kl_div1 + kl_div2 if kl_div1 is not None and kl_div2 is not None else float('inf')
    
    print(f"\n--- Topology Test Results ---")
    print(f"CNOTs applied: {cnot_topology}")
    print(f"KL Div (Circ 1): {kl_div1:.6f}")
    print(f"KL Div (Circ 2): {kl_div2:.6f}")
    print(f"Total Combined KL: {total_kl:.6f}")
    
    return circuit_to_test, total_kl


# Define your "Ground Truth" or "Expected" topology
#my_expected_topology = [(0, 2), (2, 3), (3, 4), (3, 5), (3, 6), (6, 1)] 
#my_expected_topology = [(0, 2), (2, 3), (3, 6), (6, 1)] 
my_expected_topology = [(0, 2), (2, 3), (3, 4), (3, 6), (6, 1)]
# Run the test
final_circ, score = test_specific_topology(
    circ1, 
    circ2, 
    my_expected_topology,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co
)

final_circ.draw(output="mpl", style="clifford", fold=40, scale=0.5, #filename="cnot_optimized_circuit_classi.svg"
                               )
# Out:
# findfont: Font family ['DejaVu Sans Display'] not found. Falling back to DejaVu Sans.
# --- Topology Test Results ---
# CNOTs applied: [(0, 2), (2, 3), (3, 4), (3, 6), (6, 1)]
# KL Div (Circ 1): 0.847199
# KL Div (Circ 2): 1.842008
# Total Combined KL: 2.689207

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_circ, nshots=5000, 
                            title_prefix="CNOT Optimized Circuit", figsize=(8,4.5), 
                            #figure_save_name = "cnot_optimized_circuit_histograms.svg" 
                            )
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'00': 2258, '01': 2506, '11': 204, '10': 32}
# Counts for c_measure2: {'00000': 3543, '00111': 173, '00001': 664, '10011': 161, '10111': 165, '10000': 40, '00011': 154, '00100': 17, '11111': 1, '01011': 2, '11000': 1, '10110': 9, '01001': 4, '10001': 9, '00110': 15, '10010': 11, '00010': 7, '01000': 19, '00101': 2, '01111': 1, '11100': 1, '11011': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
#plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    my_expected_topology, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*1/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    my_expected_topology,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=0.7)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (5 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['2.8538', '2.2537', '1.8232', '2.2677', '2.8216']
# CRX Angle Optimization took: 17.61 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['2.8538', '2.2537', '1.8232', '2.2677', '2.8216']
#   Minimum Combined KL Divergence with Optimized CRX: 1.805461
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                          ┌─┐                               »
# «         q_0: ──────■─────────────────────┤M├───────────────────────────────»
# «                    │                     └╥┘                               »
# «         q_1: ──────┼──────────────────────╫────────────────────────────────»
# «              ┌─────┴──────┐               ║               ┌─┐              »
# «         q_2: ┤ Rx(2.8538) ├──────■────────╫───────────────┤M├──────────────»
# «              └────────────┘┌─────┴──────┐ ║               └╥┘              »
# «         q_3: ──────────────┤ Rx(2.2537) ├─╫───────■────────╫───────■───────»
# «                            └────────────┘ ║ ┌─────┴──────┐ ║       │       »
# «         q_4: ─────────────────────────────╫─┤ Rx(1.8232) ├─╫───────┼───────»
# «                   ┌─┐                     ║ └────────────┘ ║       │       »
# «         q_5: ─────┤M├─────────────────────╫────────────────╫───────┼───────»
# «                   └╥┘                     ║                ║ ┌─────┴──────┐»
# «         q_6: ──────╫──────────────────────╫────────────────╫─┤ Rx(2.2677) ├»
# «                    ║                      ║                ║ └────────────┘»
# «c_measure1: 2/══════╬══════════════════════╩════════════════╬═══════════════»
# «                    ║                      0                ║               »
# «c_measure2: 5/══════╩═══════════════════════════════════════╩═══════════════»
# «                    3                                       0               »
# «
# «         q_0: ──────────────────────────
# «                 ┌────────────┐   ┌─┐
# «         q_1: ───┤ Rx(2.8216) ├───┤M├───
# «                 └─────┬──────┘   └╥┘
# «         q_2: ─────────┼───────────╫────
# «                       │       ┌─┐ ║
# «         q_3: ─────────┼───────┤M├─╫────
# «              ┌─┐      │       └╥┘ ║
# «         q_4: ┤M├──────┼────────╫──╫────
# «              └╥┘      │        ║  ║
# «         q_5: ─╫───────┼────────╫──╫────
# «               ║       │        ║  ║ ┌─┐
# «         q_6: ─╫───────■────────╫──╫─┤M├
# «               ║                ║  ║ └╥┘
# «c_measure1: 2/═╬════════════════╬══╩══╬═
# «               ║                ║  1  ║
# «c_measure2: 5/═╩════════════════╩═════╩═
# «               2                1     4
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'00': 2240, '11': 1668, '01': 1010, '10': 82}
# Counts for c_measure2: {'00000': 2281, '10111': 1038, '00011': 149, '10011': 645, '00001': 511, '10100': 3, '00111': 253, '11011': 7, '10000': 34, '10110': 15, '11111': 10, '01001': 3, '10010': 7, '10001': 8, '00100': 12, '00110': 3, '01011': 2, '00101': 3, '01111': 2, '11101': 1, '11000': 1, '01000': 11, '00010': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
#plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import find_cnot_candidates_from_state_diff
thresh = 0.01
# --- State and Density Matrix Analysis ---
initial_cnot_config, stats = find_cnot_candidates_from_state_diff(
    normalized_joint_counts_ct1_mo, normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co, normalized_joint_counts_ct2_co,
    threshold = thresh, search_mode="pos", show_plot = True, verbose_print = True)

print(stats)
# Out:
# --- CNOT Analysis (pos) ---
# Max Signal: 0.0592
# Candidates Found: 30 / 42
# ------------------------------
#
# {'max_element': 0.05917293538518284, 'min_element': -0.5049040601854593, 'abs_average': 0.0036331824769214476, 'relevant_avg': 0.01223226362003928}

# %%
from quantum_functions import find_best_cnot_sequence_iterative_n_wise, concatenate_circuits_with_separate_measurements, add_cnots_and_measurements_to_circuit

np.random.seed(42) 

print("\n" + "="*40)
print("--- Running N-wise Search ---")
print("="*40)

# Single insertion can be insertion or deletation of CX (something failing with the update criteria)
all_possible_single_cnots, best_cnot_sequence, min_kl_sum = find_best_cnot_sequence_iterative_n_wise(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    nshots=5000,
    threshold=thresh,
    search_mode="pos",
    nchoose=2,
    kl_tol = 0.1, 
    ratio_kl_tol = 0.6
)

print("\n" + "="*40)
if best_cnot_sequence:
    print(f"Multi-Epoch Search Optimal CNOT sequence found:")
    for cnot in best_cnot_sequence:
        print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    print(f"With minimum combined KL Divergence: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("Multi-Epoch Search: No sequence improved the KL divergence beyond the baseline.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))
print("="*40 + "\n")
# Out:
# ========================================
# --- Running N-wise Search ---
# ========================================
#
# --- Starting Iterative Pairwise Search ---
# --- CNOT Analysis (pos) ---
# Max Signal: 0.0592
# Candidates Found: 30 / 42
# ------------------------------
#
# Number of initial CNOT candidates: 30
# Initial KL-divergence: 3.742346
#
#   - Starting Efficiency-Optimized Search -
#
# --- Iteration 1 | Current KL: 3.738089 ---
#    - Single Insertion Phase: Added (0, 2) at index 0. New KL: 3.127899
#   [Phase 1] Added Single: (0, 2) | New KL: 3.127899
#   [Phase 2] Added Pair: ((0, 1), (0, 6)) | New KL: 1.993570
#
# --- Iteration 2 | Current KL: 1.993570 ---
#    - Single Insertion Phase: Added (0, 4) at index 0. New KL: 1.562210
#   [Phase 1] Added Single: (0, 4) | New KL: 1.562210
#   [Phase 2] Added Pair: ((0, 3), (1, 0)) | New KL: 1.129499
#
# --- Iteration 3 | Current KL: 1.129499 ---
#   - No improvements in any phase. Search Terminated.
#
# --- Total Search Time: 641.70s ---
#
# --- Pairwise Addition Result ---
# Best sequence after addition: [(0, 4), (0, 2), (0, 1), (0, 6), (0, 3), (1, 0)]
# KL sum after addition: 1.129499
#
# Total search time: 642.38 seconds.
#
# ========================================
# Multi-Epoch Search Optimal CNOT sequence found:
#   q[0] -> q[4]
#   q[0] -> q[2]
#   q[0] -> q[1]
#   q[0] -> q[6]
#   q[0] -> q[3]
#   q[1] -> q[0]
# With minimum combined KL Divergence: 1.129499
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                     »
# «         q_0: ─────■──────────■──────────■──────────■──────────■─────»
# «                   │          │     ┌────┴────┐     │          │     »
# «         q_1: ─────┼──────────┼─────┤ Rx(π/2) ├─────┼──────────┼─────»
# «                   │     ┌────┴────┐└───┬─┬───┘     │          │     »
# «         q_2: ─────┼─────┤ Rx(π/2) ├────┤M├─────────┼──────────┼─────»
# «                   │     └─────────┘    └╥┘         │     ┌────┴────┐»
# «         q_3: ─────┼─────────────────────╫──────────┼─────┤ Rx(π/2) ├»
# «              ┌────┴────┐    ┌─┐         ║          │     └─────────┘»
# «         q_4: ┤ Rx(π/2) ├────┤M├─────────╫──────────┼────────────────»
# «              └───┬─┬───┘    └╥┘         ║          │                »
# «         q_5: ────┤M├─────────╫──────────╫──────────┼────────────────»
# «                  └╥┘         ║          ║     ┌────┴────┐    ┌─┐    »
# «         q_6: ─────╫──────────╫──────────╫─────┤ Rx(π/2) ├────┤M├────»
# «                   ║          ║          ║     └─────────┘    └╥┘    »
# «c_measure1: 2/═════╬══════════╬══════════╬═════════════════════╬═════»
# «                   ║          ║          ║                     ║     »
# «c_measure2: 5/═════╩══════════╩══════════╩═════════════════════╩═════»
# «                   3          2          0                     4     »
# «              ┌─────────┐┌─┐
# «         q_0: ┤ Rx(π/2) ├┤M├───
# «              └────┬────┘└╥┘┌─┐
# «         q_1: ─────■──────╫─┤M├
# «                          ║ └╥┘
# «         q_2: ────────────╫──╫─
# «                  ┌─┐     ║  ║
# «         q_3: ────┤M├─────╫──╫─
# «                  └╥┘     ║  ║
# «         q_4: ─────╫──────╫──╫─
# «                   ║      ║  ║
# «         q_5: ─────╫──────╫──╫─
# «                   ║      ║  ║
# «         q_6: ─────╫──────╫──╫─
# «                   ║      ║  ║
# «c_measure1: 2/═════╬══════╩══╩═
# «                   ║      0  1
# «c_measure2: 5/═════╩═══════════
# «                   1
# ========================================

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_best_circuit_search, nshots=5000, 
                            title_prefix="CNOT Optimized Circuit", figsize=(8,4.5), 
                            #figure_save_name = "cnot_optimized_circuit_histograms.svg" 
                            )
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.7, #filename="cnot_optimized_circuit_classi.svg"
                               )
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'10': 670, '01': 1365, '00': 2217, '11': 748}
# Counts for c_measure2: {'10111': 186, '00100': 181, '10010': 154, '00000': 2319, '00111': 166, '01100': 1, '00101': 200, '00001': 174, '10011': 170, '10110': 164, '10101': 171, '01000': 17, '10000': 208, '00110': 169, '10100': 167, '00010': 200, '01111': 4, '00011': 172, '11001': 1, '10001': 155, '01101': 1, '11011': 1, '01110': 2, '11010': 3, '01011': 1, '11110': 2, '11100': 2, '11000': 2, '01001': 3, '11111': 1, '11101': 1, '01010': 2}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    best_cnot_sequence, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*0/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    best_cnot_sequence,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=0.7)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (6 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['2.0756', '1.8812', '2.0277', '1.7995', '1.5486', '1.2255']
# CRX Angle Optimization took: 22.88 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['2.0756', '1.8812', '2.0277', '1.7995', '1.5486', '1.2255']
#   Minimum Combined KL Divergence with Optimized CRX: 1.055945
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                      »
# «         q_0: ──────■─────────────■─────────────■─────────────■───────»
# «                    │             │       ┌─────┴──────┐      │       »
# «         q_1: ──────┼─────────────┼───────┤ Rx(2.0277) ├──────┼───────»
# «                    │       ┌─────┴──────┐└────┬─┬─────┘      │       »
# «         q_2: ──────┼───────┤ Rx(1.8812) ├─────┤M├────────────┼───────»
# «                    │       └────────────┘     └╥┘            │       »
# «         q_3: ──────┼───────────────────────────╫─────────────┼───────»
# «              ┌─────┴──────┐     ┌─┐            ║             │       »
# «         q_4: ┤ Rx(2.0756) ├─────┤M├────────────╫─────────────┼───────»
# «              └────┬─┬─────┘     └╥┘            ║             │       »
# «         q_5: ─────┤M├────────────╫─────────────╫─────────────┼───────»
# «                   └╥┘            ║             ║       ┌─────┴──────┐»
# «         q_6: ──────╫─────────────╫─────────────╫───────┤ Rx(1.7995) ├»
# «                    ║             ║             ║       └────────────┘»
# «c_measure1: 2/══════╬═════════════╬═════════════╬═════════════════════»
# «                    ║             ║             ║                     »
# «c_measure2: 5/══════╩═════════════╩═════════════╩═════════════════════»
# «                    3             2             0                     »
# «                            ┌────────────┐┌─┐
# «         q_0: ──────■───────┤ Rx(1.2255) ├┤M├───
# «                    │       └─────┬──────┘└╥┘┌─┐
# «         q_1: ──────┼─────────────■────────╫─┤M├
# «                    │                      ║ └╥┘
# «         q_2: ──────┼──────────────────────╫──╫─
# «              ┌─────┴──────┐     ┌─┐       ║  ║
# «         q_3: ┤ Rx(1.5486) ├─────┤M├───────╫──╫─
# «              └────────────┘     └╥┘       ║  ║
# «         q_4: ────────────────────╫────────╫──╫─
# «                                  ║        ║  ║
# «         q_5: ────────────────────╫────────╫──╫─
# «                   ┌─┐            ║        ║  ║
# «         q_6: ─────┤M├────────────╫────────╫──╫─
# «                   └╥┘            ║        ║  ║
# «c_measure1: 2/══════╬═════════════╬════════╩══╩═
# «                    ║             ║        0  1
# «c_measure2: 5/══════╩═════════════╩═════════════
# «                    4             1
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'00': 2323, '10': 632, '11': 1293, '01': 752}
# Counts for c_measure2: {'00000': 2277, '10101': 438, '00001': 93, '10000': 114, '10111': 396, '00110': 101, '00111': 265, '10011': 139, '10001': 130, '10110': 213, '10100': 208, '00101': 262, '00100': 124, '00011': 75, '00010': 65, '11101': 2, '10010': 69, '01000': 14, '11111': 4, '11110': 2, '01011': 1, '01001': 1, '01101': 3, '01111': 1, '01110': 1, '11000': 1, '01010': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison_ang_opt.svg')
plt.show()

# %%
from quantum_functions import find_best_cnot_sequence_multi_epoch

np.random.seed(42) 

print("\n" + "="*40)
print("--- Running Multi-Epoch Refined Search ---")
print("="*40)

n_epochs = 42
min_greedy_depth = 2

best_cnot_sequence, min_kl_sum = find_best_cnot_sequence_multi_epoch(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    n_epochs=n_epochs,
    min_cnot_depth=min_greedy_depth,
    nshots=5000,
    threshold = thresh,
    search_mode="pos",
    kl_tol = 0.05,
    ratio_kl_tol = 0.6
)

print("\n" + "="*40)
if best_cnot_sequence:
    print(f"Multi-Epoch Search Optimal CNOT sequence found:")
    for cnot in best_cnot_sequence:
        print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    print(f"With minimum combined KL Divergence: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )


    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("Multi-Epoch Search: No sequence improved the KL divergence beyond the baseline.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))
print("="*40 + "\n")
# Out:
# ========================================
# --- Running Multi-Epoch Refined Search ---
# ========================================
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Generating CNOT candidates from density matrix difference. ---
# --- CNOT Analysis (pos) ---
# Max Signal: 0.0592
# Candidates Found: 30 / 42
# ------------------------------
#
# Initial KL divergence (baseline): 3.765722
#
# --- Starting Epoch 1/30 (Addition) with CNOT: (1, 4) (KL: 3.729394) ---
#     --> Found a better KL on this path: 3.081857 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.470305 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.958941 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.553046 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.309191 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.183696 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.107489 at depth 8 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.073209 at depth 9 with added CNOT (3, 2)
#   Epoch 1 best KL Sum: 1.073209
#   --> Epoch 1 found a new overall best KL Sum: 1.073209
#
# --- Starting Epoch 2/30 (Addition) with CNOT: (4, 3) (KL: 3.726183) ---
#     --> Found a better KL on this path: 3.088301 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.511814 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.970444 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.537060 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.353444 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.216832 at depth 7 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.142533 at depth 8 with added CNOT (1, 2)
#   Epoch 2 best KL Sum: 1.142533
#
# --- Starting Epoch 3/30 (Addition) with CNOT: (1, 6) (KL: 3.739227) ---
#     --> Found a better KL on this path: 3.101752 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.496787 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.945872 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.516187 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.358124 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.190473 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.074432 at depth 8 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.050122 at depth 9 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.033841 at depth 10 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.011749 at depth 11 with added CNOT (6, 2)
#   Epoch 3 best KL Sum: 1.011749
#   --> Epoch 3 found a new overall best KL Sum: 1.011749
#
# --- Starting Epoch 4/30 (Addition) with CNOT: (6, 1) (KL: 3.708432) ---
#     --> Found a better KL on this path: 3.039753 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.442650 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.982794 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.518890 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.313211 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.247957 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.142003 at depth 8 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.085105 at depth 9 with added CNOT (4, 2)
#     --> Found a better KL on this path: 1.075145 at depth 10 with added CNOT (4, 0)
#   Epoch 4 best KL Sum: 1.075145
#
# --- Starting Epoch 5/30 (Addition) with CNOT: (2, 1) (KL: 3.702241) ---
#     --> Found a better KL on this path: 3.102212 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.444125 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.004913 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.517799 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.346039 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.188474 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.100951 at depth 8 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.071428 at depth 9 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.031526 at depth 10 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.014455 at depth 11 with added CNOT (2, 6)
#     --> Found a better KL on this path: 0.963630 at depth 12 with added CNOT (6, 2)
#   Epoch 5 best KL Sum: 0.963630
#   --> Epoch 5 found a new overall best KL Sum: 0.963630
#
# --- Starting Epoch 6/30 (Addition) with CNOT: (0, 6) (KL: 3.102240) ---
#     --> Found a better KL on this path: 2.512780 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.018327 at depth 3 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.557446 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.366604 at depth 5 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.159362 at depth 6 with added CNOT (1, 0)
#   Epoch 6 best KL Sum: 1.159362
#
# --- Starting Epoch 7/30 (Addition) with CNOT: (0, 2) (KL: 3.156912) ---
#     --> Found a better KL on this path: 2.490789 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 1.977263 at depth 3 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.520301 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.358736 at depth 5 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.190965 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.148700 at depth 7 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.078571 at depth 8 with added CNOT (3, 6)
#   Epoch 7 best KL Sum: 1.078571
#
# --- Starting Epoch 8/30 (Addition) with CNOT: (0, 1) (KL: 3.212400) ---
#     --> Found a better KL on this path: 2.592425 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 1.953158 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.515041 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.372987 at depth 5 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.176606 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.126376 at depth 7 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.099012 at depth 8 with added CNOT (2, 6)
#   Epoch 8 best KL Sum: 1.099012
#
# --- Starting Epoch 9/30 (Addition) with CNOT: (1, 0) (KL: 3.734268) ---
#     --> Found a better KL on this path: 3.101862 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.444438 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.973669 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.599744 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.365811 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.168726 at depth 7 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.120351 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.114004 at depth 9 with added CNOT (2, 0)
#   Epoch 9 best KL Sum: 1.114004
#
# --- Starting Epoch 10/30 (Addition) with CNOT: (1, 3) (KL: 3.731423) ---
#     --> Found a better KL on this path: 3.080513 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.474402 at depth 3 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.027059 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.505749 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.345283 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.202190 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.048917 at depth 8 with added CNOT (1, 2)
#   Epoch 10 best KL Sum: 1.048917
#
# --- Starting Epoch 11/30 (Addition) with CNOT: (3, 2) (KL: 3.712686) ---
#     --> Found a better KL on this path: 3.089753 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.520431 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.961913 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.573562 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.364463 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.178347 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.068846 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.020817 at depth 9 with added CNOT (3, 1)
#   Epoch 11 best KL Sum: 1.020817
#
# --- Starting Epoch 12/30 (Addition) with CNOT: (2, 4) (KL: 3.716685) ---
#     --> Found a better KL on this path: 3.097421 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.503332 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.964055 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.586195 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.336850 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.207378 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.127264 at depth 8 with added CNOT (1, 2)
#   Epoch 12 best KL Sum: 1.127264
#
# --- Starting Epoch 13/30 (Addition) with CNOT: (2, 6) (KL: 3.696833) ---
#     --> Found a better KL on this path: 3.107960 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.508132 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.988834 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.537072 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.363983 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.156027 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.076927 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.001904 at depth 9 with added CNOT (3, 1)
#   Epoch 13 best KL Sum: 1.001904
#
# --- Starting Epoch 14/30 (Addition) with CNOT: (0, 3) (KL: 3.709752) ---
#     --> Found a better KL on this path: 2.952540 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.357914 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.864295 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.358239 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.185959 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.077109 at depth 7 with added CNOT (1, 6)
#   Epoch 14 best KL Sum: 1.077109
#
# --- Starting Epoch 15/30 (Addition) with CNOT: (2, 3) (KL: 3.705795) ---
#     --> Found a better KL on this path: 3.067180 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.463229 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.979181 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.539118 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.320524 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.138539 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.117746 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.099990 at depth 9 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.094448 at depth 10 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.079686 at depth 11 with added CNOT (2, 0)
#   Epoch 15 best KL Sum: 1.079686
#
# --- Starting Epoch 16/30 (Addition) with CNOT: (2, 0) (KL: 3.720019) ---
#     --> Found a better KL on this path: 3.085639 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.481001 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.992100 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.518650 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.349333 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.153389 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.047237 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 0.986196 at depth 9 with added CNOT (3, 1)
#     --> Found a better KL on this path: 0.975936 at depth 10 with added CNOT (6, 0)
#   Epoch 16 best KL Sum: 0.975936
#
# --- Starting Epoch 17/30 (Addition) with CNOT: (0, 4) (KL: 3.166011) ---
#     --> Found a better KL on this path: 2.641985 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.074765 at depth 3 with added CNOT (0, 6)
#     --> Found a better KL on this path: 1.523318 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.356380 at depth 5 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.155040 at depth 6 with added CNOT (1, 3)
#   Epoch 17 best KL Sum: 1.155040
#
# --- Starting Epoch 18/30 (Addition) with CNOT: (4, 6) (KL: 3.729313) ---
#     --> Found a better KL on this path: 3.089267 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.504129 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.003738 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.550016 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.375312 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.205778 at depth 7 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.181641 at depth 8 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.133093 at depth 9 with added CNOT (6, 0)
#   Epoch 18 best KL Sum: 1.133093
#
# --- Starting Epoch 19/30 (Addition) with CNOT: (6, 2) (KL: 3.690313) ---
#     --> Found a better KL on this path: 3.091449 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.486892 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.968528 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.562394 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.325987 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.180495 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.156641 at depth 8 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.125863 at depth 9 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.116851 at depth 10 with added CNOT (6, 1)
#   Epoch 19 best KL Sum: 1.116851
#
# --- Starting Epoch 20/30 (Addition) with CNOT: (6, 4) (KL: 3.733111) ---
#     --> Found a better KL on this path: 3.100408 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.469901 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.934114 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.518967 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.336506 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.242767 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.115356 at depth 8 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.049502 at depth 9 with added CNOT (6, 2)
#   Epoch 20 best KL Sum: 1.049502
#
# --- Starting Epoch 21/30 (Addition) with CNOT: (3, 4) (KL: 3.713349) ---
#     --> Found a better KL on this path: 3.101746 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.474951 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.977800 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.527677 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.340299 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.118064 at depth 7 with added CNOT (1, 0)
#   Epoch 21 best KL Sum: 1.118064
#
# --- Starting Epoch 22/30 (Addition) with CNOT: (6, 3) (KL: 3.696954) ---
#     --> Found a better KL on this path: 3.054666 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.490640 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.959756 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.548586 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.341338 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.155206 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.123961 at depth 8 with added CNOT (2, 1)
#   Epoch 22 best KL Sum: 1.123961
#
# --- Starting Epoch 23/30 (Addition) with CNOT: (4, 2) (KL: 3.739958) ---
#     --> Found a better KL on this path: 3.062601 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.498206 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.994867 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.496077 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.374760 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.148188 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.071161 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 0.967908 at depth 9 with added CNOT (3, 1)
#   Epoch 23 best KL Sum: 0.967908
#
# --- Starting Epoch 24/30 (Addition) with CNOT: (3, 6) (KL: 3.699696) ---
#     --> Found a better KL on this path: 3.071601 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.466485 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.995058 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.606451 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.360720 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.183254 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.122130 at depth 8 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.106410 at depth 9 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.051803 at depth 10 with added CNOT (4, 0)
#   Epoch 24 best KL Sum: 1.051803
#
# --- Starting Epoch 25/30 (Addition) with CNOT: (4, 0) (KL: 3.757248) ---
#     --> Found a better KL on this path: 3.073537 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.506689 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.003893 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.551083 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.353133 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.125879 at depth 7 with added CNOT (1, 3)
#   Epoch 25 best KL Sum: 1.125879
#
# --- Starting Epoch 26/30 (Addition) with CNOT: (3, 0) (KL: 3.732884) ---
#     --> Found a better KL on this path: 3.109413 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.503083 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.021621 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.571747 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.349132 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.202528 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.146702 at depth 8 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.135724 at depth 9 with added CNOT (3, 6)
#   Epoch 26 best KL Sum: 1.135724
#
# --- Starting Epoch 27/30 (Addition) with CNOT: (1, 2) (KL: 3.714898) ---
#     --> Found a better KL on this path: 3.069741 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.466455 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.996414 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.512333 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.305227 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.211462 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.152116 at depth 8 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.108461 at depth 9 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.097096 at depth 10 with added CNOT (1, 6)
#     --> Found a better KL on this path: 1.055222 at depth 11 with added CNOT (4, 6)
#     --> Found a better KL on this path: 1.042302 at depth 12 with added CNOT (3, 0)
#   Epoch 27 best KL Sum: 1.042302
#
# --- Starting Epoch 28/30 (Addition) with CNOT: (6, 0) (KL: 3.720940) ---
#     --> Found a better KL on this path: 3.062774 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.442072 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.977932 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.481124 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.314913 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.151291 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.061559 at depth 8 with added CNOT (1, 2)
#   Epoch 28 best KL Sum: 1.061559
#
# --- Starting Epoch 29/30 (Addition) with CNOT: (4, 1) (KL: 3.715713) ---
#     --> Found a better KL on this path: 3.116018 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.468319 at depth 3 with added CNOT (0, 6)
#     --> Found a better KL on this path: 1.981733 at depth 4 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.573878 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.331297 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.205815 at depth 7 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.178424 at depth 8 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.143797 at depth 9 with added CNOT (2, 6)
#     --> Found a better KL on this path: 1.109992 at depth 10 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.093113 at depth 11 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.065820 at depth 12 with added CNOT (1, 2)
#   Epoch 29 best KL Sum: 1.065820
#
# --- Starting Epoch 30/30 (Addition) with CNOT: (3, 1) (KL: 3.680802) ---
#     --> Found a better KL on this path: 3.069967 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.430607 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.959052 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.578821 at depth 5 with added CNOT (0, 1)
#     --> Found a better KL on this path: 1.312959 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.166101 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.108128 at depth 8 with added CNOT (1, 2)
#   Epoch 30 best KL Sum: 1.108128
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 12 CNOTs (KL Sum: 0.963630)
#   No CNOT removal improved the score. Stopping removal search.
#
# Final Result: Best sequence found has 9 CNOTs (KL: 0.967908).
#
# Total search took: 1885.30 seconds.
#
# ========================================
# Multi-Epoch Search Optimal CNOT sequence found:
#   q[4] -> q[2]
#   q[0] -> q[6]
#   q[0] -> q[2]
#   q[0] -> q[1]
#   q[0] -> q[4]
#   q[1] -> q[0]
#   q[0] -> q[3]
#   q[1] -> q[6]
#   q[3] -> q[1]
# With minimum combined KL Divergence: 0.967908
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                     »
# «         q_0: ────────────────■──────────■──────────■──────────■─────»
# «                              │          │     ┌────┴────┐     │     »
# «         q_1: ────────────────┼──────────┼─────┤ Rx(π/2) ├─────┼─────»
# «              ┌─────────┐     │     ┌────┴────┐└───┬─┬───┘     │     »
# «         q_2: ┤ Rx(π/2) ├─────┼─────┤ Rx(π/2) ├────┤M├─────────┼─────»
# «              └────┬────┘     │     └─────────┘    └╥┘         │     »
# «         q_3: ─────┼──────────┼─────────────────────╫──────────┼─────»
# «                   │          │                     ║     ┌────┴────┐»
# «         q_4: ─────■──────────┼─────────────────────╫─────┤ Rx(π/2) ├»
# «                  ┌─┐         │                     ║     └─────────┘»
# «         q_5: ────┤M├─────────┼─────────────────────╫────────────────»
# «                  └╥┘    ┌────┴────┐                ║                »
# «         q_6: ─────╫─────┤ Rx(π/2) ├────────────────╫────────────────»
# «                   ║     └─────────┘                ║                »
# «c_measure1: 2/═════╬════════════════════════════════╬════════════════»
# «                   ║                                ║                »
# «c_measure2: 5/═════╩════════════════════════════════╩════════════════»
# «                   3                                0                »
# «              ┌─────────┐                                 ┌─┐
# «         q_0: ┤ Rx(π/2) ├─────■───────────────────────────┤M├──────
# «              └────┬────┘     │                ┌─────────┐└╥┘┌─┐
# «         q_1: ─────■──────────┼──────────■─────┤ Rx(π/2) ├─╫─┤M├───
# «                              │          │     └────┬────┘ ║ └╥┘
# «         q_2: ────────────────┼──────────┼──────────┼──────╫──╫────
# «                         ┌────┴────┐     │          │      ║  ║ ┌─┐
# «         q_3: ───────────┤ Rx(π/2) ├─────┼──────────■──────╫──╫─┤M├
# «                  ┌─┐    └─────────┘     │                 ║  ║ └╥┘
# «         q_4: ────┤M├────────────────────┼─────────────────╫──╫──╫─
# «                  └╥┘                    │                 ║  ║  ║
# «         q_5: ─────╫─────────────────────┼─────────────────╫──╫──╫─
# «                   ║                ┌────┴────┐    ┌─┐     ║  ║  ║
# «         q_6: ─────╫────────────────┤ Rx(π/2) ├────┤M├─────╫──╫──╫─
# «                   ║                └─────────┘    └╥┘     ║  ║  ║
# «c_measure1: 2/═════╬════════════════════════════════╬══════╩══╩══╬═
# «                   ║                                ║      0  1  ║
# «c_measure2: 5/═════╩════════════════════════════════╩════════════╩═
# «                   2                                4            1
# ========================================

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_best_circuit_search, nshots=5000, title_prefix="CNOT Optimized Circuit")
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.5)
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'01': 835, '11': 1219, '00': 2279, '10': 667}
# Counts for c_measure2: {'00000': 2306, '10100': 334, '10001': 352, '00010': 106, '10101': 331, '10000': 351, '10010': 192, '00001': 94, '10111': 168, '10110': 145, '00011': 73, '00110': 93, '10011': 162, '00100': 95, '00111': 73, '00101': 91, '01000': 13, '11101': 2, '11000': 3, '01001': 2, '11010': 2, '11001': 2, '11100': 2, '11111': 1, '01101': 1, '11011': 1, '01110': 1, '11110': 2, '01011': 1, '01100': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    best_cnot_sequence, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*1/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    best_cnot_sequence,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=1.2)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (9 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['2.4921', '1.6779', '1.5756', '1.5563', '1.5693', '2.5511', '1.5579', '1.5504', '2.5450']
# CRX Angle Optimization took: 32.65 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['2.4921', '1.6779', '1.5756', '1.5563', '1.5693', '2.5511', '1.5579', '1.5504', '2.5450']
#   Minimum Combined KL Divergence with Optimized CRX: 1.001719
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                      »
# «         q_0: ────────────────────■─────────────■─────────────■───────»
# «                                  │             │       ┌─────┴──────┐»
# «         q_1: ────────────────────┼─────────────┼───────┤ Rx(1.5563) ├»
# «              ┌────────────┐      │       ┌─────┴──────┐└────┬─┬─────┘»
# «         q_2: ┤ Rx(2.4921) ├──────┼───────┤ Rx(1.5756) ├─────┤M├──────»
# «              └─────┬──────┘      │       └────────────┘     └╥┘      »
# «         q_3: ──────┼─────────────┼───────────────────────────╫───────»
# «                    │             │                           ║       »
# «         q_4: ──────■─────────────┼───────────────────────────╫───────»
# «                   ┌─┐            │                           ║       »
# «         q_5: ─────┤M├────────────┼───────────────────────────╫───────»
# «                   └╥┘      ┌─────┴──────┐                    ║       »
# «         q_6: ──────╫───────┤ Rx(1.6779) ├────────────────────╫───────»
# «                    ║       └────────────┘                    ║       »
# «c_measure1: 2/══════╬═════════════════════════════════════════╬═══════»
# «                    ║                                         ║       »
# «c_measure2: 5/══════╩═════════════════════════════════════════╩═══════»
# «                    3                                         0       »
# «                            ┌────────────┐                            »
# «         q_0: ──────■───────┤ Rx(2.5511) ├──────■─────────────────────»
# «                    │       └─────┬──────┘      │                     »
# «         q_1: ──────┼─────────────■─────────────┼─────────────■───────»
# «                    │                           │             │       »
# «         q_2: ──────┼───────────────────────────┼─────────────┼───────»
# «                    │                     ┌─────┴──────┐      │       »
# «         q_3: ──────┼─────────────────────┤ Rx(1.5579) ├──────┼───────»
# «              ┌─────┴──────┐     ┌─┐      └────────────┘      │       »
# «         q_4: ┤ Rx(1.5693) ├─────┤M├──────────────────────────┼───────»
# «              └────────────┘     └╥┘                          │       »
# «         q_5: ────────────────────╫───────────────────────────┼───────»
# «                                  ║                     ┌─────┴──────┐»
# «         q_6: ────────────────────╫─────────────────────┤ Rx(1.5504) ├»
# «                                  ║                     └────────────┘»
# «c_measure1: 2/════════════════════╬═══════════════════════════════════»
# «                                  ║                                   »
# «c_measure2: 5/════════════════════╩═══════════════════════════════════»
# «                                  2                                   »
# «                           ┌─┐
# «         q_0: ─────────────┤M├──────
# «              ┌───────────┐└╥┘┌─┐
# «         q_1: ┤ Rx(2.545) ├─╫─┤M├───
# «              └─────┬─────┘ ║ └╥┘
# «         q_2: ──────┼───────╫──╫────
# «                    │       ║  ║ ┌─┐
# «         q_3: ──────■───────╫──╫─┤M├
# «                            ║  ║ └╥┘
# «         q_4: ──────────────╫──╫──╫─
# «                            ║  ║  ║
# «         q_5: ──────────────╫──╫──╫─
# «                   ┌─┐      ║  ║  ║
# «         q_6: ─────┤M├──────╫──╫──╫─
# «                   └╥┘      ║  ║  ║
# «c_measure1: 2/══════╬═══════╩══╩══╬═
# «                    ║       0  1  ║
# «c_measure2: 5/══════╩═════════════╩═
# «                    4             1
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'00': 2265, '01': 759, '10': 1183, '11': 793}
# Counts for c_measure2: {'00000': 2283, '10000': 445, '10011': 112, '00110': 79, '10010': 125, '10110': 102, '10101': 407, '00100': 93, '10001': 374, '00001': 117, '00010': 98, '10100': 379, '00101': 93, '10111': 126, '00011': 82, '00111': 65, '11100': 1, '01000': 11, '11001': 1, '01111': 1, '01011': 1, '11010': 1, '11101': 2, '11110': 1, '01101': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison_ang_opt.svg')
plt.show()

# %%
from quantum_functions import build_kl_divergence_matrix_interaction

np.random.seed(42) 

print("\n" + "="*40)
print("--- Creating QUBO matrix ---")
print("="*40)
    
kl_divergence_matrix, cnot_to_index, initial_cnot_config, initial_kl_sum = build_kl_divergence_matrix_interaction(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    nshots=5000,
    threshold= thresh, 
    search_mode="pos",
    include_single_cnot_kl=True
)
# Out:
# ========================================
# --- Creating QUBO matrix ---
# ========================================
#
# --- Identifying Potential CNOT Linkers from Density Matrix Difference ---
# --- CNOT Analysis (pos) ---
# Max Signal: 0.0592
# Candidates Found: 30 / 42
# ------------------------------
#
# Initial KL Divergence (no CNOTs): 3.701300
#
# --- Building KL Divergence Matrix (30x30) ---
# Calculating KL for single CNOTs (diagonal elements)...
# Calculating KL for CNOT pairs (off-diagonal elements)...
# Total CNOT pairs tested: 870
# --- KL Divergence Matrix Built ---

# %%
from quantum_functions import kl_to_qubo_matrix

# Creating Q matrix 
kl_div_mat_qubo = kl_to_qubo_matrix(kl_matrix = kl_divergence_matrix, initial_kl_sum = initial_kl_sum)

# %%
from qiskit_optimization import QuadraticProgram
from qiskit.quantum_info import SparsePauliOp
import numpy as np

# Assume kl_div_mat_qubo is your 42x42 NumPy array

num_qubits = kl_div_mat_qubo.shape[0]

# --- 1. Define the Quadratic Program (QUBO) ---
qp = QuadraticProgram(name="CnotOptimization")

for i in range(num_qubits):
    qp.binary_var(name=f'x{i}')

# Set the objective function to minimize the cost defined by the QUBO matrix
# The matrix must be passed as the 'quadratic' term.
qp.minimize(quadratic=kl_div_mat_qubo)

# --- 2. Convert the QUBO to an Ising Hamiltonian ---
# The Ising Converter performs the necessary transformation (x = (1 - Z)/2)
hamiltonian, offset = qp.to_ising()
print(offset)
print(hamiltonian)
# Out:
# -7.165314516138689
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIZZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZZIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIZIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIZIII', 'IIIIII ...
#               coeffs=[ 7.35382435e-01+0.j, -1.45125976e-02+0.j,  1.04340794e+00+0.j,
#   2.76964024e-03+0.j,  4.71869091e-01+0.j, -3.52762344e-03+0.j,
#   7.57502275e-01+0.j,  7.07674574e-04+0.j,  7.29036178e-01+0.j,
#  -5.56138904e-02+0.j,  3.38798968e-01+0.j, -8.71593193e-02+0.j,
#   3.81251955e-01+0.j, -3.16584913e-02+0.j,  4.07721605e-01+0.j,
#  -8.55686205e-02+0.j,  4.16360108e-01+0.j, -9.39252352e-02+0.j,
#   4.36150115e-01+0.j, -1.27446124e-02+0.j,  4.70646090e-01+0.j,
#  -2.95404199e-03+0.j,  5.10958880e-01+0.j,  1.00301453e-04+0.j,
#   1.77558121e-01+0.j, -1.12153723e-02+0.j,  4.02685850e-01+0.j,
#  -6.68792191e-03+0.j,  3.65458672e-01+0.j, -3.56567862e-03+0.j,
#  -2.66398044e-02+0.j, -3.46040849e-02+0.j, -1.71042482e-02+0.j,
#  -1.94898505e-02+0.j, -1.84617634e-02+0.j, -1.74888448e-02+0.j,
#  -2.54745251e-02+0.j, -2.16816137e-02+0.j, -1.57582802e-02+0.j,
#  -2.01772812e-02+0.j, -5.87131992e-03+0.j, -1.03512848e-02+0.j,
#  -2.51207487e-02+0.j, -1.93503801e-02+0.j, -1.53863910e-02+0.j,
#  -1.21766343e-02+0.j, -1.23691287e-02+0.j, -1.97900366e-02+0.j,
#  -1.71032868e-02+0.j, -1.00985244e-02+0.j, -8.00970579e-03+0.j,
#  -6.68700840e-03+0.j, -3.95337328e-04+0.j, -5.76345293e-03+0.j,
#   2.19327570e-04+0.j, -7.48414474e-03+0.j,  6.89262114e-04+0.j])

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_aer import AerSimulator
from qiskit.circuit.library import EfficientSU2
from qiskit.circuit import QuantumCircuit
from qiskit.compiler import transpile
import numpy as np

# --- 1. Configuration (Example values) ---
num_qubits = kl_div_mat_qubo.shape[0]
reps = 1
entanglement = 'circular'  # linear sca circular pairwise reverse_linear full

# --- 2. Ansatz Creation ---
ansatz = EfficientSU2( num_qubits=num_qubits, entanglement=entanglement, reps=reps)

basis_gates = ['u', 'cx'] 
# 2. Transpile the circuit to decompose it into the basis gates.
expanded_ansatz = transpile(
    ansatz, 
    basis_gates = basis_gates, 
    optimization_level = 0  # Set to 0 to minimize changes beyond decomposition
)

# To run on hardware, select the backend with the fewest number of jobs in the queue
backend = AerSimulator()
#backend = service.least_busy(operational=True, simulator=False)
#expanded_ansatz.draw()
# Out:
# C:\Users\ssromerogon\AppData\Local\Temp\ipykernel_47796\2260493373.py:14: DeprecationWarning: The class ``qiskit.circuit.library.n_local.efficient_su2.EfficientSU2`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.efficient_su2 instead.
#   ansatz = EfficientSU2( num_qubits=num_qubits, entanglement=entanglement, reps=reps)

# %%
from quantum_functions import vqe_solver
result, optimized_params, cost_values = vqe_solver(
    expanded_ansatz,
    hamiltonian,
    backend,
    optimizer_method="COBYLA", # COBYLA | L-BFGS-B 
    niter= 200
)

# Plot the cost function values
plt.figure(figsize=(5, 4))
plt.plot(cost_values)
plt.xlabel("Optimization Iteration")
plt.ylabel("Cost Function Value (Energy)")
plt.title("Energy Minimization Curve")
plt.grid(True)
plt.tight_layout()
#plt.savefig('vqe_opt_curve_qmat.svg', bbox_inches='tight')
plt.show()
# Out:
# Starting optimization with method: COBYLA
# Iteration 0: Current cost: 0.22391159316477316
# Iteration 20: Current cost: 0.013260511662107679
# Iteration 40: Current cost: 0.05088214356163598
# Iteration 60: Current cost: -6.523851079921254
# Iteration 80: Current cost: -6.236889275561749
# Iteration 100: Current cost: -6.5039693788916
# Iteration 200: Current cost: -8.224213196591
#
# Optimization Result:
#  message: Maximum number of function evaluations has been exceeded.
#  success: False
#   status: 2
#      fun
#   θ[90]: 1.4960234032555968
#   θ[91]: 1.5135716883775776
#   θ[92]: 1.4182388733606308
#   θ[93]: 1.5005904776311358
#   θ[94]: 1.459144319058262
#   θ[95]: 1.447847293492243
#   θ[96]: 1.5256674294829036
#   θ[97]: 1.3851953367854666
#   θ[98]: 1.375672442398351
#   θ[99]: 1.471765789813953
#   θ[100]: 1.5070453089207203
#   θ[101]: 2.5729931542547955
#   θ[102]: 1.4513303789047163
#   θ[103]: 2.5962198282814453
#   θ[104]: 1.3940733175811888
#   θ[105]: 1.5539034570770347
#   θ[106]: 1.5556571889260504
#   θ[107]: 1.356024192503785
#   θ[108]: 1.4679803305284875
#   θ[109]: 1.4041157359345031
#   θ[110]: 2.5998383410720036
#   θ[111]: 1.4067599273630453
#   θ[112]: 1.4812062074958228
#   θ[113]: 1.4151474013095868
#   θ[114]: 1.4309932492540687
#   θ[115]: 1.4288917043904152
#   θ[116]: 1.5494329900673758
#   θ[117]: 2.597854121381175
#   θ[118]: 1.4221695974764865
#   θ[119]: 1.3653361662609182

# %%
from quantum_functions import evaluate_and_plot_ansatz

counts, bound_circuit = evaluate_and_plot_ansatz(
    ansatz=expanded_ansatz, 
    params=optimized_params, 
    backend=backend,
    shots=1024,
    title="VQE Opt. Histogram for QUBO",
    show_plot=True  # Explicitly show the plot
)
#bound_circuit.draw(output="mpl", style="clifford", fold=40)  # Show the circuit plot

# %%
# ==============================================================================
# --- CALL THE VQE HYBRID SEARCH AND DISPLAY RESULTS ---
# ==============================================================================
from quantum_functions import run_vqe_hybrid_search
# Assume these variables are defined from your previous notebook cells:
# - counts: The dictionary of measurement results from your VQE run.
# - initial_cnot_config: The full list of CNOT candidates used for the VQE QUBO.
# - circ1, circ2: Your two base quantum circuits.
# - normalized_joint_counts_ct1_mo, normalized_joint_counts_ct2_mo: Initial states.
# - normalized_joint_counts_ct1_co, normalized_joint_counts_ct2_co: Target states.
# - thresh: The threshold for density matrix analysis (if used).

# Call the main search function
best_cnot_sequence, min_kl_sum, best_solution_rank = run_vqe_hybrid_search(
    vqe_counts=counts,
    initial_cnot_config=initial_cnot_config,
    circ1=circ1,
    circ2=circ2,
    state_probs_initial1=normalized_joint_counts_ct1_mo,
    state_probs_initial2=normalized_joint_counts_ct2_mo,
    state_vec_probs_target1=normalized_joint_counts_ct1_co,
    state_vec_probs_target2=normalized_joint_counts_ct2_co,
    num_solutions_to_test=3,
    nshots=5000,
    threshold=thresh,
    search_mode="pos",
    kl_tol=0.1,
    ratio_kl_tol=0.6,
    max_greedy_depth=30
)

# --- FINAL SUMMARY: Display the Overall Best Solution ---
print("\n" + "="*60)
print("--- OVERALL BEST SOLUTION AFTER HYBRID SEARCH ---")
print("="*60)

if best_solution_rank is not None:
    print(f"The best solution originated from the VQE's result at Rank {best_solution_rank}.")
    print(f"\nFinal optimal CNOT sequence found with {len(best_cnot_sequence)} CNOTs:")
    if best_cnot_sequence:
        for cnot in best_cnot_sequence:
            print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    else:
        print("  (The best solution found was to use no CNOTs)")

    print(f"\nWith a minimum combined KL Divergence of: {min_kl_sum:.6f}")

    # Re-create and draw the final, absolute best circuit
    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("No VQE solution led to a greedy search result that improved upon the initial baseline.")
    print("The best configuration is the baseline circuit with no CNOTs.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))

print("="*60 + "\n")
# Out:
# ============================================================
# --- Preparing to test Top 3 VQE solutions in REVERSE order ---
# ============================================================
#
# --- Testing VQE Solution (Rank 3/3) ---
# This VQE Solution corresponds to a candidate subset of 25 CNOTs:
#   q[0] -> q[2]
#   q[0] -> q[4]
#   q[0] -> q[6]
#   q[1] -> q[3]
#   q[1] -> q[4]
#   q[1] -> q[6]
#   q[2] -> q[0]
#   q[2] -> q[1]
#   q[2] -> q[3]
#   q[2] -> q[4]
#   q[2] -> q[6]
#   q[3] -> q[0]
#   q[3] -> q[1]
#   q[3] -> q[2]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[4] -> q[0]
#   q[4] -> q[1]
#   q[4] -> q[2]
#   q[4] -> q[3]
#   q[4] -> q[6]
#   q[6] -> q[0]
#   q[6] -> q[1]
#   q[6] -> q[2]
#   q[6] -> q[4]
#
# Setting number of greedy search epochs to 25 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 25
# Initial KL divergence (baseline): 3.729584
#
# --- Starting Epoch 1/25 (Addition) with CNOT: (4, 2) (KL: 3.749674) ---
#   Skipping epoch: Single CNOT KL (3.749674) does not improve over baseline (3.729584).
#
# --- Starting Epoch 2/25 (Addition) with CNOT: (6, 4) (KL: 3.683042) ---
#     --> Found a better KL on this path: 3.044389 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.430389 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.016679 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.633644 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.505294 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.312987 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.270416 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.236173 at depth 9 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.201723 at depth 10 with added CNOT (2, 6)
#   Epoch 2 best KL Sum: 1.201723
#   --> Epoch 2 found a new overall best KL Sum: 1.201723
#
# --- Starting Epoch 3/25 (Addition) with CNOT: (3, 4) (KL: 3.714578) ---
#     --> Found a better KL on this path: 3.095333 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.485066 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.056163 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.677804 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.514651 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.347000 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.272862 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.202315 at depth 9 with added CNOT (4, 1)
#   Epoch 3 best KL Sum: 1.202315
#
# --- Starting Epoch 4/25 (Addition) with CNOT: (4, 0) (KL: 3.751060) ---
#   Skipping epoch: Single CNOT KL (3.751060) does not improve over baseline (3.729584).
#
# --- Starting Epoch 5/25 (Addition) with CNOT: (6, 1) (KL: 3.651110) ---
#     --> Found a better KL on this path: 3.078769 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.472364 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.027810 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.665577 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.541985 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.310951 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.269346 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.161031 at depth 9 with added CNOT (3, 0)
#   Epoch 5 best KL Sum: 1.161031
#   --> Epoch 5 found a new overall best KL Sum: 1.161031
#
# --- Starting Epoch 6/25 (Addition) with CNOT: (4, 6) (KL: 3.699085) ---
#     --> Found a better KL on this path: 3.098827 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.484724 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.055013 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.664818 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.498867 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.367431 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.257246 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.212391 at depth 9 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.189779 at depth 10 with added CNOT (2, 1)
#   Epoch 6 best KL Sum: 1.189779
#
# --- Starting Epoch 7/25 (Addition) with CNOT: (4, 3) (KL: 3.704618) ---
#     --> Found a better KL on this path: 3.083934 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.526188 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.067272 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.624293 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.487581 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.409594 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.299532 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.219494 at depth 9 with added CNOT (3, 4)
#   Epoch 7 best KL Sum: 1.219494
#
# --- Starting Epoch 8/25 (Addition) with CNOT: (2, 6) (KL: 3.680901) ---
#     --> Found a better KL on this path: 3.110991 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.495954 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.017249 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.649383 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.492839 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.363042 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.253984 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.205092 at depth 9 with added CNOT (3, 6)
#   Epoch 8 best KL Sum: 1.205092
#
# --- Starting Epoch 9/25 (Addition) with CNOT: (0, 6) (KL: 3.082747) ---
#     --> Found a better KL on this path: 2.507644 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.051621 at depth 3 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.670509 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.518665 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.403177 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.258637 at depth 7 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.218988 at depth 8 with added CNOT (6, 0)
#   Epoch 9 best KL Sum: 1.218988
#
# --- Starting Epoch 10/25 (Addition) with CNOT: (3, 6) (KL: 3.712734) ---
#     --> Found a better KL on this path: 3.070967 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.518895 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.056722 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.679266 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.466520 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.358379 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.279943 at depth 8 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.230696 at depth 9 with added CNOT (2, 6)
#     --> Found a better KL on this path: 1.210024 at depth 10 with added CNOT (4, 1)
#   Epoch 10 best KL Sum: 1.210024
#
# --- Starting Epoch 11/25 (Addition) with CNOT: (2, 1) (KL: 3.706417) ---
#     --> Found a better KL on this path: 3.064016 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.474316 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.019881 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.646196 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.484658 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.339386 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.269449 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.198327 at depth 9 with added CNOT (4, 6)
#     --> Found a better KL on this path: 1.155992 at depth 10 with added CNOT (2, 6)
#   Epoch 11 best KL Sum: 1.155992
#   --> Epoch 11 found a new overall best KL Sum: 1.155992
#
# --- Starting Epoch 12/25 (Addition) with CNOT: (2, 3) (KL: 3.746863) ---
#   Skipping epoch: Single CNOT KL (3.746863) does not improve over baseline (3.729584).
#
# --- Starting Epoch 13/25 (Addition) with CNOT: (1, 3) (KL: 3.744117) ---
#   Skipping epoch: Single CNOT KL (3.744117) does not improve over baseline (3.729584).
#
# --- Starting Epoch 14/25 (Addition) with CNOT: (6, 2) (KL: 3.731457) ---
#   Skipping epoch: Single CNOT KL (3.731457) does not improve over baseline (3.729584).
#
# --- Starting Epoch 15/25 (Addition) with CNOT: (0, 2) (KL: 3.148961) ---
#     --> Found a better KL on this path: 2.501981 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.040087 at depth 3 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.691880 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.481338 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.366323 at depth 6 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.298781 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.224503 at depth 8 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.181565 at depth 9 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.160833 at depth 10 with added CNOT (6, 2)
#     --> Found a better KL on this path: 1.156592 at depth 11 with added CNOT (4, 6)
#   Epoch 15 best KL Sum: 1.156592
#
# --- Starting Epoch 16/25 (Addition) with CNOT: (2, 4) (KL: 3.690255) ---
#     --> Found a better KL on this path: 3.091432 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.423892 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.045393 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.664386 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.509979 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.406127 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.234062 at depth 8 with added CNOT (2, 3)
#   Epoch 16 best KL Sum: 1.234062
#
# --- Starting Epoch 17/25 (Addition) with CNOT: (3, 1) (KL: 3.686055) ---
#     --> Found a better KL on this path: 3.051506 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.440238 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.057701 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.663360 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.497075 at depth 6 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.363330 at depth 7 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.260449 at depth 8 with added CNOT (4, 0)
#   Epoch 17 best KL Sum: 1.260449
#
# --- Starting Epoch 18/25 (Addition) with CNOT: (1, 6) (KL: 3.697212) ---
#     --> Found a better KL on this path: 3.069478 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.446778 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.021759 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.618600 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.504009 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.335631 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.210484 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.191763 at depth 9 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.191389 at depth 10 with added CNOT (6, 2)
#     --> Found a better KL on this path: 1.189388 at depth 11 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.142771 at depth 12 with added CNOT (3, 4)
#   Epoch 18 best KL Sum: 1.142771
#   --> Epoch 18 found a new overall best KL Sum: 1.142771
#
# --- Starting Epoch 19/25 (Addition) with CNOT: (3, 2) (KL: 3.702033) ---
#     --> Found a better KL on this path: 3.072832 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.463963 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.042687 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.631312 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.496508 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.344855 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.263822 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.245598 at depth 9 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.156352 at depth 10 with added CNOT (3, 1)
#   Epoch 19 best KL Sum: 1.156352
#
# --- Starting Epoch 20/25 (Addition) with CNOT: (3, 0) (KL: 3.705652) ---
#     --> Found a better KL on this path: 3.110278 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.519666 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.043671 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.668296 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.551971 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.376649 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.285355 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.238627 at depth 9 with added CNOT (6, 2)
#     --> Found a better KL on this path: 1.235869 at depth 10 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.211450 at depth 11 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.205178 at depth 12 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.167882 at depth 13 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.167528 at depth 14 with added CNOT (4, 2)
#   Epoch 20 best KL Sum: 1.167528
#
# --- Starting Epoch 21/25 (Addition) with CNOT: (6, 0) (KL: 3.749535) ---
#   Skipping epoch: Single CNOT KL (3.749535) does not improve over baseline (3.729584).
#
# --- Starting Epoch 22/25 (Addition) with CNOT: (2, 0) (KL: 3.732478) ---
#   Skipping epoch: Single CNOT KL (3.732478) does not improve over baseline (3.729584).
#
# --- Starting Epoch 23/25 (Addition) with CNOT: (0, 4) (KL: 3.187943) ---
#     --> Found a better KL on this path: 2.609150 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.043492 at depth 3 with added CNOT (0, 6)
#     --> Found a better KL on this path: 1.641955 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.524249 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.395612 at depth 6 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.304453 at depth 7 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.215494 at depth 8 with added CNOT (6, 0)
#   Epoch 23 best KL Sum: 1.215494
#
# --- Starting Epoch 24/25 (Addition) with CNOT: (4, 1) (KL: 3.747227) ---
#   Skipping epoch: Single CNOT KL (3.747227) does not improve over baseline (3.729584).
#
# --- Starting Epoch 25/25 (Addition) with CNOT: (1, 4) (KL: 3.706909) ---
#     --> Found a better KL on this path: 3.105029 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.499839 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.072097 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.673189 at depth 5 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.512137 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.331554 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.260803 at depth 8 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.217450 at depth 9 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.208863 at depth 10 with added CNOT (4, 0)
#   Epoch 25 best KL Sum: 1.208863
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 12 CNOTs (KL Sum: 1.142771)
#   No CNOT removal improved the score. Stopping removal search.
#
# Final Result: Best sequence found has 10 CNOTs (KL: 1.155992).
#
# Total search took: 711.09 seconds.
#
# Result for (Rank 3): Final KL Sum = 1.155992
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.155992
#   Origin: VQE solution at rank 3
#
# --- Testing VQE Solution (Rank 2/3) ---
# This VQE Solution corresponds to a candidate subset of 24 CNOTs:
#   q[0] -> q[2]
#   q[0] -> q[4]
#   q[0] -> q[6]
#   q[1] -> q[2]
#   q[1] -> q[6]
#   q[2] -> q[0]
#   q[2] -> q[1]
#   q[2] -> q[3]
#   q[2] -> q[4]
#   q[2] -> q[6]
#   q[3] -> q[0]
#   q[3] -> q[1]
#   q[3] -> q[2]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[4] -> q[0]
#   q[4] -> q[1]
#   q[4] -> q[2]
#   q[4] -> q[3]
#   q[4] -> q[6]
#   q[6] -> q[0]
#   q[6] -> q[1]
#   q[6] -> q[2]
#   q[6] -> q[4]
#
# Setting number of greedy search epochs to 24 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 24
# Initial KL divergence (baseline): 3.722665
#
# --- Starting Epoch 1/24 (Addition) with CNOT: (2, 6) (KL: 3.721858) ---
#     --> Found a better KL on this path: 3.091889 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.474936 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.054885 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.597910 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.524828 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.374890 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.305877 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.206223 at depth 9 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.169756 at depth 10 with added CNOT (6, 1)
#   Epoch 1 best KL Sum: 1.169756
#   --> Epoch 1 found a new overall best KL Sum: 1.169756
#
# --- Starting Epoch 2/24 (Addition) with CNOT: (4, 2) (KL: 3.740245) ---
#   Skipping epoch: Single CNOT KL (3.740245) does not improve over baseline (3.722665).
#
# --- Starting Epoch 3/24 (Addition) with CNOT: (6, 0) (KL: 3.743243) ---
#   Skipping epoch: Single CNOT KL (3.743243) does not improve over baseline (3.722665).
#
# --- Starting Epoch 4/24 (Addition) with CNOT: (2, 1) (KL: 3.724805) ---
#   Skipping epoch: Single CNOT KL (3.724805) does not improve over baseline (3.722665).
#
# --- Starting Epoch 5/24 (Addition) with CNOT: (4, 3) (KL: 3.725038) ---
#   Skipping epoch: Single CNOT KL (3.725038) does not improve over baseline (3.722665).
#
# --- Starting Epoch 6/24 (Addition) with CNOT: (0, 4) (KL: 3.211464) ---
#     --> Found a better KL on this path: 2.624623 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.010169 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.682778 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.507182 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.400124 at depth 6 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.276176 at depth 7 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.238419 at depth 8 with added CNOT (3, 0)
#   Epoch 6 best KL Sum: 1.238419
#
# --- Starting Epoch 7/24 (Addition) with CNOT: (4, 1) (KL: 3.709118) ---
#     --> Found a better KL on this path: 3.069384 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.471442 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.021194 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.670010 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.549292 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.349316 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.264404 at depth 8 with added CNOT (2, 3)
#     --> Found a better KL on this path: 1.248936 at depth 9 with added CNOT (4, 2)
#     --> Found a better KL on this path: 1.244579 at depth 10 with added CNOT (3, 6)
#   Epoch 7 best KL Sum: 1.244579
#
# --- Starting Epoch 8/24 (Addition) with CNOT: (3, 0) (KL: 3.687584) ---
#     --> Found a better KL on this path: 3.094568 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.467527 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.054827 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.668101 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.540370 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.384762 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.264288 at depth 8 with added CNOT (2, 1)
#   Epoch 8 best KL Sum: 1.264288
#
# --- Starting Epoch 9/24 (Addition) with CNOT: (6, 4) (KL: 3.701583) ---
#     --> Found a better KL on this path: 3.051494 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.464475 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.048886 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.665444 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.502659 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.397620 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.273093 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.200318 at depth 9 with added CNOT (3, 4)
#   Epoch 9 best KL Sum: 1.200318
#
# --- Starting Epoch 10/24 (Addition) with CNOT: (0, 2) (KL: 3.158188) ---
#     --> Found a better KL on this path: 2.467734 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.058129 at depth 3 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.611832 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.525012 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.384115 at depth 6 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.316720 at depth 7 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.206254 at depth 8 with added CNOT (3, 4)
#   Epoch 10 best KL Sum: 1.206254
#
# --- Starting Epoch 11/24 (Addition) with CNOT: (3, 6) (KL: 3.716720) ---
#     --> Found a better KL on this path: 3.075777 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.444132 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.061727 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.638756 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.481202 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.338083 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.324570 at depth 8 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.289069 at depth 9 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.246104 at depth 10 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.200329 at depth 11 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.194297 at depth 12 with added CNOT (3, 2)
#   Epoch 11 best KL Sum: 1.194297
#
# --- Starting Epoch 12/24 (Addition) with CNOT: (2, 4) (KL: 3.692782) ---
#     --> Found a better KL on this path: 3.067681 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.456335 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.064541 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.668298 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.492897 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.374823 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.254917 at depth 8 with added CNOT (4, 3)
#   Epoch 12 best KL Sum: 1.254917
#
# --- Starting Epoch 13/24 (Addition) with CNOT: (4, 0) (KL: 3.709098) ---
#     --> Found a better KL on this path: 3.099651 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.485544 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.035252 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.636318 at depth 5 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.512534 at depth 6 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.358268 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.295300 at depth 8 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.231326 at depth 9 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.198238 at depth 10 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.160738 at depth 11 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.127760 at depth 12 with added CNOT (6, 0)
#   Epoch 13 best KL Sum: 1.127760
#   --> Epoch 13 found a new overall best KL Sum: 1.127760
#
# --- Starting Epoch 14/24 (Addition) with CNOT: (4, 6) (KL: 3.729328) ---
#   Skipping epoch: Single CNOT KL (3.729328) does not improve over baseline (3.722665).
#
# --- Starting Epoch 15/24 (Addition) with CNOT: (6, 2) (KL: 3.720419) ---
#     --> Found a better KL on this path: 3.047165 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.516364 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.058417 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.626818 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.482265 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.302807 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.284894 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.234976 at depth 9 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.192190 at depth 10 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.152693 at depth 11 with added CNOT (3, 0)
#   Epoch 15 best KL Sum: 1.152693
#
# --- Starting Epoch 16/24 (Addition) with CNOT: (3, 1) (KL: 3.665817) ---
#     --> Found a better KL on this path: 3.063497 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.463719 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.021400 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.617891 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.491613 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.347313 at depth 7 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.296594 at depth 8 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.255598 at depth 9 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.196132 at depth 10 with added CNOT (4, 2)
#   Epoch 16 best KL Sum: 1.196132
#
# --- Starting Epoch 17/24 (Addition) with CNOT: (3, 4) (KL: 3.712245) ---
#     --> Found a better KL on this path: 3.038146 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.462242 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.065400 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.652329 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.481404 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.342896 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.290320 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.260511 at depth 9 with added CNOT (4, 6)
#   Epoch 17 best KL Sum: 1.260511
#
# --- Starting Epoch 18/24 (Addition) with CNOT: (1, 6) (KL: 3.710765) ---
#     --> Found a better KL on this path: 3.066106 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.455974 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.066863 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.652389 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.532552 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.383394 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.311307 at depth 8 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.302636 at depth 9 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.185667 at depth 10 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.124669 at depth 11 with added CNOT (2, 0)
#   Epoch 18 best KL Sum: 1.124669
#   --> Epoch 18 found a new overall best KL Sum: 1.124669
#
# --- Starting Epoch 19/24 (Addition) with CNOT: (6, 1) (KL: 3.716662) ---
#     --> Found a better KL on this path: 3.037352 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.461331 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.968873 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.674885 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.530836 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.387603 at depth 7 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.300746 at depth 8 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.256560 at depth 9 with added CNOT (3, 0)
#   Epoch 19 best KL Sum: 1.256560
#
# --- Starting Epoch 20/24 (Addition) with CNOT: (2, 0) (KL: 3.724920) ---
#   Skipping epoch: Single CNOT KL (3.724920) does not improve over baseline (3.722665).
#
# --- Starting Epoch 21/24 (Addition) with CNOT: (3, 2) (KL: 3.713597) ---
#     --> Found a better KL on this path: 3.096946 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.481181 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.023243 at depth 4 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.649223 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.526514 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.373375 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.293539 at depth 8 with added CNOT (2, 3)
#     --> Found a better KL on this path: 1.254069 at depth 9 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.234517 at depth 10 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.229760 at depth 11 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.188181 at depth 12 with added CNOT (3, 0)
#     --> Found a better KL on this path: 1.170016 at depth 13 with added CNOT (4, 6)
#   Epoch 21 best KL Sum: 1.170016
#
# --- Starting Epoch 22/24 (Addition) with CNOT: (0, 6) (KL: 3.079298) ---
#     --> Found a better KL on this path: 2.462397 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.043318 at depth 3 with added CNOT (0, 4)
#     --> Found a better KL on this path: 1.670338 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.512072 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 1.390505 at depth 6 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.275373 at depth 7 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.196622 at depth 8 with added CNOT (3, 4)
#   Epoch 22 best KL Sum: 1.196622
#
# --- Starting Epoch 23/24 (Addition) with CNOT: (1, 2) (KL: 3.743572) ---
#   Skipping epoch: Single CNOT KL (3.743572) does not improve over baseline (3.722665).
#
# --- Starting Epoch 24/24 (Addition) with CNOT: (2, 3) (KL: 3.723795) ---
#   Skipping epoch: Single CNOT KL (3.723795) does not improve over baseline (3.722665).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 11 CNOTs (KL Sum: 1.124669)
#   No CNOT removal improved the score. Stopping removal search.
#
# Final Result: Best sequence found has 10 CNOTs (KL: 1.169756).
#
# Total search took: 639.24 seconds.
#
# Result for (Rank 2): Final KL Sum = 1.169756
#   This result (1.169756) did not beat the current best (1.155992).
#
# --- Testing VQE Solution (Rank 1/3) ---
# This VQE Solution corresponds to a candidate subset of 27 CNOTs:
#   q[0] -> q[2]
#   q[0] -> q[3]
#   q[0] -> q[6]
#   q[1] -> q[0]
#   q[1] -> q[2]
#   q[1] -> q[3]
#   q[1] -> q[4]
#   q[1] -> q[6]
#   q[2] -> q[0]
#   q[2] -> q[1]
#   q[2] -> q[3]
#   q[2] -> q[4]
#   q[2] -> q[6]
#   q[3] -> q[0]
#   q[3] -> q[1]
#   q[3] -> q[2]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[4] -> q[0]
#   q[4] -> q[1]
#   q[4] -> q[2]
#   q[4] -> q[3]
#   q[4] -> q[6]
#   q[6] -> q[0]
#   q[6] -> q[1]
#   q[6] -> q[2]
#   q[6] -> q[4]
#
# Setting number of greedy search epochs to 27 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 27
# Initial KL divergence (baseline): 3.714777
#
# --- Starting Epoch 1/27 (Addition) with CNOT: (1, 0) (KL: 3.701407) ---
#     --> Found a better KL on this path: 3.073161 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.492819 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.087497 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.904954 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.758770 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.612400 at depth 7 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.448325 at depth 8 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.350891 at depth 9 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.336269 at depth 10 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.264690 at depth 11 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.233556 at depth 12 with added CNOT (3, 2)
#   Epoch 1 best KL Sum: 1.233556
#   --> Epoch 1 found a new overall best KL Sum: 1.233556
#
# --- Starting Epoch 2/27 (Addition) with CNOT: (4, 3) (KL: 3.712435) ---
#     --> Found a better KL on this path: 3.076122 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.501380 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.072690 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.926124 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.763597 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.599744 at depth 7 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.472536 at depth 8 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.419216 at depth 9 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.378750 at depth 10 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.361402 at depth 11 with added CNOT (1, 4)
#     --> Found a better KL on this path: 1.310132 at depth 12 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.308787 at depth 13 with added CNOT (3, 1)
#   Epoch 2 best KL Sum: 1.308787
#
# --- Starting Epoch 3/27 (Addition) with CNOT: (4, 2) (KL: 3.709802) ---
#     --> Found a better KL on this path: 3.099391 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.475869 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.090995 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.942179 at depth 5 with added CNOT (1, 4)
#     --> Found a better KL on this path: 1.788682 at depth 6 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.693476 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.496941 at depth 8 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.385224 at depth 9 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.359432 at depth 10 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.344575 at depth 11 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.303194 at depth 12 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.274389 at depth 13 with added CNOT (6, 2)
#   Epoch 3 best KL Sum: 1.274389
#
# --- Starting Epoch 4/27 (Addition) with CNOT: (2, 1) (KL: 3.711620) ---
#     --> Found a better KL on this path: 3.069154 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.472209 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.122200 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.898759 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.785127 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.650649 at depth 7 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.452085 at depth 8 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.399191 at depth 9 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.355475 at depth 10 with added CNOT (1, 3)
#     --> Found a better KL on this path: 1.355208 at depth 11 with added CNOT (4, 3)
#     --> Found a better KL on this path: 1.285209 at depth 12 with added CNOT (6, 4)
#     --> Found a better KL on this path: 1.245436 at depth 13 with added CNOT (2, 6)
#   Epoch 4 best KL Sum: 1.245436
#
# --- Starting Epoch 5/27 (Addition) with CNOT: (2, 0) (KL: 3.721994) ---
#   Skipping epoch: Single CNOT KL (3.721994) does not improve over baseline (3.714777).
#
# --- Starting Epoch 6/27 (Addition) with CNOT: (0, 3) (KL: 3.632556) ---
#     --> Found a better KL on this path: 2.964960 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.337113 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 1.941087 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.801543 at depth 5 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.602727 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.399735 at depth 7 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.344823 at depth 8 with added CNOT (1, 4)
#     --> Found a better KL on this path: 1.335845 at depth 9 with added CNOT (2, 4)
#   Epoch 6 best KL Sum: 1.335845
#
# --- Starting Epoch 7/27 (Addition) with CNOT: (6, 0) (KL: 3.740141) ---
#   Skipping epoch: Single CNOT KL (3.740141) does not improve over baseline (3.714777).
#
# --- Starting Epoch 8/27 (Addition) with CNOT: (4, 0) (KL: 3.740161) ---
#   Skipping epoch: Single CNOT KL (3.740161) does not improve over baseline (3.714777).
#
# --- Starting Epoch 9/27 (Addition) with CNOT: (3, 1) (KL: 3.728396) ---
#   Skipping epoch: Single CNOT KL (3.728396) does not improve over baseline (3.714777).
#
# --- Starting Epoch 10/27 (Addition) with CNOT: (3, 4) (KL: 3.714973) ---
#   Skipping epoch: Single CNOT KL (3.714973) does not improve over baseline (3.714777).
#
# --- Starting Epoch 11/27 (Addition) with CNOT: (3, 0) (KL: 3.744407) ---
#   Skipping epoch: Single CNOT KL (3.744407) does not improve over baseline (3.714777).
#
# --- Starting Epoch 12/27 (Addition) with CNOT: (2, 3) (KL: 3.734225) ---
#   Skipping epoch: Single CNOT KL (3.734225) does not improve over baseline (3.714777).
#
# --- Starting Epoch 13/27 (Addition) with CNOT: (3, 6) (KL: 3.751205) ---
#   Skipping epoch: Single CNOT KL (3.751205) does not improve over baseline (3.714777).
#
# --- Starting Epoch 14/27 (Addition) with CNOT: (6, 1) (KL: 3.667239) ---
#     --> Found a better KL on this path: 3.037311 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.451962 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.101512 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.900883 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.744038 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.623587 at depth 7 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.484150 at depth 8 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.395944 at depth 9 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.295136 at depth 10 with added CNOT (1, 4)
#   Epoch 14 best KL Sum: 1.295136
#
# --- Starting Epoch 15/27 (Addition) with CNOT: (0, 6) (KL: 3.090047) ---
#     --> Found a better KL on this path: 2.463213 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.047111 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.931843 at depth 4 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.787493 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.614391 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.443075 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.335278 at depth 8 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.293964 at depth 9 with added CNOT (4, 2)
#     --> Found a better KL on this path: 1.289089 at depth 10 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.281241 at depth 11 with added CNOT (6, 2)
#     --> Found a better KL on this path: 1.172597 at depth 12 with added CNOT (1, 4)
#   Epoch 15 best KL Sum: 1.172597
#   --> Epoch 15 found a new overall best KL Sum: 1.172597
#
# --- Starting Epoch 16/27 (Addition) with CNOT: (0, 2) (KL: 3.179541) ---
#     --> Found a better KL on this path: 2.476779 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.097021 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.908714 at depth 4 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.808127 at depth 5 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.612838 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.397727 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.348901 at depth 8 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.330290 at depth 9 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.225427 at depth 10 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.209468 at depth 11 with added CNOT (1, 4)
#     --> Found a better KL on this path: 1.123034 at depth 12 with added CNOT (4, 2)
#     --> Found a better KL on this path: 1.104756 at depth 13 with added CNOT (6, 4)
#   Epoch 16 best KL Sum: 1.104756
#   --> Epoch 16 found a new overall best KL Sum: 1.104756
#
# --- Starting Epoch 17/27 (Addition) with CNOT: (3, 2) (KL: 3.698885) ---
#     --> Found a better KL on this path: 3.085171 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.434021 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.117366 at depth 4 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.924254 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.763382 at depth 6 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.574960 at depth 7 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.456939 at depth 8 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.416964 at depth 9 with added CNOT (1, 2)
#     --> Found a better KL on this path: 1.363141 at depth 10 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.304346 at depth 11 with added CNOT (4, 0)
#   Epoch 17 best KL Sum: 1.304346
#
# --- Starting Epoch 18/27 (Addition) with CNOT: (4, 6) (KL: 3.718340) ---
#   Skipping epoch: Single CNOT KL (3.718340) does not improve over baseline (3.714777).
#
# --- Starting Epoch 19/27 (Addition) with CNOT: (6, 2) (KL: 3.696272) ---
#     --> Found a better KL on this path: 3.069979 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.491553 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.072253 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.902855 at depth 5 with added CNOT (6, 4)
#     --> Found a better KL on this path: 1.766147 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.647949 at depth 7 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.470343 at depth 8 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.375711 at depth 9 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.355044 at depth 10 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.302811 at depth 11 with added CNOT (1, 2)
#   Epoch 19 best KL Sum: 1.302811
#
# --- Starting Epoch 20/27 (Addition) with CNOT: (1, 4) (KL: 3.684347) ---
#     --> Found a better KL on this path: 3.091230 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.455713 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.075003 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.887662 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.762897 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.636827 at depth 7 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.460372 at depth 8 with added CNOT (2, 0)
#     --> Found a better KL on this path: 1.401822 at depth 9 with added CNOT (3, 2)
#     --> Found a better KL on this path: 1.371473 at depth 10 with added CNOT (4, 0)
#     --> Found a better KL on this path: 1.325281 at depth 11 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.281018 at depth 12 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.239582 at depth 13 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.238912 at depth 14 with added CNOT (6, 2)
#   Epoch 20 best KL Sum: 1.238912
#
# --- Starting Epoch 21/27 (Addition) with CNOT: (2, 6) (KL: 3.741943) ---
#   Skipping epoch: Single CNOT KL (3.741943) does not improve over baseline (3.714777).
#
# --- Starting Epoch 22/27 (Addition) with CNOT: (1, 6) (KL: 3.725166) ---
#   Skipping epoch: Single CNOT KL (3.725166) does not improve over baseline (3.714777).
#
# --- Starting Epoch 23/27 (Addition) with CNOT: (4, 1) (KL: 3.724266) ---
#   Skipping epoch: Single CNOT KL (3.724266) does not improve over baseline (3.714777).
#
# --- Starting Epoch 24/27 (Addition) with CNOT: (1, 2) (KL: 3.711863) ---
#     --> Found a better KL on this path: 3.107746 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.543789 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.116776 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.889315 at depth 5 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.751793 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.596095 at depth 7 with added CNOT (2, 1)
#     --> Found a better KL on this path: 1.476210 at depth 8 with added CNOT (1, 0)
#     --> Found a better KL on this path: 1.370099 at depth 9 with added CNOT (4, 6)
#   Epoch 24 best KL Sum: 1.370099
#
# --- Starting Epoch 25/27 (Addition) with CNOT: (1, 3) (KL: 3.717018) ---
#   Skipping epoch: Single CNOT KL (3.717018) does not improve over baseline (3.714777).
#
# --- Starting Epoch 26/27 (Addition) with CNOT: (6, 4) (KL: 3.680385) ---
#     --> Found a better KL on this path: 3.075424 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 2.464066 at depth 3 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.063757 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 1.932592 at depth 5 with added CNOT (1, 4)
#     --> Found a better KL on this path: 1.801947 at depth 6 with added CNOT (0, 3)
#     --> Found a better KL on this path: 1.678210 at depth 7 with added CNOT (2, 4)
#     --> Found a better KL on this path: 1.552362 at depth 8 with added CNOT (3, 1)
#     --> Found a better KL on this path: 1.412752 at depth 9 with added CNOT (6, 0)
#     --> Found a better KL on this path: 1.350875 at depth 10 with added CNOT (1, 2)
#   Epoch 26 best KL Sum: 1.350875
#
# --- Starting Epoch 27/27 (Addition) with CNOT: (2, 4) (KL: 3.724773) ---
#   Skipping epoch: Single CNOT KL (3.724773) does not improve over baseline (3.714777).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 13 CNOTs (KL Sum: 1.104756)
#   No CNOT removal improved the score. Stopping removal search.
#
# Final Result: Best sequence found has 12 CNOTs (KL: 1.172597).
#
# Total search took: 684.59 seconds.
#
# Result for (Rank 1): Final KL Sum = 1.172597
#   This result (1.172597) did not beat the current best (1.155992).
#
# ============================================================
# --- OVERALL BEST SOLUTION AFTER HYBRID SEARCH ---
# ============================================================
# The best solution originated from the VQE's result at Rank 3.
#
# Final optimal CNOT sequence found with 10 CNOTs:
#   q[2] -> q[1]
#   q[0] -> q[6]
#   q[0] -> q[2]
#   q[0] -> q[4]
#   q[6] -> q[1]
#   q[4] -> q[1]
#   q[6] -> q[0]
#   q[1] -> q[3]
#   q[4] -> q[6]
#   q[2] -> q[6]
#
# With a minimum combined KL Divergence of: 1.155992
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                     »
# «         q_0: ────────────────■──────────■─────────────────────■─────»
# «              ┌─────────┐     │          │     ┌─────────┐     │     »
# «         q_1: ┤ Rx(π/2) ├─────┼──────────┼─────┤ Rx(π/2) ├─────┼─────»
# «              └────┬────┘     │     ┌────┴────┐└────┬────┘     │     »
# «         q_2: ─────■──────────┼─────┤ Rx(π/2) ├─────┼──────────┼─────»
# «                              │     └─────────┘     │          │     »
# «         q_3: ────────────────┼─────────────────────┼──────────┼─────»
# «                              │                     │     ┌────┴────┐»
# «         q_4: ────────────────┼─────────────────────┼─────┤ Rx(π/2) ├»
# «                  ┌─┐         │                     │     └─────────┘»
# «         q_5: ────┤M├─────────┼─────────────────────┼────────────────»
# «                  └╥┘    ┌────┴────┐                │                »
# «         q_6: ─────╫─────┤ Rx(π/2) ├────────────────■────────────────»
# «                   ║     └─────────┘                                 »
# «c_measure1: 2/═════╬═════════════════════════════════════════════════»
# «                   ║                                                 »
# «c_measure2: 5/═════╩═════════════════════════════════════════════════»
# «                   3                                                 »
# «                         ┌─────────┐           ┌─┐
# «         q_0: ───────────┤ Rx(π/2) ├───────────┤M├──────────────────────────
# «              ┌─────────┐└────┬────┘           └╥┘           ┌─┐
# «         q_1: ┤ Rx(π/2) ├─────┼──────────■──────╫────────────┤M├────────────
# «              └────┬────┘     │          │      ║            └╥┘      ┌─┐
# «         q_2: ─────┼──────────┼──────────┼──────╫──────■──────╫───────┤M├───
# «                   │          │     ┌────┴────┐ ║      │      ║ ┌─┐   └╥┘
# «         q_3: ─────┼──────────┼─────┤ Rx(π/2) ├─╫──────┼──────╫─┤M├────╫────
# «                   │          │     └─────────┘ ║      │      ║ └╥┘┌─┐ ║
# «         q_4: ─────■──────────┼──────────■──────╫──────┼──────╫──╫─┤M├─╫────
# «                              │          │      ║      │      ║  ║ └╥┘ ║
# «         q_5: ────────────────┼──────────┼──────╫──────┼──────╫──╫──╫──╫────
# «                              │     ┌────┴────┐ ║ ┌────┴────┐ ║  ║  ║  ║ ┌─┐
# «         q_6: ────────────────■─────┤ Rx(π/2) ├─╫─┤ Rx(π/2) ├─╫──╫──╫──╫─┤M├
# «                                    └─────────┘ ║ └─────────┘ ║  ║  ║  ║ └╥┘
# «c_measure1: 2/══════════════════════════════════╩═════════════╩══╬══╬══╬══╬═
# «                                                0             1  ║  ║  ║  ║
# «c_measure2: 5/═══════════════════════════════════════════════════╩══╩══╩══╩═
# «                                                                 1  2  0  4
# ============================================================

# %%
# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_best_circuit_search, nshots=5000, title_prefix="VQE + Epoch search Optimized Circuit")
final_best_circuit_search
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=1.2)
# Out:
# --- Running circuit for: VQE + Epoch search Optimized Circuit ---
# Counts for c_measure1: {'00': 2424, '11': 867, '01': 1217, '10': 492}
# Counts for c_measure2: {'00000': 2605, '10010': 98, '00101': 173, '00111': 175, '10001': 410, '10110': 177, '10100': 278, '10000': 262, '10101': 228, '10111': 80, '00100': 138, '10011': 52, '00110': 58, '00001': 166, '00011': 50, '00010': 24, '11000': 3, '11100': 4, '01000': 12, '11010': 2, '11111': 1, '11001': 2, '01100': 1, '01101': 1}

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    best_cnot_sequence, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*1/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    best_cnot_sequence,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=1.2)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (10 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['1.7553', '2.7631', '1.5161', '1.4478', '1.5974', '1.5605', '1.4112', '1.4566', '2.5744', '1.5654']
# CRX Angle Optimization took: 25.10 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['1.7553', '2.7631', '1.5161', '1.4478', '1.5974', '1.5605', '1.4112', '1.4566', '2.5744', '1.5654']
#   Minimum Combined KL Divergence with Optimized CRX: 1.117821
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                                       ┌────────────────────────────────────────────────┐                                                                                        »
# «         q_0: ─────────────────────────────────────────────────────────────────────────────────────────┤0                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                       │  Initialize(0.67623,0.73246,0.050148,0.060785) │                                                                                        »
# «         q_1: ─────────────────────────────────────────────────────────────────────────────────────────┤1                                               ├────────────────────────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_3: ┤1                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_4: ┤2 Initialize(0.9802,0.079715,0.10038,0.0029524,0.06643,0.0029524,0.0059048,0,0.075287,0.0044286,0.01181,0,0.0014762,0,0,0,0.11072,0.0059048,0.0029524,0,0.0088573,0,0,0.0014762,0.0088573,0.0014762,0.0014762,0,0.0029524,0,0,0) ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_5: ┤3                                                                                                                                                                                                                                ├»
# «              │                                                                                                                                                                                                                                 │»
# «         q_6: ┤4                                                                                                                                                                                                                                ├»
# «              └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                                                                                 »
# «                                                                      »
# «         q_0: ────────────────────■─────────────■─────────────────────»
# «              ┌────────────┐      │             │       ┌────────────┐»
# «         q_1: ┤ Rx(1.7553) ├──────┼─────────────┼───────┤ Rx(1.5974) ├»
# «              └─────┬──────┘      │       ┌─────┴──────┐└─────┬──────┘»
# «         q_2: ──────■─────────────┼───────┤ Rx(1.5161) ├──────┼───────»
# «                                  │       └────────────┘      │       »
# «         q_3: ────────────────────┼───────────────────────────┼───────»
# «                                  │                           │       »
# «         q_4: ────────────────────┼───────────────────────────┼───────»
# «                   ┌─┐            │                           │       »
# «         q_5: ─────┤M├────────────┼───────────────────────────┼───────»
# «                   └╥┘      ┌─────┴──────┐                    │       »
# «         q_6: ──────╫───────┤ Rx(2.7631) ├────────────────────■───────»
# «                    ║       └────────────┘                            »
# «c_measure1: 2/══════╬═════════════════════════════════════════════════»
# «                    ║                                                 »
# «c_measure2: 5/══════╩═════════════════════════════════════════════════»
# «                    3                                                 »
# «                                          ┌────────────┐              ┌─┐»
# «         q_0: ──────■─────────────────────┤ Rx(1.4112) ├──────────────┤M├»
# «                    │       ┌────────────┐└─────┬──────┘              └╥┘»
# «         q_1: ──────┼───────┤ Rx(1.5605) ├──────┼─────────────■────────╫─»
# «                    │       └─────┬──────┘      │             │        ║ »
# «         q_2: ──────┼─────────────┼─────────────┼─────────────┼────────╫─»
# «                    │             │             │       ┌─────┴──────┐ ║ »
# «         q_3: ──────┼─────────────┼─────────────┼───────┤ Rx(1.4566) ├─╫─»
# «              ┌─────┴──────┐      │             │       └────────────┘ ║ »
# «         q_4: ┤ Rx(1.4478) ├──────■─────────────┼─────────────■────────╫─»
# «              └────────────┘                    │             │        ║ »
# «         q_5: ──────────────────────────────────┼─────────────┼────────╫─»
# «                                                │       ┌─────┴──────┐ ║ »
# «         q_6: ──────────────────────────────────■───────┤ Rx(2.5744) ├─╫─»
# «                                                        └────────────┘ ║ »
# «c_measure1: 2/═════════════════════════════════════════════════════════╩═»
# «                                                                       0 »
# «c_measure2: 5/═══════════════════════════════════════════════════════════»
# «                                                                         »
# «
# «         q_0: ─────────────────────────────
# «                            ┌─┐
# «         q_1: ──────────────┤M├────────────
# «                            └╥┘      ┌─┐
# «         q_2: ──────■────────╫───────┤M├───
# «                    │        ║ ┌─┐   └╥┘
# «         q_3: ──────┼────────╫─┤M├────╫────
# «                    │        ║ └╥┘┌─┐ ║
# «         q_4: ──────┼────────╫──╫─┤M├─╫────
# «                    │        ║  ║ └╥┘ ║
# «         q_5: ──────┼────────╫──╫──╫──╫────
# «              ┌─────┴──────┐ ║  ║  ║  ║ ┌─┐
# «         q_6: ┤ Rx(1.5654) ├─╫──╫──╫──╫─┤M├
# «              └────────────┘ ║  ║  ║  ║ └╥┘
# «c_measure1: 2/═══════════════╩══╬══╬══╬══╬═
# «                             1  ║  ║  ║  ║
# «c_measure2: 5/══════════════════╩══╩══╩══╩═
# «                                1  2  0  4
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'10': 756, '00': 2507, '11': 1171, '01': 566}
# Counts for c_measure2: {'00101': 261, '00000': 2244, '00100': 276, '10001': 322, '00111': 180, '10101': 47, '00110': 224, '00001': 265, '10000': 606, '10111': 39, '10100': 71, '00011': 95, '10010': 191, '10011': 88, '00010': 23, '01111': 3, '10110': 32, '01000': 14, '01010': 2, '11010': 3, '11000': 4, '01011': 2, '11011': 2, '01100': 3, '01110': 1, '01001': 2}

# %%
# ==============================================================================
# --- STAGE 1: RUN QAOA TO GET CANDIDATE SOLUTIONS ---
# ==============================================================================
# This is your existing QAOA setup code
import numpy as np
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.algorithms import (
    MinimumEigenOptimizer,
    OptimizationResultStatus,
    RecursiveMinimumEigenOptimizer,
    SolutionSample,
)
from qiskit_optimization.minimum_eigensolvers import QAOA, NumPyMinimumEigensolver
from qiskit_optimization.optimizers import COBYLA
from qiskit_optimization.utils import algorithm_globals
num_qubits = kl_div_mat_qubo.shape[0]
# --- 1. Define the Quadratic Program (QUBO) ---
qp = QuadraticProgram(name="CnotOptimization")
# Add binary variables: one for each CNOT candidate (0 to 41)
for i in range(num_qubits):
    qp.binary_var(name=f'x{i}')
qp.minimize(quadratic=kl_div_mat_qubo)
# kl_vec = np.diag(kl_div_mat_qubo).copy()
# np.fill_diagonal(kl_div_mat_qubo, 0.0)
#qp.minimize(quadratic=kl_div_mat_qubo, linear=kl_vec)
op, offset = qp.to_ising()
print("offset: {}".format(offset))
print(qp.prettyprint())
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import SamplerV2
algorithm_globals.random_seed = 10598
pass_manager = generate_preset_pass_manager(optimization_level=2, backend=AerSimulator())
qaoa_set = QAOA(
    sampler=SamplerV2(seed=123, default_shots=2000),
    optimizer=COBYLA(maxiter=200),
    initial_point=[1, 1],
    pass_manager=pass_manager,
    reps=1
)
meo_set = MinimumEigenOptimizer(qaoa_set)
qaoa_result = meo_set.solve(qp)
print(qaoa_result.prettyprint())
# Out:
# offset: -7.165314516138689
# Problem name: CnotOptimization
#
# Minimize
#   -0.4945236376537574*x0^2 - 0.05805039029928283*x0*x1
#   - 0.050978449571250195*x0*x10 - 0.011816167961912427*x0*x11
#   + 0.00040120581128810784*x0*x12 - 0.04486148915696431*x0*x13
#   - 0.026751687630166998*x0*x14 - 0.014262714495582252*x0*x15
#   - 0.015849707958895287*x0*x16 - 0.017786274767230825*x0*x17
#   - 0.028122900815187535*x0*x18 - 0.0029754831124182424*x0*x19
#   + 0.011078560961740092*x0*x2 - 0.005561204983755896*x0*x20
#   + 0.019667031756323006*x0*x21 - 0.08955445995444355*x0*x22
#   - 0.018171248309005517*x8*x28 - 0.022217105889999367*x8*x29
#   + 0.018577052041527153*x8^2 - 0.05531301927841614*x8*x9
#   - 0.07736264666638659*x9*x10 - 0.07763849110932242*x9*x11
#   - 0.006469294464729991*x9*x12 - 0.06576811495715917*x9*x13
#   - 0.059859068395989645*x9*x14 - 0.0639110692417213*x9*x15
#   - 0.07321349886048534*x9*x16 - 0.05424883795154045*x9*x17
#   - 0.03705011537973846*x9*x18 - 0.044404437198840796*x9*x19
#   - 0.049450698815765914*x9*x20 - 0.02666740885588048*x9*x21
#   - 0.08398662383430722*x9*x22 - 0.07603156214678508*x9*x23
#   - 0.06649335760873143*x9*x24 - 0.07812786263879046*x9*x25
#   - 0.02667087716442751*x9*x26 - 0.04485007174427569*x9*x27
#   + 0.01861591259269524*x9*x28 - 0.018118828731130243*x9*x29
#   + 0.021866468292537355*x9^2
#
# Subject to
#   No constraints
#
#   Binary variables (30)
#     x0 x1 x2 x3 x4 x5 x6 x7 x8 x9 x10 x11 x12 x13 x14 x15 x16 x17 x18 x19 x20
#     x21 x22 x23 x24 x25 x26 x27 x28 x29

# %%
# CORRECTED HELPER FUNCTION
from qiskit_optimization.algorithms import SolutionSample 
from typing import List, Dict

def convert_qaoa_samples_to_counts(
    samples: List[SolutionSample], 
    total_shots_equivalent: int = 10000
) -> Dict[str, int]:
    """
    Converts a list of QAOA SolutionSample objects into a VQE-style counts dictionary.

    This is necessary to use the QAOA results with functions designed for VQE/Sampler output.
    It preserves the relative probabilities of the solutions by converting them to integer counts.

    Args:
        samples (List[SolutionSample]): The list of samples from a Qiskit Optimization result.
        total_shots_equivalent (int): A scaling factor to convert probabilities into
                                      integer counts. The exact value doesn't matter as
                                      long as it preserves the order.

    Returns:
        Dict[str, int]: A dictionary where keys are big-endian bitstrings and values are
                        the corresponding "counts", compatible with the hybrid search function.
    """
    qaoa_counts = {}
    for s in samples:
        # QAOA sample.x is an array like [1., 0., 1.]. Convert to a string '101'.
        # We reverse it to create a big-endian string '101' -> ...x2x1x0, which is
        # a common Qiskit convention and consistent with our VQE helpers.
        bitstring = "".join(str(int(v)) for v in reversed(s.x))
        
        # Convert the solution's probability to an integer count
        count = int(s.probability * total_shots_equivalent)
        
        # Only add solutions with a non-zero chance
        if count > 0:
            qaoa_counts[bitstring] = count
            
    return qaoa_counts

# %%
# ==============================================================================
# --- STAGE 2: CONVERT QAOA RESULTS AND RUN HYBRID SEARCH ---
# ==============================================================================

# 1. Convert the QAOA samples list into a VQE-style counts dictionary
qaoa_counts = convert_qaoa_samples_to_counts(qaoa_result.samples)
print(f"\nConverted QAOA results into a counts dictionary with {len(qaoa_counts)} entries.")

# 2. Call the main hybrid search function, using the QAOA counts as input
best_cnot_sequence, min_kl_sum, best_solution_rank = run_vqe_hybrid_search(
    vqe_counts=qaoa_counts,  # <-- Using the converted QAOA results here!
    initial_cnot_config=initial_cnot_config,
    circ1=circ1,
    circ2=circ2,
    state_probs_initial1=normalized_joint_counts_ct1_mo,
    state_probs_initial2=normalized_joint_counts_ct2_mo,
    state_vec_probs_target1=normalized_joint_counts_ct1_co,
    state_vec_probs_target2=normalized_joint_counts_ct2_co,
    num_solutions_to_test=3,  # We will test the top 3 solutions from QAOA
    nshots=5000,
    threshold=thresh,
    kl_tol=0.1,
    ratio_kl_tol=0.6,
    max_greedy_depth=30,
    min_cnot_depth=1 # You can adjust this as needed
)

# ==============================================================================
# --- STAGE 3: DISPLAY THE FINAL, OVERALL BEST SOLUTION ---
# ==============================================================================
print("\n" + "="*60)
print("--- OVERALL BEST SOLUTION AFTER QAOA + HYBRID SEARCH ---")
print("="*60)

if best_solution_rank is not None:
    print(f"The best solution originated from the QAOA's result at Rank {best_solution_rank}.")
    print(f"\nFinal optimal CNOT sequence found with {len(best_cnot_sequence)} CNOTs:")
    if best_cnot_sequence:
        for cnot in best_cnot_sequence:
            print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    else:
        print("  (The best solution found was to use no CNOTs)")

    print(f"\nWith a minimum combined KL Divergence of: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("No QAOA solution led to a greedy search result that improved upon the initial baseline.")
    print("The best configuration is the baseline circuit with no CNOTs.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))

print("="*60 + "\n")
# Out:
# Converted QAOA results into a counts dictionary with 50 entries.
# ============================================================
# --- Preparing to test Top 3 VQE solutions in REVERSE order ---
# ============================================================
#
# --- Testing VQE Solution (Rank 3/3) ---
# This VQE Solution corresponds to a candidate subset of 4 CNOTs:
#   q[0] -> q[3]
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 4 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 4
# Initial KL divergence (baseline): 4.789146
#
# --- Starting Epoch 1/4 (Addition) with CNOT: (0, 3) (KL: 4.819736) ---
#   Skipping epoch: Single CNOT KL (4.819736) does not improve over baseline (4.789146).
#
# --- Starting Epoch 2/4 (Addition) with CNOT: (3, 6) (KL: 4.847292) ---
#   Skipping epoch: Single CNOT KL (4.847292) does not improve over baseline (4.789146).
#
# --- Starting Epoch 3/4 (Addition) with CNOT: (3, 4) (KL: 4.292987) ---
#     --> Found a better KL on this path: 2.183854 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.062435 at depth 3 with added CNOT (3, 0)
#   Epoch 3 best KL Sum: 1.062435
#   --> Epoch 3 found a new overall best KL Sum: 1.062435
#
# --- Starting Epoch 4/4 (Addition) with CNOT: (3, 0) (KL: 3.740064) ---
#     --> Found a better KL on this path: 3.281870 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.120152 at depth 3 with added CNOT (3, 6)
#   Epoch 4 best KL Sum: 1.120152
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.062435)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 3.52 seconds.
#
# Result for (Rank 3): Final KL Sum = 1.062435
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.062435
#   Origin: VQE solution at rank 3
#
# --- Testing VQE Solution (Rank 2/3) ---
# This VQE Solution corresponds to a candidate subset of 3 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 3 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 3
# Initial KL divergence (baseline): 4.820033
#
# --- Starting Epoch 1/3 (Addition) with CNOT: (3, 4) (KL: 4.295982) ---
#     --> Found a better KL on this path: 2.135486 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.128085 at depth 3 with added CNOT (3, 0)
#   Epoch 1 best KL Sum: 1.128085
#   --> Epoch 1 found a new overall best KL Sum: 1.128085
#
# --- Starting Epoch 2/3 (Addition) with CNOT: (3, 6) (KL: 4.852074) ---
#   Skipping epoch: Single CNOT KL (4.852074) does not improve over baseline (4.820033).
#
# --- Starting Epoch 3/3 (Addition) with CNOT: (3, 0) (KL: 3.660631) ---
#     --> Found a better KL on this path: 3.326624 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.097431 at depth 3 with added CNOT (3, 6)
#   Epoch 3 best KL Sum: 1.097431
#   --> Epoch 3 found a new overall best KL Sum: 1.097431
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.097431)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 2.23 seconds.
#
# Result for (Rank 2): Final KL Sum = 1.097431
#   This result (1.097431) did not beat the current best (1.062435).
#
# --- Testing VQE Solution (Rank 1/3) ---
# This VQE Solution corresponds to a candidate subset of 4 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[6] -> q[3]
#
# Setting number of greedy search epochs to 4 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 4
# Initial KL divergence (baseline): 4.726786
#
# --- Starting Epoch 1/4 (Addition) with CNOT: (3, 4) (KL: 4.344885) ---
#     --> Found a better KL on this path: 2.123228 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.100594 at depth 3 with added CNOT (3, 0)
#   Epoch 1 best KL Sum: 1.100594
#   --> Epoch 1 found a new overall best KL Sum: 1.100594
#
# --- Starting Epoch 2/4 (Addition) with CNOT: (3, 0) (KL: 3.672662) ---
#     --> Found a better KL on this path: 3.273173 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.009368 at depth 3 with added CNOT (3, 6)
#   Epoch 2 best KL Sum: 1.009368
#   --> Epoch 2 found a new overall best KL Sum: 1.009368
#
# --- Starting Epoch 3/4 (Addition) with CNOT: (3, 6) (KL: 4.900948) ---
#   Skipping epoch: Single CNOT KL (4.900948) does not improve over baseline (4.726786).
#
# --- Starting Epoch 4/4 (Addition) with CNOT: (6, 3) (KL: 4.797861) ---
#   Skipping epoch: Single CNOT KL (4.797861) does not improve over baseline (4.726786).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.009368)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 3.56 seconds.
#
# Result for (Rank 1): Final KL Sum = 1.009368
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.009368
#   Origin: VQE solution at rank 1
#
# ============================================================
# --- OVERALL BEST SOLUTION AFTER QAOA + HYBRID SEARCH ---
# ============================================================
# The best solution originated from the QAOA's result at Rank 1.
#
# Final optimal CNOT sequence found with 3 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# With a minimum combined KL Divergence of: 1.009368
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 4/»
#               »
# c_measure2: 3/»
#               »
# «              ┌──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_0: ┤0                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_1: ┤1                                                                                                                                                     ├»
# «              │  Initialize(0.22375,0.014855,0.021354,0,0.020425,0.00092842,0.067775,0.0064989,0.91357,0.0882,0.083558,0.0046421,0.075202,0.011141,0.29709,0.027853) │»
# «         q_2: ┤2                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_3: ┤3                                                                                                                                                     ├»
# «              └────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────┘»
# «         q_4: ─────────────────────────────────────┤0                                                                           ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_5: ─────────────────────────────────────┤1 Initialize(0.97212,0.085592,0.19832,0.022268,0.086287,0.01183,0.015309,0) ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_6: ─────────────────────────────────────┤2                                                                           ├─────────────────────────────────────»
# «                                                   └────────────────────────────────────────────────────────────────────────────┘                                     »
# «c_measure1: 4/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «c_measure2: 3/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «              ┌───┐           ┌─┐
# «         q_0: ┤ X ├───────────┤M├──────────────
# «              └─┬─┘┌─┐        └╥┘
# «         q_1: ──┼──┤M├─────────╫───────────────
# «                │  └╥┘┌─┐      ║
# «         q_2: ──┼───╫─┤M├──────╫───────────────
# «                │   ║ └╥┘      ║         ┌─┐
# «         q_3: ──■───╫──╫───■───╫───■─────┤M├───
# «                    ║  ║ ┌─┴─┐ ║   │  ┌─┐└╥┘
# «         q_4: ──────╫──╫─┤ X ├─╫───┼──┤M├─╫────
# «               ┌─┐  ║  ║ └───┘ ║   │  └╥┘ ║
# «         q_5: ─┤M├──╫──╫───────╫───┼───╫──╫────
# «               └╥┘  ║  ║       ║ ┌─┴─┐ ║  ║ ┌─┐
# «         q_6: ──╫───╫──╫───────╫─┤ X ├─╫──╫─┤M├
# «                ║   ║  ║       ║ └───┘ ║  ║ └╥┘
# «c_measure1: 4/══╬═══╩══╩═══════╩═══════╬══╩══╬═
# «                ║   1  2       0       ║  3  ║
# «c_measure2: 3/══╩══════════════════════╩═════╩═
# «                1                      0     2
# ============================================================

# %%
# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_best_circuit_search, nshots=5000, title_prefix="VQE + Epoch search Optimized Circuit")
final_best_circuit_search
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.5)
# Out:
# --- Running circuit for: VQE + Epoch search Optimized Circuit ---
# Counts for c_measure1: {'1001': 4227, '1000': 35, '1111': 413, '0000': 236, '0110': 23, '1011': 41, '1101': 19, '1110': 2, '0001': 2, '0100': 2}
# Counts for c_measure2: {'101': 4496, '000': 245, '111': 177, '100': 41, '001': 28, '010': 11, '011': 1, '110': 1}
