# %%
import numpy as np
import pandas as pd
import scanpy as sc 

np.random.seed(42)

adata = sc.read_h5ad("sim_cells_datasets_co_mo_simulated_classical.h5ad")
# Data prep
#sc.pp.normalize_total(adata, target_sum=1e4) # You can adjust target_sum # Seems not to help
#sc.pp.log1p(adata)
adata.X = adata.layers['counts']
adata
# Out:
# AnnData object with n_obs × n_vars = 4000 × 120
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pp.normalize_total(adata, target_sum=1e4) # You can adjust target_sum # Seems not to help
sc.pp.log1p(adata)
#sc.experimental.pp.normalize_pearson_residuals(adata, theta=100, clip=True, inplace=True)

# %%
# Manual Targeted Setup
# We want to trace the flow:
# A (50) -> B (60 -> 70 -> 71, 72, 80) -> A (80 -> 90)

# Sources: The genes initiating signals or regulation
# The "Cause" List
gl_source = [
    "Gene_50", # Source from A 
    "Gene_90"  # Target in A (Spatial Feedback)
]

# The "Effect" List
gl_recv = [
    "Gene_60", # Target in B (Spatial)
    "Gene_70", # GRN in B (Internal)
    "Gene_71", # GRN in B (Internal)
    "Gene_72", # GRN in B (Internal)
    "Gene_80", # Soruce in B
]

# %%
adata.obs['cell_type'].unique()
# Out:
# ['Type_A_Interact', 'Type_B_Lone', 'Type_A_Lone', 'Type_B_Interact']
# Categories (4, object): ['Type_A_Interact', 'Type_A_Lone', 'Type_B_Interact', 'Type_B_Lone']

# %%
# This case we have 120 genes, but want to identify the functional ones!
from scipy.sparse import issparse

ict1 = (adata.obs["cell_type"] == 'Type_A_Interact') 
ict2 = (adata.obs["cell_type"] == 'Type_B_Interact') 

adata_ct1_co = adata[ict1, gl_source].copy()
adata_ct2_co = adata[ict2, gl_recv].copy()
#adata_ct1_co = sc.external.pp.magic(adata_ct1_co, name_list=gl_source, knn=5, random_state=42)
#adata_ct2_co = sc.external.pp.magic(adata_ct2_co, name_list=gl_recv, knn=5, random_state=42)

print(adata_ct1_co)
print(adata_ct2_co)

if issparse(adata_ct1_co.X):
    Xct1_co = adata_ct1_co.X.toarray()
else:
    Xct1_co = adata_ct1_co.X

if issparse(adata_ct2_co.X):
    Xct2_co = adata_ct2_co.X.toarray()
else:
    Xct2_co = adata_ct2_co.X

# Assuming Xct1_co and Xct2 are your log-transformed expression matrices
Xct1means = np.mean(Xct1_co, axis=0) *1
Xct2means = np.mean(Xct2_co, axis=0) *1
print("CT1 (Co) mean expression:", Xct1means)
print("CT2 (Co) mean expression:", Xct2means)

# Binarize Xct1
Xct1_binary_co = (Xct1_co > Xct1means).astype(int)
# Binarize Xct2
Xct2_binary_co = (Xct2_co > Xct2means).astype(int)
# Out:
# AnnData object with n_obs × n_vars = 1000 × 2
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap', 'pearson_residuals_normalization'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# AnnData object with n_obs × n_vars = 1000 × 5
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap', 'pearson_residuals_normalization'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# CT1 (Co) mean expression: [-0.13926303  0.13488254]
# CT2 (Co) mean expression: [ 0.07939395 -0.05493112 -0.0992057  -0.29390237 -0.09555728]

# %%
adata.obs['cell_type'].unique()
# Out:
# ['Type_A_Interact', 'Type_B_Lone', 'Type_A_Lone', 'Type_B_Interact']
# Categories (4, object): ['Type_A_Interact', 'Type_A_Lone', 'Type_B_Interact', 'Type_B_Lone']

# %%
ict1 = (adata.obs["cell_type"] == 'Type_A_Lone')
ict2 = (adata.obs["cell_type"] == 'Type_B_Lone') 

adata_ct1_mo = adata[ict1, gl_source]
adata_ct2_mo = adata[ict2, gl_recv]
#adata_ct1_mo = sc.external.pp.magic(adata_ct1_mo, name_list=gl_source, knn=5, random_state=42)
#adata_ct2_mo = sc.external.pp.magic(adata_ct2_mo, name_list=gl_recv, knn=5, random_state=42)

print(adata_ct1_mo)
print(adata_ct2_mo)

if issparse(adata_ct1_mo.X):
    Xct1_mo = adata_ct1_mo.X.toarray()
else:
    Xct1_mo = adata_ct1_mo.X

if issparse(adata_ct2_mo.X):
    Xct2_mo = adata_ct2_mo.X.toarray()
else:
    Xct2_mo = adata_ct2_mo.X

# Utilize the mono cultured means here
# Binarize Xct1
Xct1_binary_mo = (Xct1_mo > Xct1means).astype(int)
# Binarize Xct2
Xct2_binary_mo = (Xct2_mo > Xct2means).astype(int)
# Out:
# View of AnnData object with n_obs × n_vars = 1000 × 2
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap', 'pearson_residuals_normalization'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 1000 × 5
#     obs: 'cell_type'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap', 'pearson_residuals_normalization'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
import sys
import os

# Replace with your actual path
cc_grn_functions_path = r"C:\Users\ssromerogon\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions"
#cc_grn_functions_path = r"C:\Users\selim\Documents\vs_working_dir\QuantumXCT\python\cc_grn_functions"
sys.path.append(cc_grn_functions_path)

from histogram_functions import create_joint_histogram, plot_joint_histogram, create_percent_joint_histogram, count_boolean_vector_occurrences

# %%
joint_counts_ct1_co, bit_strings_ct1_co = create_joint_histogram(Xct1_binary_co)
#joint_counts_ct1_co, bit_strings_ct1_co = create_percent_joint_histogram(Xct1_binary_co)

num_qubits = Xct1_binary_co.shape[1] 
plot_joint_histogram(joint_counts_ct1_co, num_qubits = num_qubits, figsize = (5,4), title='Data Joint Histogram Co-CT1' )  # Pass num_qubits
#plot_joint_histogram(histogram_data, figsize=(5,4), filename = 'hist_cc_3_4pi.svg', title= r'Histogram $Ry(3\pi/4)$' )

print("Joint Counts:", joint_counts_ct1_co)
print("Bit Strings:", bit_strings_ct1_co)
# Out:
# Joint Counts: Counter({'10': 424, '01': 220, '00': 213, '11': 143})
# Bit Strings: ['00', '01', '10', '11']

# %%
joint_counts_ct1_mo, bit_strings_ct1_mo = create_joint_histogram(Xct1_binary_mo)
#joint_counts_ct1_mo, bit_strings_ct1_mo = create_percent_joint_histogram(Xct1_binary_mo)

num_qubits = Xct1_binary_mo.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct1_mo, num_qubits = num_qubits, features=gl_source, figsize = (5,4), filename = 'joint_counts_mo_ct1.svg', title='Data Joint Histogram Mo-CT1' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct1_mo)
print("Bit Strings:", bit_strings_ct1_mo)
# Out:
# Joint Counts: Counter({'01': 522, '00': 478})
# Bit Strings: ['00', '01']

# %%
joint_counts_ct2_co, bit_strings_ct2_co = create_joint_histogram(Xct2_binary_co)
#joint_counts_ct2_co, bit_strings_ct2_co = create_percent_joint_histogram(Xct2_binary_co)

num_qubits2 = Xct2_binary_co.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct2_co, num_qubits = num_qubits2, features=gl_recv, figsize = (5,4), filename = 'joint_counts_co_ct2.svg', title='Data Joint Histogram Co-CT2' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct2_co)
print("Bit Strings:", bit_strings_ct2_co)
# Out:
# Joint Counts: Counter({'00001': 166, '11000': 84, '11100': 69, '01000': 64, '01100': 62, '00011': 56, '11010': 52, '10001': 52, '00101': 48, '01110': 47, '11110': 38, '01001': 30, '10101': 28, '00111': 28, '01010': 27, '10011': 23, '11001': 20, '01011': 16, '01101': 16, '11101': 14, '01111': 13, '11111': 10, '10111': 9, '11011': 8, '10100': 7, '10010': 5, '10110': 5, '10000': 3})
# Bit Strings: ['00001', '00011', '00101', '00111', '01000', '01001', '01010', '01011', '01100', '01101', '01110', '01111', '10000', '10001', '10010', '10011', '10100', '10101', '10110', '10111', '11000', '11001', '11010', '11011', '11100', '11101', '11110', '11111']

# %%
joint_counts_ct2_mo, bit_strings_ct2_mo = create_joint_histogram(Xct2_binary_mo)
#joint_counts_ct2_mo, bit_strings_ct2_mo = create_percent_joint_histogram(Xct2_binary_mo)

num_qubits2 = Xct2_binary_mo.shape[1]  # Get the number of qubits (important!)
plot_joint_histogram(joint_counts_ct2_mo, num_qubits = num_qubits2, features=gl_recv, figsize = (5,4), filename = 'joint_counts_mo_ct2.svg', title='Data Joint Histogram Mo-CT2' )  # Pass num_qubits

print("Joint Counts:", joint_counts_ct2_mo)
print("Bit Strings:", bit_strings_ct2_mo)
# Out:
# Joint Counts: Counter({'01000': 772, '11000': 86, '01010': 78, '01100': 48, '11100': 8, '01110': 4, '11010': 3, '11110': 1})
# Bit Strings: ['01000', '01010', '01100', '01110', '11000', '11010', '11100', '11110']

# %%
from quantum_functions import vector_normalize_dictionary_values, create_initial_circuit2

import numpy as np
# --- Apply and Print ---
print("--- New Dictionary Definitions ---")
print("State Set CT1 MO:", joint_counts_ct1_mo)
print("State Set CT2 MO:", joint_counts_ct2_mo)
print("Interacted State Set CT1 CO:", joint_counts_ct1_co)
print("Interacted State Set CT2 CO:", joint_counts_ct2_co)

# Apply vector normalization to the new dictionaries
normalized_joint_counts_ct1_mo = vector_normalize_dictionary_values(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = vector_normalize_dictionary_values(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = vector_normalize_dictionary_values(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = vector_normalize_dictionary_values(joint_counts_ct2_co)

print("\n--- Vector Normalized Dictionary Definitions ---")
print("Normalized State Set CT1 Mo (Vector Norm):", normalized_joint_counts_ct1_mo)
print("Normalized State Set CT2 Mo (Vector Norm):", normalized_joint_counts_ct2_mo)
print("Normalized Interacted State Set CT1 Co (Vector Norm):", normalized_joint_counts_ct1_co)
print("Normalized Interacted State Set CT2 Co (Vector Norm):", normalized_joint_counts_ct2_co)
# 1. Define initial circuits for concatenation
circ1 = create_initial_circuit2(normalized_joint_counts_ct1_mo)
circ2 = create_initial_circuit2(normalized_joint_counts_ct2_mo)
# Out:
# --- New Dictionary Definitions ---
# State Set CT1 MO: Counter({'01': 522, '00': 478})
# State Set CT2 MO: Counter({'01000': 772, '11000': 86, '01010': 78, '01100': 48, '11100': 8, '01110': 4, '11010': 3, '11110': 1})
# Interacted State Set CT1 CO: Counter({'10': 424, '01': 220, '00': 213, '11': 143})
# Interacted State Set CT2 CO: Counter({'00001': 166, '11000': 84, '11100': 69, '01000': 64, '01100': 62, '00011': 56, '11010': 52, '10001': 52, '00101': 48, '01110': 47, '11110': 38, '01001': 30, '10101': 28, '00111': 28, '01010': 27, '10011': 23, '11001': 20, '01011': 16, '01101': 16, '11101': 14, '01111': 13, '11111': 10, '10111': 9, '11011': 8, '10100': 7, '10010': 5, '10110': 5, '10000': 3})
#
# --- Vector Normalized Dictionary Definitions ---
# Normalized State Set CT1 Mo (Vector Norm): {'01': 0.7375059190254428, '00': 0.6753406691459036}
# Normalized State Set CT2 Mo (Vector Norm): {'01000': 0.9869427905576192, '11100': 0.010227386430648903, '11000': 0.10994440412947572, '01010': 0.09971701769882682, '01100': 0.06136431858389343, '11010': 0.0038352699114933392, '11110': 0.001278423303831113, '01110': 0.005113693215324452}
# Normalized Interacted State Set CT1 Co (Vector Norm): {'00': 0.3928351765151277, '10': 0.7819817598235407, '11': 0.26373441428010924, '01': 0.4057452527386296}
# Normalized Interacted State Set CT2 Co (Vector Norm): {'11100': 0.26623271226326256, '01011': 0.06173512168423479, '11010': 0.20063914547376308, '11000': 0.32410938884223267, '01000': 0.24694048673693916, '00001': 0.640501887473936, '10101': 0.10803646294741089, '10001': 0.20063914547376308, '00011': 0.21607292589482177, '01001': 0.11575335315794023, '00101': 0.18520536505270438, '01100': 0.23922359652640982, '01111': 0.05015978636844077, '11111': 0.03858445105264675, '11001': 0.0771689021052935, '10100': 0.02700911573685272, '11110': 0.14662091400005764, '10010': 0.019292225526323373, '01101': 0.06173512168423479, '10011': 0.08874423742108752, '01110': 0.1813469199474397, '10111': 0.03472600594738207, '01010': 0.10417801784214621, '10110': 0.019292225526323373, '11011': 0.030867560842117395, '10000': 0.011575335315794024, '11101': 0.05401823147370544, '00111': 0.10803646294741089}

# %%
from quantum_functions import concatenate_circuits_with_separate_measurements, add_cnots_and_measurements_to_circuit, score_circuit_kl_divergences

def test_specific_topology(
    circ1, 
    circ2, 
    cnot_topology, 
    state_vec_probs_target1, 
    state_vec_probs_target2, 
    nshots=5000
):
    """
    Manually injects a specific CNOT topology and evaluates the KL divergence.
    """
    ng_circ1 = circ1.num_qubits
    
    # 1. Concatenate the two base circuits
    base_combined = concatenate_circuits_with_separate_measurements(circ1, circ2)
    
    # 2. Add your specific CNOTs and the measurement gates
    # Note: Using your existing 'add_cnots_and_measurements_to_circuit'
    circuit_to_test = add_cnots_and_measurements_to_circuit(
        base_combined, 
        ng_circ1, 
        cnot_topology
    )
    
    # 3. Score it
    kl_div1, kl_div2 = score_circuit_kl_divergences(
        circuit_to_test,
        state_vec_probs_target1,
        state_vec_probs_target2,
        nshots
    )
    
    total_kl = kl_div1 + kl_div2 if kl_div1 is not None and kl_div2 is not None else float('inf')
    
    print(f"\n--- Topology Test Results ---")
    print(f"CNOTs applied: {cnot_topology}")
    print(f"KL Div (Circ 1): {kl_div1:.6f}")
    print(f"KL Div (Circ 2): {kl_div2:.6f}")
    print(f"Total Combined KL: {total_kl:.6f}")
    
    return circuit_to_test, total_kl


# Define your "Ground Truth" or "Expected" topology
#my_expected_topology = [(0, 2), (2, 3), (3, 4), (3, 5), (3, 6), (6, 1)] 
#my_expected_topology = [(0, 2), (2, 3), (3, 6), (6, 1)] 
my_expected_topology = [(0, 2), (2, 3), (3, 4), (3, 6), (6, 1)]
# Run the test
final_circ, score = test_specific_topology(
    circ1, 
    circ2, 
    my_expected_topology,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co
)

final_circ.draw(output="mpl", style="clifford", fold=40, scale=0.5, #filename="cnot_optimized_circuit_classi.svg"
                               )
# Out:
# --- Topology Test Results ---
# CNOTs applied: [(0, 2), (2, 3), (3, 4), (3, 6), (6, 1)]
# KL Div (Circ 1): 1.492690
# KL Div (Circ 2): 3.967417
# Total Combined KL: 5.460108

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_circ, nshots=5000, 
                            title_prefix="CNOT Optimized Circuit", figsize=(8,4.5), 
                            #figure_save_name = "cnot_optimized_circuit_histograms.svg" 
                            )
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'11': 2174, '00': 2783, '01': 16, '10': 27}
# Counts for c_measure2: {'11111': 2174, '01000': 2782, '01001': 16, '11110': 27, '01100': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
#plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    my_expected_topology, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*0/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    my_expected_topology,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=0.7)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (5 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['3.1416', '0.0000', '2.0230', '0.1250', '-0.0000']
# CRX Angle Optimization took: 16.90 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['3.1416', '0.0000', '2.0230', '0.1250', '-0.0000']
#   Minimum Combined KL Divergence with Optimized CRX: 2.249348
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                   ┌──────────────────────────────────┐                                                                     »
# «         q_0: ─────────────────────────────────────────────────────────────────────┤0                                 ├─────────────────────────────────────────────────────────────────────»
# «                                                                                   │  Initialize(0.67534,0.73751,0,0) │                                                                     »
# «         q_1: ─────────────────────────────────────────────────────────────────────┤1                                 ├─────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────┴──────────────────────────────────┴────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_3: ┤1                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_4: ┤2 Initialize(0.98441,0,0.095973,0,0.064439,0,0.0054842,0,0.074036,0,0.012339,0,0.001371,0,0,0,0.10831,0,0.0027421,0,0.0082263,0,0.001371,0,0.0095973,0,0,0,0.0027421,0,0,0) ├»
# «              │                                                                                                                                                                            │»
# «         q_5: ┤3                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_6: ┤4                                                                                                                                                                           ├»
# «              └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «c_measure2: 5/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «                                ┌─┐                                         »
# «         q_0: ────■─────────────┤M├─────────────────────────────────────────»
# «                  │             └╥┘                                ┌───────┐»
# «         q_1: ────┼──────────────╫─────────────────────────────────┤ Rx(0) ├»
# «              ┌───┴───┐          ║              ┌─┐                └───┬───┘»
# «         q_2: ┤ Rx(π) ├────■─────╫──────────────┤M├────────────────────┼────»
# «              └───────┘┌───┴───┐ ║              └╥┘                    │    »
# «         q_3: ─────────┤ Rx(0) ├─╫───────■───────╫───────■─────────────┼────»
# «                       └───────┘ ║ ┌─────┴─────┐ ║       │      ┌─┐    │    »
# «         q_4: ───────────────────╫─┤ Rx(2.023) ├─╫───────┼──────┤M├────┼────»
# «                 ┌─┐             ║ └───────────┘ ║       │      └╥┘    │    »
# «         q_5: ───┤M├─────────────╫───────────────╫───────┼───────╫─────┼────»
# «                 └╥┘             ║               ║ ┌─────┴─────┐ ║     │    »
# «         q_6: ────╫──────────────╫───────────────╫─┤ Rx(0.125) ├─╫─────■────»
# «                  ║              ║               ║ └───────────┘ ║          »
# «c_measure1: 2/════╬══════════════╩═══════════════╬═══════════════╬══════════»
# «                  ║              0               ║               ║          »
# «c_measure2: 5/════╩══════════════════════════════╩═══════════════╩══════════»
# «                  3                              0               2          »
# «
# «         q_0: ─────────
# «                 ┌─┐
# «         q_1: ───┤M├───
# «                 └╥┘
# «         q_2: ────╫────
# «              ┌─┐ ║
# «         q_3: ┤M├─╫────
# «              └╥┘ ║
# «         q_4: ─╫──╫────
# «               ║  ║
# «         q_5: ─╫──╫────
# «               ║  ║ ┌─┐
# «         q_6: ─╫──╫─┤M├
# «               ║  ║ └╥┘
# «c_measure1: 2/═╬══╩══╬═
# «               ║  1  ║
# «c_measure2: 5/═╩═════╩═
# «               1     4
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'01': 2682, '00': 2318}
# Counts for c_measure2: {'00001': 2589, '00000': 2255, '00101': 14, '01000': 4, '00111': 29, '10001': 31, '10000': 30, '01001': 13, '00010': 5, '00100': 13, '11000': 1, '01110': 1, '00110': 9, '00011': 6}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
#plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import find_cnot_candidates_from_state_diff
thresh = 0.01
# --- State and Density Matrix Analysis ---
initial_cnot_config, stats = find_cnot_candidates_from_state_diff(
    normalized_joint_counts_ct1_mo, normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co, normalized_joint_counts_ct2_co,
    threshold = thresh, search_mode="pos", show_plot = True, verbose_print = True)

print(stats)
# Out:
# --- CNOT Candidate Analysis Summary ---
# System has 7 qubits.
# Total possible CNOTs (brute-force): 42
# Number of refined CNOT candidates found: 30
# ---------------------------------------
#
# {'max_element': 0.2920573689032295, 'min_element': -0.5196328426438541, 'abs_average': 0.0024755275515270228, 'relevant_avg': 0.008127056272191248}

# %%
from quantum_functions import find_best_cnot_sequence_iterative_n_wise, concatenate_circuits_with_separate_measurements, add_cnots_and_measurements_to_circuit

np.random.seed(42) 

print("\n" + "="*40)
print("--- Running N-wise Search ---")
print("="*40)

# Single insertion can be insertion or deletation of CX (something failing with the update criteria)
all_possible_single_cnots, best_cnot_sequence, min_kl_sum = find_best_cnot_sequence_iterative_n_wise(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    nshots=5000,
    threshold=thresh,
    search_mode="pos",
    nchoose=2,
    kl_tol = 0.1, 
    ratio_kl_tol = 0.6
)

print("\n" + "="*40)
if best_cnot_sequence:
    print(f"Multi-Epoch Search Optimal CNOT sequence found:")
    for cnot in best_cnot_sequence:
        print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    print(f"With minimum combined KL Divergence: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("Multi-Epoch Search: No sequence improved the KL divergence beyond the baseline.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))
print("="*40 + "\n")
# Out:
# ========================================
# --- Running N-wise Search ---
# ========================================
#
# --- Starting Iterative Pairwise Search ---
# --- CNOT Candidate Analysis Summary ---
# System has 7 qubits.
# Total possible CNOTs (brute-force): 42
# Number of refined CNOT candidates found: 30
# ---------------------------------------
#
# Number of initial CNOT candidates: 30
# Initial KL-divergence: 4.145448
#
#   - Starting Efficiency-Optimized Search -
#
# --- Iteration 1 | Current KL: 4.179135 ---
#    - Single Insertion Phase: Added (0, 2) at index 0. New KL: 2.194235
#   [Phase 1] Added Single: (0, 2) | New KL: 2.194235
#   [Phase 2] Added Pair: ((0, 1), (1, 0)) | New KL: 1.548682
#
# --- Iteration 2 | Current KL: 1.548682 ---
#    - Single Insertion Phase: Added (0, 6) at index 3. New KL: 1.441542
#   [Phase 1] Added Single: (0, 6) | New KL: 1.441542
#
# --- Iteration 3 | Current KL: 1.441542 ---
#    - Deletion Phase: Best Removed (0, 6). New KL: 1.483686
#   - No improvements in any phase. Search Terminated.
#
# --- Total Search Time: 514.41s ---
#
# --- Pairwise Addition Result ---
# Best sequence after addition: [(0, 2), (0, 1), (1, 0), (0, 6)]
# KL sum after addition: 1.441542
#
# Total search time: 514.76 seconds.
#
# ========================================
# Multi-Epoch Search Optimal CNOT sequence found:
#   q[0] -> q[2]
#   q[0] -> q[1]
#   q[1] -> q[0]
#   q[0] -> q[6]
# With minimum combined KL Divergence: 1.441542
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                   ┌──────────────────────────────────┐                                                                     »
# «         q_0: ─────────────────────────────────────────────────────────────────────┤0                                 ├─────────────────────────────────────────────────────────────────────»
# «                                                                                   │  Initialize(0.67534,0.73751,0,0) │                                                                     »
# «         q_1: ─────────────────────────────────────────────────────────────────────┤1                                 ├─────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────┴──────────────────────────────────┴────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_3: ┤1                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_4: ┤2 Initialize(0.98441,0,0.095973,0,0.064439,0,0.0054842,0,0.074036,0,0.012339,0,0.001371,0,0,0,0.10831,0,0.0027421,0,0.0082263,0,0.001371,0,0.0095973,0,0,0,0.0027421,0,0,0) ├»
# «              │                                                                                                                                                                            │»
# «         q_5: ┤3                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_6: ┤4                                                                                                                                                                           ├»
# «              └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «c_measure2: 5/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «                        ┌───┐           ┌─┐
# «         q_0: ──■────■──┤ X ├─────■─────┤M├───
# «                │  ┌─┴─┐└─┬─┘     │  ┌─┐└╥┘
# «         q_1: ──┼──┤ X ├──■───────┼──┤M├─╫────
# «              ┌─┴─┐└───┘     ┌─┐  │  └╥┘ ║
# «         q_2: ┤ X ├──────────┤M├──┼───╫──╫────
# «              └┬─┬┘          └╥┘  │   ║  ║
# «         q_3: ─┤M├────────────╫───┼───╫──╫────
# «               └╥┘  ┌─┐       ║   │   ║  ║
# «         q_4: ──╫───┤M├───────╫───┼───╫──╫────
# «                ║   └╥┘  ┌─┐  ║   │   ║  ║
# «         q_5: ──╫────╫───┤M├──╫───┼───╫──╫────
# «                ║    ║   └╥┘  ║ ┌─┴─┐ ║  ║ ┌─┐
# «         q_6: ──╫────╫────╫───╫─┤ X ├─╫──╫─┤M├
# «                ║    ║    ║   ║ └───┘ ║  ║ └╥┘
# «c_measure1: 2/══╬════╬════╬═══╬═══════╩══╩══╬═
# «                ║    ║    ║   ║       1  0  ║
# «c_measure2: 5/══╩════╩════╩═══╩═════════════╩═
# «                1    2    3   0             4
# ========================================

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_best_circuit_search, nshots=5000, 
                            title_prefix="CNOT Optimized Circuit", figsize=(8,4.5), 
                            #figure_save_name = "cnot_optimized_circuit_histograms.svg" 
                            )
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.7, #filename="cnot_optimized_circuit_classi.svg"
                               )
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'10': 2771, '00': 2229}
# Counts for c_measure2: {'00001': 2685, '00000': 2164, '00010': 13, '00011': 25, '10001': 34, '10000': 21, '01010': 2, '00100': 13, '01000': 13, '00101': 12, '01001': 13, '11000': 2, '01101': 1, '10100': 1, '01011': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    best_cnot_sequence, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*0/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    best_cnot_sequence,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=0.7)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (4 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['3.1416', '2.2982', '3.0327', '1.7475']
# CRX Angle Optimization took: 14.24 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['3.1416', '2.2982', '3.0327', '1.7475']
#   Minimum Combined KL Divergence with Optimized CRX: 1.348564
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                   ┌──────────────────────────────────┐                                                                     »
# «         q_0: ─────────────────────────────────────────────────────────────────────┤0                                 ├─────────────────────────────────────────────────────────────────────»
# «                                                                                   │  Initialize(0.67534,0.73751,0,0) │                                                                     »
# «         q_1: ─────────────────────────────────────────────────────────────────────┤1                                 ├─────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────┴──────────────────────────────────┴────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_3: ┤1                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_4: ┤2 Initialize(0.98441,0,0.095973,0,0.064439,0,0.0054842,0,0.074036,0,0.012339,0,0.001371,0,0,0,0.10831,0,0.0027421,0,0.0082263,0,0.001371,0,0.0095973,0,0,0,0.0027421,0,0,0) ├»
# «              │                                                                                                                                                                            │»
# «         q_5: ┤3                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_6: ┤4                                                                                                                                                                           ├»
# «              └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «c_measure2: 5/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «                                          ┌────────────┐                    »
# «         q_0: ──────■─────────────■───────┤ Rx(3.0327) ├─────────■──────────»
# «                    │       ┌─────┴──────┐└─────┬──────┘         │       ┌─┐»
# «         q_1: ──────┼───────┤ Rx(2.2982) ├──────■────────────────┼───────┤M├»
# «              ┌─────┴──────┐└────────────┘              ┌─┐      │       └╥┘»
# «         q_2: ┤ Rx(3.1416) ├────────────────────────────┤M├──────┼────────╫─»
# «              └────┬─┬─────┘                            └╥┘      │        ║ »
# «         q_3: ─────┤M├───────────────────────────────────╫───────┼────────╫─»
# «                   └╥┘           ┌─┐                     ║       │        ║ »
# «         q_4: ──────╫────────────┤M├─────────────────────╫───────┼────────╫─»
# «                    ║            └╥┘           ┌─┐       ║       │        ║ »
# «         q_5: ──────╫─────────────╫────────────┤M├───────╫───────┼────────╫─»
# «                    ║             ║            └╥┘       ║ ┌─────┴──────┐ ║ »
# «         q_6: ──────╫─────────────╫─────────────╫────────╫─┤ Rx(1.7475) ├─╫─»
# «                    ║             ║             ║        ║ └────────────┘ ║ »
# «c_measure1: 2/══════╬═════════════╬═════════════╬════════╬════════════════╩═»
# «                    ║             ║             ║        ║                1 »
# «c_measure2: 5/══════╩═════════════╩═════════════╩════════╩══════════════════»
# «                    1             2             3        0                  »
# «              ┌─┐
# «         q_0: ┤M├───
# «              └╥┘
# «         q_1: ─╫────
# «               ║
# «         q_2: ─╫────
# «               ║
# «         q_3: ─╫────
# «               ║
# «         q_4: ─╫────
# «               ║
# «         q_5: ─╫────
# «               ║ ┌─┐
# «         q_6: ─╫─┤M├
# «               ║ └╥┘
# «c_measure1: 2/═╩══╬═
# «               0  ║
# «c_measure2: 5/════╩═
# «                  4
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'00': 2331, '01': 409, '10': 2255, '11': 5}
# Counts for c_measure2: {'00000': 2261, '10001': 265, '00001': 2348, '10000': 30, '00101': 10, '00010': 18, '01001': 17, '01000': 11, '00011': 22, '00100': 10, '10100': 1, '11011': 1, '10011': 4, '11001': 2}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison_ang_opt.svg')
plt.show()

# %%
from quantum_functions import find_best_cnot_sequence_multi_epoch

np.random.seed(42) 

print("\n" + "="*40)
print("--- Running Multi-Epoch Refined Search ---")
print("="*40)

n_epochs = 42
min_greedy_depth = 2

best_cnot_sequence, min_kl_sum = find_best_cnot_sequence_multi_epoch(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    n_epochs=n_epochs,
    min_cnot_depth=min_greedy_depth,
    nshots=5000,
    threshold = thresh,
    search_mode="pos",
    kl_tol = 0.05,
    ratio_kl_tol = 0.6
)

print("\n" + "="*40)
if best_cnot_sequence:
    print(f"Multi-Epoch Search Optimal CNOT sequence found:")
    for cnot in best_cnot_sequence:
        print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    print(f"With minimum combined KL Divergence: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )


    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("Multi-Epoch Search: No sequence improved the KL divergence beyond the baseline.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))
print("="*40 + "\n")
# Out:
# ========================================
# --- Running Multi-Epoch Refined Search ---
# ========================================
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Generating CNOT candidates from density matrix difference. ---
# --- CNOT Candidate Analysis Summary ---
# System has 7 qubits.
# Total possible CNOTs (brute-force): 42
# Number of refined CNOT candidates found: 30
# ---------------------------------------
#
# Initial KL divergence (baseline): 4.161990
#
# --- Starting Epoch 1/30 (Addition) with CNOT: (4, 0) (KL: 4.168155) ---
#   Skipping epoch: Single CNOT KL (4.168155) does not improve over baseline (4.161990).
#
# --- Starting Epoch 2/30 (Addition) with CNOT: (2, 4) (KL: 4.120995) ---
#     --> Found a better KL on this path: 2.220870 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.165787 at depth 3 with added CNOT (3, 1)
#     --> Found a better KL on this path: 2.103950 at depth 4 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.070321 at depth 5 with added CNOT (1, 0)
#   Epoch 2 best KL Sum: 2.070321
#   --> Epoch 2 found a new overall best KL Sum: 2.070321
#
# --- Starting Epoch 3/30 (Addition) with CNOT: (4, 1) (KL: 4.170120) ---
#   Skipping epoch: Single CNOT KL (4.170120) does not improve over baseline (4.161990).
#
# --- Starting Epoch 4/30 (Addition) with CNOT: (2, 1) (KL: 4.186705) ---
#   Skipping epoch: Single CNOT KL (4.186705) does not improve over baseline (4.161990).
#
# --- Starting Epoch 5/30 (Addition) with CNOT: (1, 2) (KL: 4.178218) ---
#   Skipping epoch: Single CNOT KL (4.178218) does not improve over baseline (4.161990).
#
# --- Starting Epoch 6/30 (Addition) with CNOT: (6, 1) (KL: 4.099802) ---
#     --> Found a better KL on this path: 2.185037 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.123262 at depth 3 with added CNOT (6, 0)
#     --> Found a better KL on this path: 2.118871 at depth 4 with added CNOT (1, 0)
#     --> Found a better KL on this path: 2.100679 at depth 5 with added CNOT (3, 1)
#     --> Found a better KL on this path: 2.087481 at depth 6 with added CNOT (3, 6)
#   Epoch 6 best KL Sum: 2.087481
#
# --- Starting Epoch 7/30 (Addition) with CNOT: (1, 0) (KL: 4.160904) ---
#     --> Found a better KL on this path: 2.225047 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.147201 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.115278 at depth 4 with added CNOT (6, 4)
#   Epoch 7 best KL Sum: 2.115278
#
# --- Starting Epoch 8/30 (Addition) with CNOT: (6, 2) (KL: 4.165833) ---
#   Skipping epoch: Single CNOT KL (4.165833) does not improve over baseline (4.161990).
#
# --- Starting Epoch 9/30 (Addition) with CNOT: (0, 3) (KL: 4.472629) ---
#   Skipping epoch: Single CNOT KL (4.472629) does not improve over baseline (4.161990).
#
# --- Starting Epoch 10/30 (Addition) with CNOT: (3, 1) (KL: 4.118150) ---
#     --> Found a better KL on this path: 2.160135 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.128251 at depth 3 with added CNOT (4, 0)
#   Epoch 10 best KL Sum: 2.128251
#
# --- Starting Epoch 11/30 (Addition) with CNOT: (0, 4) (KL: 3.511910) ---
#     --> Found a better KL on this path: 3.293221 at depth 2 with added CNOT (0, 6)
#     --> Found a better KL on this path: 3.158432 at depth 3 with added CNOT (6, 4)
#     --> Found a better KL on this path: 3.090322 at depth 4 with added CNOT (3, 1)
#     --> Found a better KL on this path: 3.082653 at depth 5 with added CNOT (4, 1)
#     --> Found a better KL on this path: 3.005051 at depth 6 with added CNOT (1, 0)
#     --> Found a better KL on this path: 3.002525 at depth 7 with added CNOT (1, 2)
#   Epoch 11 best KL Sum: 3.002525
#
# --- Starting Epoch 12/30 (Addition) with CNOT: (4, 2) (KL: 4.168118) ---
#   Skipping epoch: Single CNOT KL (4.168118) does not improve over baseline (4.161990).
#
# --- Starting Epoch 13/30 (Addition) with CNOT: (4, 3) (KL: 4.175142) ---
#   Skipping epoch: Single CNOT KL (4.175142) does not improve over baseline (4.161990).
#
# --- Starting Epoch 14/30 (Addition) with CNOT: (2, 0) (KL: 4.128776) ---
#     --> Found a better KL on this path: 2.192714 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.150275 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.095443 at depth 4 with added CNOT (4, 1)
#     --> Found a better KL on this path: 2.061421 at depth 5 with added CNOT (3, 1)
#   Epoch 14 best KL Sum: 2.061421
#   --> Epoch 14 found a new overall best KL Sum: 2.061421
#
# --- Starting Epoch 15/30 (Addition) with CNOT: (6, 4) (KL: 4.194216) ---
#   Skipping epoch: Single CNOT KL (4.194216) does not improve over baseline (4.161990).
#
# --- Starting Epoch 16/30 (Addition) with CNOT: (3, 4) (KL: 4.166097) ---
#   Skipping epoch: Single CNOT KL (4.166097) does not improve over baseline (4.161990).
#
# --- Starting Epoch 17/30 (Addition) with CNOT: (6, 0) (KL: 4.177174) ---
#   Skipping epoch: Single CNOT KL (4.177174) does not improve over baseline (4.161990).
#
# --- Starting Epoch 18/30 (Addition) with CNOT: (0, 2) (KL: 2.245614) ---
#     --> Found a better KL on this path: 2.160674 at depth 2 with added CNOT (3, 1)
#     --> Found a better KL on this path: 2.084803 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.065684 at depth 4 with added CNOT (4, 1)
#   Epoch 18 best KL Sum: 2.065684
#
# --- Starting Epoch 19/30 (Addition) with CNOT: (1, 4) (KL: 4.162496) ---
#   Skipping epoch: Single CNOT KL (4.162496) does not improve over baseline (4.161990).
#
# --- Starting Epoch 20/30 (Addition) with CNOT: (4, 6) (KL: 4.181607) ---
#   Skipping epoch: Single CNOT KL (4.181607) does not improve over baseline (4.161990).
#
# --- Starting Epoch 21/30 (Addition) with CNOT: (3, 0) (KL: 4.162356) ---
#   Skipping epoch: Single CNOT KL (4.162356) does not improve over baseline (4.161990).
#
# --- Starting Epoch 22/30 (Addition) with CNOT: (3, 6) (KL: 4.146603) ---
#     --> Found a better KL on this path: 2.213019 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.106130 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.102185 at depth 4 with added CNOT (1, 0)
#     --> Found a better KL on this path: 2.054370 at depth 5 with added CNOT (4, 6)
#   Epoch 22 best KL Sum: 2.054370
#   --> Epoch 22 found a new overall best KL Sum: 2.054370
#
# --- Starting Epoch 23/30 (Addition) with CNOT: (0, 6) (KL: 3.220234) ---
#     --> Found a better KL on this path: 3.186865 at depth 2 with added CNOT (3, 1)
#     --> Found a better KL on this path: 3.123967 at depth 3 with added CNOT (4, 1)
#   Epoch 23 best KL Sum: 3.123967
#
# --- Starting Epoch 24/30 (Addition) with CNOT: (3, 2) (KL: 4.124427) ---
#     --> Found a better KL on this path: 2.205103 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.129346 at depth 3 with added CNOT (6, 1)
#     --> Found a better KL on this path: 2.082341 at depth 4 with added CNOT (4, 1)
#     --> Found a better KL on this path: 2.066296 at depth 5 with added CNOT (3, 1)
#   Epoch 24 best KL Sum: 2.066296
#
# --- Starting Epoch 25/30 (Addition) with CNOT: (0, 1) (KL: 4.689292) ---
#   Skipping epoch: Single CNOT KL (4.689292) does not improve over baseline (4.161990).
#
# --- Starting Epoch 26/30 (Addition) with CNOT: (1, 6) (KL: 4.188662) ---
#   Skipping epoch: Single CNOT KL (4.188662) does not improve over baseline (4.161990).
#
# --- Starting Epoch 27/30 (Addition) with CNOT: (2, 6) (KL: 4.174326) ---
#   Skipping epoch: Single CNOT KL (4.174326) does not improve over baseline (4.161990).
#
# --- Starting Epoch 28/30 (Addition) with CNOT: (2, 3) (KL: 4.178613) ---
#   Skipping epoch: Single CNOT KL (4.178613) does not improve over baseline (4.161990).
#
# --- Starting Epoch 29/30 (Addition) with CNOT: (1, 3) (KL: 4.184111) ---
#   Skipping epoch: Single CNOT KL (4.184111) does not improve over baseline (4.161990).
#
# --- Starting Epoch 30/30 (Addition) with CNOT: (6, 3) (KL: 4.161437) ---
#     --> Found a better KL on this path: 2.246671 at depth 2 with added CNOT (0, 2)
#     --> Found a better KL on this path: 2.155819 at depth 3 with added CNOT (3, 1)
#     --> Found a better KL on this path: 2.092328 at depth 4 with added CNOT (6, 2)
#   Epoch 30 best KL Sum: 2.092328
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 5 CNOTs (KL Sum: 2.054370)
#   No CNOT removal improved the score. Stopping removal search.
#
# Final Result: Best sequence found has 4 CNOTs (KL: 2.065684).
#
# Total search took: 296.72 seconds.
#
# ========================================
# Multi-Epoch Search Optimal CNOT sequence found:
#   q[0] -> q[2]
#   q[3] -> q[1]
#   q[6] -> q[1]
#   q[4] -> q[1]
# With minimum combined KL Divergence: 2.065684
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                   ┌──────────────────────────────────┐                                                                     »
# «         q_0: ─────────────────────────────────────────────────────────────────────┤0                                 ├─────────────────────────────────────────────────────────────────────»
# «                                                                                   │  Initialize(0.67534,0.73751,0,0) │                                                                     »
# «         q_1: ─────────────────────────────────────────────────────────────────────┤1                                 ├─────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────┴──────────────────────────────────┴────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_3: ┤1                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_4: ┤2 Initialize(0.98441,0,0.095973,0,0.064439,0,0.0054842,0,0.074036,0,0.012339,0,0.001371,0,0,0,0.10831,0,0.0027421,0,0.0082263,0,0.001371,0,0.0095973,0,0,0,0.0027421,0,0,0) ├»
# «              │                                                                                                                                                                            │»
# «         q_5: ┤3                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_6: ┤4                                                                                                                                                                           ├»
# «              └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «c_measure2: 5/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «                             ┌─┐
# «         q_0: ──■────────────┤M├─────────────────
# «                │  ┌───┐┌───┐└╥┘      ┌───┐┌─┐
# «         q_1: ──┼──┤ X ├┤ X ├─╫───────┤ X ├┤M├───
# «              ┌─┴─┐└─┬─┘└─┬─┘ ║ ┌─┐   └─┬─┘└╥┘
# «         q_2: ┤ X ├──┼────┼───╫─┤M├─────┼───╫────
# «              └───┘  │    │   ║ └╥┘┌─┐  │   ║
# «         q_3: ───────■────┼───╫──╫─┤M├──┼───╫────
# «                          │   ║  ║ └╥┘  │   ║ ┌─┐
# «         q_4: ────────────┼───╫──╫──╫───■───╫─┤M├
# «               ┌─┐        │   ║  ║  ║       ║ └╥┘
# «         q_5: ─┤M├────────┼───╫──╫──╫───────╫──╫─
# «               └╥┘        │   ║  ║  ║  ┌─┐  ║  ║
# «         q_6: ──╫─────────■───╫──╫──╫──┤M├──╫──╫─
# «                ║             ║  ║  ║  └╥┘  ║  ║
# «c_measure1: 2/══╬═════════════╩══╬══╬═══╬═══╩══╬═
# «                ║             0  ║  ║   ║   1  ║
# «c_measure2: 5/══╩════════════════╩══╩═══╩══════╩═
# «                3                0  1   4      2
# ========================================

# %%
from quantum_functions import plot_measurement_histograms

measure_counts1, measure_counts2 = plot_measurement_histograms( final_best_circuit_search, nshots=5000, title_prefix="CNOT Optimized Circuit")
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.5)
# Out:
# --- Running circuit for: CNOT Optimized Circuit ---
# Counts for c_measure1: {'01': 2702, '00': 2175, '10': 55, '11': 68}
# Counts for c_measure2: {'00001': 2690, '00000': 2162, '10000': 28, '00011': 24, '10001': 30, '01000': 13, '00101': 11, '00010': 18, '11001': 1, '00100': 9, '01001': 11, '00111': 1, '01011': 1, '01101': 1}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison.svg')
plt.show()

# %%
from quantum_functions import optimize_crx_angles, add_crx_gates_and_measurements_to_circuit

# --- Optimize CRX angles for the Brute-Force CNOT topology ---
print("\n" + "="*40)
print("--- Running CRX Angle Optimization (based on CNOT topology) ---")
print("="*40)

optimized_crx_angles, min_kl_crx_optimized, crx_optimization_history = optimize_crx_angles(
    circ1,
    circ2,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    best_cnot_sequence, # Use the CNOT topology found by brute-force
    nshots=5000,
    opt_method='COBYLA', # Using L-BFGS-B COBYLA for angle optimization
    initial_angle_value= np.pi*0#/2 # Start angles at pi (CNOT equivalent) | pi/2 mixed
)

print("\n" + "="*40)
print(f"CRX Angle Optimization Results:")
print(f"  Optimized Angles: {[f'{angle:.4f}' for angle in optimized_crx_angles]}")
print(f"  Minimum Combined KL Divergence with Optimized CRX: {min_kl_crx_optimized:.6f}")
#print(f"  Optimization History (KL Sums per iteration): {[f'{val:.6f}' for val in crx_optimization_history]}")

# Plot the optimization history
if crx_optimization_history:
    plt.figure(figsize=(10, 6))
    plt.plot(crx_optimization_history, marker='o', linestyle='-')
    plt.title('CRX Angle Optimization History (KL Divergence Sum)')
    plt.xlabel('Optimization Iteration')
    plt.ylabel('Combined KL Divergence')
    plt.grid(True)
    #plt.xticks(range(len(crx_optimization_history))) # Ensure all iterations are shown on x-axis
    plt.show()
    plt.close() # Close the figure to free memory


# Construct and draw the final circuit with optimized CRX angles
final_crx_optimized_circuit = add_crx_gates_and_measurements_to_circuit(
    concatenate_circuits_with_separate_measurements(circ1, circ2),
    circ1.num_qubits,
    best_cnot_sequence,
    optimized_crx_angles
)
print("\n--- Final Optimized Circuit (CRX Angles) ---")
print(final_crx_optimized_circuit.draw('text'))

# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_crx_optimized_circuit, nshots=5000, title_prefix="CRX Optimized Circuit")
final_crx_optimized_circuit
final_crx_optimized_circuit.draw(output="mpl", style="clifford", fold=40, scale=1.2)
# Out:
# ========================================
# --- Running CRX Angle Optimization (based on CNOT topology) ---
# ========================================
#
# --- Starting CRX Angle Optimization (4 CRX gates) ---
#
# Optimization Results:
#   Success: True
#   Message: Optimization terminated successfully.
#   Optimized Angles: ['3.0972', '1.0639', '1.8757', '0.9233']
# CRX Angle Optimization took: 11.55 seconds
#
# ========================================
# CRX Angle Optimization Results:
#   Optimized Angles: ['3.0972', '1.0639', '1.8757', '0.9233']
#   Minimum Combined KL Divergence with Optimized CRX: 2.150757
# --- Final Optimized Circuit (CRX Angles) ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 2/»
#               »
# c_measure2: 5/»
#               »
# «                                                                                   ┌──────────────────────────────────┐                                                                     »
# «         q_0: ─────────────────────────────────────────────────────────────────────┤0                                 ├─────────────────────────────────────────────────────────────────────»
# «                                                                                   │  Initialize(0.67534,0.73751,0,0) │                                                                     »
# «         q_1: ─────────────────────────────────────────────────────────────────────┤1                                 ├─────────────────────────────────────────────────────────────────────»
# «              ┌────────────────────────────────────────────────────────────────────┴──────────────────────────────────┴────────────────────────────────────────────────────────────────────┐»
# «         q_2: ┤0                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_3: ┤1                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_4: ┤2 Initialize(0.98441,0,0.095973,0,0.064439,0,0.0054842,0,0.074036,0,0.012339,0,0.001371,0,0,0,0.10831,0,0.0027421,0,0.0082263,0,0.001371,0,0.0095973,0,0,0,0.0027421,0,0,0) ├»
# «              │                                                                                                                                                                            │»
# «         q_5: ┤3                                                                                                                                                                           ├»
# «              │                                                                                                                                                                            │»
# «         q_6: ┤4                                                                                                                                                                           ├»
# «              └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «c_measure1: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «c_measure2: 5/══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                                            »
# «                                                        ┌─┐      »
# «         q_0: ──────■───────────────────────────────────┤M├──────»
# «                    │       ┌────────────┐┌────────────┐└╥┘      »
# «         q_1: ──────┼───────┤ Rx(1.0639) ├┤ Rx(1.8757) ├─╫───────»
# «              ┌─────┴──────┐└─────┬──────┘└─────┬──────┘ ║ ┌─┐   »
# «         q_2: ┤ Rx(3.0972) ├──────┼─────────────┼────────╫─┤M├───»
# «              └────────────┘      │             │        ║ └╥┘┌─┐»
# «         q_3: ────────────────────■─────────────┼────────╫──╫─┤M├»
# «                                                │        ║  ║ └╥┘»
# «         q_4: ──────────────────────────────────┼────────╫──╫──╫─»
# «                   ┌─┐                          │        ║  ║  ║ »
# «         q_5: ─────┤M├──────────────────────────┼────────╫──╫──╫─»
# «                   └╥┘                          │        ║  ║  ║ »
# «         q_6: ──────╫───────────────────────────■────────╫──╫──╫─»
# «                    ║                                    ║  ║  ║ »
# «c_measure1: 2/══════╬════════════════════════════════════╩══╬══╬═»
# «                    ║                                    0  ║  ║ »
# «c_measure2: 5/══════╩═══════════════════════════════════════╩══╩═»
# «                    3                                       0  1 »
# «
# «         q_0: ─────────────────────
# «              ┌─────────────┐┌─┐
# «         q_1: ┤ Rx(0.92334) ├┤M├───
# «              └──────┬──────┘└╥┘
# «         q_2: ───────┼────────╫────
# «                     │        ║
# «         q_3: ───────┼────────╫────
# «                     │        ║ ┌─┐
# «         q_4: ───────■────────╫─┤M├
# «                              ║ └╥┘
# «         q_5: ────────────────╫──╫─
# «                    ┌─┐       ║  ║
# «         q_6: ──────┤M├───────╫──╫─
# «                    └╥┘       ║  ║
# «c_measure1: 2/═══════╬════════╩══╬═
# «                     ║        1  ║
# «c_measure2: 5/═══════╩═══════════╩═
# «                     4           2
#
# --- Running circuit for: CRX Optimized Circuit ---
# Counts for c_measure1: {'01': 2725, '00': 2225, '11': 27, '10': 23}
# Counts for c_measure2: {'00001': 2666, '00000': 2180, '00010': 20, '00011': 26, '10001': 27, '10000': 29, '00100': 9, '01000': 11, '01001': 19, '00101': 13}

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Normalization Logic ---
def normalize_counts(data_dict):
    total_count = sum(data_dict.values())
    if total_count == 0:
        return {key: 0 for key in data_dict}
    return {key: (value / total_count) * 100 for key, value in data_dict.items()}

# Normalize your raw data
normalized_measure_counts1 = normalize_counts(measure_counts1)
normalized_measure_counts2 = normalize_counts(measure_counts2)
normalized_joint_counts_ct1_mo = normalize_counts(joint_counts_ct1_mo)
normalized_joint_counts_ct2_mo = normalize_counts(joint_counts_ct2_mo)
normalized_joint_counts_ct1_co = normalize_counts(joint_counts_ct1_co)
normalized_joint_counts_ct2_co = normalize_counts(joint_counts_ct2_co)

# --- 2. Data Structuring ---
plot_data_columns = [
    [normalized_joint_counts_ct1_mo, normalized_measure_counts1, normalized_joint_counts_ct1_co],
    [normalized_joint_counts_ct2_mo, normalized_measure_counts2, normalized_joint_counts_ct2_co]
]
titles_columns = [
    ['joint_counts_ct1_mo', 'measure_counts1', 'joint_counts_ct1_co'],
    ['joint_counts_ct2_mo', 'measure_counts2', 'joint_counts_ct2_co']
]

# --- 3. Formatting & Style Constants ---
color_mo = '#4682B4'    # Darker Steel Blue
color_qxct = '#9370DB'  # Medium Purple
color_co = '#4B0082'    # Deep Indigo

legend_map = {
    'joint_counts_ct1_mo': 'CT1-Mo',
    'joint_counts_ct2_mo': 'CT2-Mo',
    'joint_counts_ct1_co': 'CT1-Co',
    'joint_counts_ct2_co': 'CT2-Co',
    'measure_counts1': 'CT1-QXCT',
    'measure_counts2': 'CT2-QXCT'
}

# --- 4. Plotting ---
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), sharey=True)

for i in range(2):
    current_data = plot_data_columns[i]
    current_titles = titles_columns[i]
    
    # Ensure all bitstrings are present on the X-axis
    all_keys = sorted(list(set(current_data[0].keys()) | 
                           set(current_data[1].keys()) | 
                           set(current_data[2].keys())))
    
    x = np.arange(len(all_keys))
    width = 0.25 
    
    # Extract values for bars
    values_mo = [current_data[0].get(key, 0) for key in all_keys]   # Initial
    values_qxct = [current_data[1].get(key, 0) for key in all_keys] # Prediction
    values_co = [current_data[2].get(key, 0) for key in all_keys]   # Target

    # Bar plotting
    axes[i].bar(x - width, values_mo, width, 
                label=legend_map[current_titles[0]], color=color_mo)
    axes[i].bar(x, values_qxct, width, 
                label=legend_map[current_titles[1]], color=color_qxct)
    axes[i].bar(x + width, values_co, width, 
                label=legend_map[current_titles[2]], color=color_co)
    
    # Refined Axis Customization
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(all_keys, rotation=60, ha='right', fontsize=11)
    
    cell_type = "CT1" if i == 0 else "CT2"
    axes[i].set_title(f'State Occupancy Comparison ({cell_type})', fontweight='bold', fontsize=15)
    
    axes[i].grid(axis='y', linestyle=':', alpha=0.6)
    
    if i == 0:
        axes[i].set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    
    axes[i].legend(frameon=True, loc='upper left', fontsize=11)

plt.tight_layout()
plt.savefig('state_occupancy_comparison_ang_opt.svg')
plt.show()

# %%
from quantum_functions import build_kl_divergence_matrix_interaction

np.random.seed(42) 

print("\n" + "="*40)
print("--- Creating QUBO matrix ---")
print("="*40)
    
kl_divergence_matrix, cnot_to_index, initial_cnot_config, initial_kl_sum = build_kl_divergence_matrix_interaction(
    circ1,
    circ2,
    normalized_joint_counts_ct1_mo,
    normalized_joint_counts_ct2_mo,
    normalized_joint_counts_ct1_co,
    normalized_joint_counts_ct2_co,
    nshots=5000,
    threshold= thresh, 
    search_mode="pos",
    include_single_cnot_kl=True
)
# Out:
# ========================================
# --- Creating QUBO matrix ---
# ========================================
#
# --- Identifying Potential CNOT Linkers from Density Matrix Difference ---
# --- CNOT Candidate Analysis Summary ---
# System has 7 qubits.
# Total possible CNOTs (brute-force): 42
# Number of refined CNOT candidates found: 30
# ---------------------------------------
#
# Initial KL Divergence (no CNOTs): 4.185579
#
# --- Building KL Divergence Matrix (30x30) ---
# Calculating KL for single CNOTs (diagonal elements)...
# Calculating KL for CNOT pairs (off-diagonal elements)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 9
#       6 print("--- Creating QUBO matrix ---")
#       7 print("="*40)
# ----> 9 kl_divergence_matrix, cnot_to_index, initial_cnot_config, initial_kl_sum = build_kl_divergence_matrix_interaction(
#      10     circ1,
#      11     circ2,
#      12     normalized_joint_counts_ct1_mo,
#      13     normalized_joint_counts_ct2_mo,
#      14     normalized_joint_counts_ct1_co,
#      15     normalized_joint_counts_ct2_co,
#      16     nshots=5000,
#      17     threshold= thresh,
#      18     search_mode="pos",
#      19     include_single_cnot_kl=True
#      20 )
#
# File ~\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions\quantum_functions.py:1596, in build_kl_divergence_matrix_interaction(circ1, circ2, state_probs_initial1, state_probs_initial2, state_vec_probs_target1, state_vec_probs_target2, nshots, threshold, search_mode, include_single_cnot_kl)
#    1592 trial_sequence = [cnot_i_val, cnot_j_val]
#    1593 trial_circuit = add_cnots_and_measurements_to_circuit(
#    1594     base_combined_circuit, ng_circ1, trial_sequence
#    1595 )
# -> 1596 kl_divs = score_circuit_kl_divergences(
#    1597     trial_circuit, state_vec_probs_target1, state_vec_probs_target2, nshots
#    1598 )
#    1599 if kl_divs is not None:
#    1600     kl_divergence_matrix[idx_i, idx_j] = kl_divs[0] + kl_divs[1]
#
# File ~\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions\quantum_functions.py:327, in score_circuit_kl_divergences(circuit_to_evaluate, state_vec_probs_target1, state_vec_probs_target2, nshots)
#     325 # 5. Simulate the circuit
#     326 backend = AerSimulator()
# --> 327 pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
#     328 qc_comp = pm.run(circuit_to_evaluate.decompose())
#     330 sampler = Sampler(mode=backend)
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit\transpiler\preset_passmanagers\generate_preset_pass_manager.py:222, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, coupling_map, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, dt, qubits_initially_zero, _skip_target)
#     220 timing_constraints = _parse_timing_constraints(backend)
#     221 coupling_map = _parse_coupling_map(coupling_map, backend)
# --> 222 basis_gates, name_mapping = _parse_basis_gates(basis_gates, backend)
#     224 # Check if coupling map has been provided (either standalone or through backend)
#     225 # with user-defined basis_gates, and whether these have 3q or more.
#     226 if coupling_map is not None and basis_gates is not None:
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit\transpiler\preset_passmanagers\generate_preset_pass_manager.py:355, in _parse_basis_gates(basis_gates, backend)
#     351     return list(instructions), name_mapping
#     353 instructions = instructions or backend.operation_names
#     354 name_mapping.update(
# --> 355     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#     356 )
#     358 # Check for custom instructions
#     359 for inst in instructions:
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit\transpiler\preset_passmanagers\generate_preset_pass_manager.py:355, in <dictcomp>(.0)
#     351     return list(instructions), name_mapping
#     353 instructions = instructions or backend.operation_names
#     354 name_mapping.update(
# --> 355     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#     356 )
#     358 # Check for custom instructions
#     359 for inst in instructions:
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit_aer\backends\aerbackend.py:421, in AerBackend.target(self)
#     416         target.add_instruction(
#     417             instruction=qiskit_control_flow_mapping[inst_name],
#     418             name=inst_name,
#     419         )
#     420     else:
# --> 421         target.add_instruction(
#     422             instruction=inst_name_map[inst_name],
#     423             properties=prop_name_map.get(inst_name, None),
#     424             name=inst_name,
#     425         )
#     427 if self._coupling_map is not None:
#     428     target._coupling_graph = self._coupling_map.graph.copy()
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit\transpiler\target.py:376, in Target.add_instruction(self, instruction, properties, name)
#     374 if instruction_name in self._gate_map:
#     375     raise AttributeError(f"Instruction {instruction_name} is already in the target")
# --> 376 super().add_instruction(instruction, instruction_name, properties)
#     377 self._gate_map[instruction_name] = properties
#     378 self._coupling_graph = None
#
# KeyboardInterrupt:

# %%
from quantum_functions import kl_to_qubo_matrix

# Creating Q matrix 
kl_div_mat_qubo = kl_to_qubo_matrix(kl_matrix = kl_divergence_matrix, initial_kl_sum = initial_kl_sum)

# %%
from qiskit_optimization import QuadraticProgram
from qiskit.quantum_info import SparsePauliOp
import numpy as np

# Assume kl_div_mat_qubo is your 42x42 NumPy array

num_qubits = kl_div_mat_qubo.shape[0]

# --- 1. Define the Quadratic Program (QUBO) ---
qp = QuadraticProgram(name="CnotOptimization")

for i in range(num_qubits):
    qp.binary_var(name=f'x{i}')

# Set the objective function to minimize the cost defined by the QUBO matrix
# The matrix must be passed as the 'quadratic' term.
qp.minimize(quadratic=kl_div_mat_qubo)

# --- 2. Convert the QUBO to an Ising Hamiltonian ---
# The Ising Converter performs the necessary transformation (x = (1 - Z)/2)
hamiltonian, offset = qp.to_ising()
print(offset)
print(hamiltonian)
# Out:
# -4.728907001099103
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIZZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIZZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIZZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIZIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIZIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIZIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIZIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIZIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIZIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIZIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIZIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIZIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIZIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIZIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIZIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIZIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIZIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIZIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIZIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIZIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIZIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIZIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIZIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIZIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IZIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'ZIIIIIIIIIIIIIIIIIIIIIIIIIIZII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZZIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIZIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIZIII', 'IIIIII ...
#               coeffs=[ 7.94478113e-01+0.j,  4.04180975e-03+0.j,  3.33916179e-01+0.j,
#  -1.04574433e-02+0.j,  6.49214864e-01+0.j,  1.09292815e-03+0.j,
#   2.95405373e-01+0.j, -4.92324325e-03+0.j,  3.75246853e-01+0.j,
#  -3.93183762e-02+0.j,  1.79316166e-01+0.j, -2.32585252e-01+0.j,
#   6.64673520e-01+0.j, -5.83933182e-03+0.j,  1.49325081e-01+0.j,
#  -1.27461342e-01+0.j,  9.20228800e-02+0.j, -2.01158385e-01+0.j,
#   5.45605703e-01+0.j, -7.83767396e-03+0.j, -3.74700261e-02+0.j,
#  -6.58147774e-03+0.j,  2.38275495e-01+0.j, -5.88298938e-03+0.j,
#   1.74577670e-01+0.j, -1.17802477e-02+0.j,  3.36587008e-01+0.j,
#   7.73217166e-04+0.j,  3.05705598e-01+0.j, -8.78529304e-03+0.j,
#   8.04324959e-02+0.j,  3.58431932e-03+0.j,  1.67718607e-01+0.j,
#  -2.00244499e-03+0.j,  2.41795231e-01+0.j, -1.38609100e-02+0.j,
#   4.66258940e-01+0.j, -6.04322607e-03+0.j,  4.25640220e-01+0.j,
#   2.80686630e-03+0.j, -1.04851278e-01+0.j, -9.15147613e-03+0.j,
#   3.47299002e-01+0.j,  1.82865389e-03+0.j,  2.49987411e-01+0.j,
#   5.79540005e-03+0.j,  1.08928865e-01+0.j,  1.30452734e-02+0.j,
#   2.03207326e-02+0.j, -1.33313583e-02+0.j, -1.80931731e-02+0.j,
#   4.08322442e-03+0.j,  1.75601899e-01+0.j,  7.24307998e-03+0.j,
#   1.89614586e-01+0.j, -6.67459557e-03+0.j,  3.52419390e-01+0.j,
#  -8.12415880e-03+0.j,  4.13205467e-01+0.j,  4.21203056e-02+0.j,
#   1.60515065e-01+0.j,  1.29616381e-01+0.j, -5.11040299e-03+0.j,
#  -7.15908704e-03+0.j, -3.65028137e-03+0.j, -2.84091036e-03+0.j,
#  -9.75268863e-03+0.j,  5.23733543e-03+0.j, -5.36163531e-02+0.j,
#  -8.89240987e-03+0.j, -1.25284515e-02+0.j, -6.99875949e-02+0.j,
#  -1.76630310e-03+0.j, -6.33568654e-03+0.j, -9.29690506e-04+0.j,
#  -6.74573914e-03+0.j, -7.54413883e-03+0.j,  5.74565823e-03+0.j,
#  -7.23407735e-03+0.j, -2.19218839e-03+0.j,  2.67453685e-03+0.j,
#  -3.03959066e-04+0.j,  6.88953458e-03+0.j, -6.17610837e-03+0.j,
#   1.39606985e-03+0.j, -1.42713499e-02+0.j, -7.74662368e-03+0.j,
#  -3.16043838e-02+0.j,  2.24237070e-02+0.j, -1.83867739e-02+0.j,
#  -1.58444297e-02+0.j, -1.05348953e-02+0.j, -1.27245990e-03+0.j,
#  -2.20009222e-02+0.j, -8.29815566e-03+0.j, -1.60167780e-02+0.j,
#  -1.71455543e-02+0.j, -1.26741900e-02+0.j, -1.74626784e-02+0.j,
#  -3.11195133e-03+0.j, -5.91623087e-02+0.j, -1.72931845e-01+0.j,
#  -1.62003329e-01+0.j, -1.73416621e-01+0.j, -6.62911332e-03+0.j,
#  -1.97047127e-02+0.j, -1.11605867e-02+0.j, -1.40572446e-02+0.j,
#  -4.99680614e-03+0.j,  2.32685875e-03+0.j, -1.06029686e-02+0.j,
#  -2.08208565e-02+0.j, -2.18134502e-02+0.j, -2.21727646e-02+0.j,
#   1.55216186e-01+0.j, -2.28911521e-03+0.j, -1.98017222e-02+0.j,
#  -3.29679532e-03+0.j,  1.28602671e-02+0.j, -1.31762771e-02+0.j,
#  -6.65060650e-04+0.j, -3.45029449e-04+0.j, -6.16337845e-03+0.j,
#  -1.77294615e-02+0.j, -6.43773310e-03+0.j, -5.11281382e-03+0.j,
#  -3.55662940e-03+0.j,  3.18472510e-03+0.j, -5.25721862e-04+0.j,
#  -3.23490840e-03+0.j,  4.05353818e-03+0.j, -7.43971494e-02+0.j,
#  -6.45989623e-02+0.j, -6.21343723e-03+0.j, -4.12875123e-02+0.j,
#  -1.22285391e-03+0.j, -6.18946730e-03+0.j, -1.00950563e-02+0.j,
#  -1.24012444e-02+0.j, -1.54225894e-02+0.j, -6.87008239e-04+0.j,
#  -1.53117334e-02+0.j, -2.02388279e-03+0.j,  2.84005684e-03+0.j,
#  -9.00626078e-03+0.j,  1.12392145e-02+0.j, -1.39358288e-02+0.j,
#  -5.31217918e-03+0.j, -1.23137498e-02+0.j, -7.50649212e-03+0.j,
#  -7.06807348e-03+0.j, -4.62023310e-03+0.j,  4.74692899e-03+0.j,
#  -1.64580877e-02+0.j, -5.35234367e-03+0.j,  2.46015262e-05+0.j,
#  -6.89822710e-03+0.j, -6.77442011e-03+0.j,  5.57478946e-04+0.j,
#   4.02671624e-03+0.j,  1.01443947e-02+0.j, -5.76565453e-02+0.j,
#  -7.33746606e-02+0.j, -2.38744653e-02+0.j, -2.71494164e-02+0.j,
#  -1.12961647e-02+0.j,  6.27283061e-04+0.j, -3.96336277e-04+0.j,
#  -7.49946483e-03+0.j,  3.91781950e-03+0.j, -8.51636069e-03+0.j,
#  -5.13409755e-03+0.j, -1.09552979e-02+0.j, -9.91251877e-03+0.j,
#   8.85724633e-04+0.j,  1.85222987e-03+0.j, -1.83957344e-03+0.j,
#  -1.19424490e-02+0.j, -1.22496810e-02+0.j,  6.75673751e-03+0.j,
#  -6.12676408e-03+0.j, -3.60082093e-03+0.j, -6.14282464e-04+0.j,
#  -2.72697677e-03+0.j, -3.68882304e-03+0.j,  6.36403928e-03+0.j,
#  -1.00448649e-03+0.j, -1.32949086e-02+0.j, -1.94445199e-02+0.j,
#  -8.02071737e-03+0.j, -3.23292699e-03+0.j, -1.81068211e-02+0.j,
#  -6.23366228e-03+0.j, -7.38665921e-03+0.j, -1.65196307e-02+0.j,
#  -2.98161399e-02+0.j, -2.74454800e-02+0.j, -1.32396152e-02+0.j,
#  -1.62923901e-02+0.j, -1.15814409e-02+0.j, -1.78792940e-02+0.j,
#  -2.04726131e-02+0.j, -6.56033580e-03+0.j, -1.97358023e-02+0.j,
#  -2.16293417e-02+0.j, -1.91166509e-02+0.j, -5.26340103e-03+0.j,
#  -9.27182498e-03+0.j, -2.30988044e-02+0.j, -1.81032386e-02+0.j,
#  -2.25162737e-02+0.j, -2.92124900e-02+0.j,  2.37626111e-03+0.j,
#  -1.29764649e-02+0.j,  3.34511352e-03+0.j, -2.26645114e-03+0.j,
#  -9.24666606e-03+0.j, -1.69970379e-02+0.j, -6.49438963e-03+0.j,
#  -4.60087165e-03+0.j,  4.46712271e-03+0.j,  9.43792049e-04+0.j,
#  -1.54025237e-02+0.j, -1.20648869e-02+0.j,  4.88974779e-03+0.j,
#  -1.12811440e-02+0.j, -5.37285240e-03+0.j,  4.42819326e-03+0.j,
#  -1.66866995e-03+0.j, -8.28190795e-03+0.j, -2.07253745e-03+0.j,
#   4.40563432e-03+0.j, -1.33536738e-02+0.j, -1.29502980e-02+0.j,
#  -7.92426180e-03+0.j,  1.12148415e-02+0.j,  3.64272884e-03+0.j,
#   4.08643886e-03+0.j, -4.17308395e-03+0.j, -9.07016323e-04+0.j,
#   6.95145215e-03+0.j,  3.69514348e-03+0.j,  2.86918111e-03+0.j,
#  -2.05013660e-03+0.j, -8.02900565e-03+0.j,  1.63745833e-02+0.j,
#   5.64260105e-03+0.j,  1.37452854e-04+0.j,  2.13170519e-03+0.j,
#   5.90988139e-03+0.j,  9.60467579e-03+0.j,  4.25197192e-03+0.j,
#   3.79525460e-03+0.j,  3.25018633e-03+0.j, -5.32961020e-03+0.j,
#  -5.46810770e-04+0.j, -3.34210252e-03+0.j, -1.26960334e-02+0.j,
#  -2.03460869e-02+0.j, -1.70204671e-02+0.j, -1.49664774e-02+0.j,
#  -1.69052061e-02+0.j, -1.04346211e-02+0.j, -1.35128348e-02+0.j,
#  -1.34353831e-02+0.j, -1.18931526e-03+0.j, -1.84924377e-02+0.j,
#  -1.58902793e-02+0.j, -1.14655622e-02+0.j, -6.33998890e-03+0.j,
#  -7.39715286e-03+0.j, -1.82679725e-03+0.j, -8.87494430e-03+0.j,
#  -2.04484273e-02+0.j, -2.90517858e-02+0.j,  4.11157884e-03+0.j,
#   3.09670777e-03+0.j, -9.46939193e-03+0.j, -5.83742662e-03+0.j,
#  -1.50739851e-03+0.j,  2.95099101e-03+0.j,  1.99562656e-03+0.j,
#  -1.64628264e-03+0.j,  1.12751708e-03+0.j,  1.47831645e-02+0.j,
#   3.20964374e-03+0.j, -1.67119752e-03+0.j,  6.62584211e-03+0.j,
#   7.76411089e-03+0.j,  9.73531588e-03+0.j,  1.28325471e-02+0.j,
#   1.08320450e-02+0.j, -1.13991185e-02+0.j, -7.49710881e-03+0.j,
#  -3.04286363e-03+0.j, -8.35540091e-03+0.j, -9.38570095e-03+0.j,
#  -1.14649862e-03+0.j,  4.14397651e-04+0.j, -8.81446999e-03+0.j,
#  -1.41385527e-02+0.j, -7.99467082e-03+0.j,  8.08595330e-03+0.j,
#  -1.90551713e-03+0.j, -1.09743047e-02+0.j,  1.08232392e-03+0.j,
#  -6.47239520e-03+0.j,  1.28363543e-03+0.j, -1.24896683e-03+0.j,
#  -2.09486850e-02+0.j, -8.59823283e-03+0.j, -1.96968921e-02+0.j,
#  -1.37776996e-02+0.j, -8.64585643e-03+0.j, -6.65431564e-03+0.j,
#  -1.00357808e-02+0.j, -2.61473807e-03+0.j, -1.43971693e-02+0.j,
#  -1.08084923e-02+0.j,  5.65752881e-03+0.j, -8.98552680e-03+0.j,
#  -9.93004574e-03+0.j, -3.28087034e-03+0.j,  1.05824593e-02+0.j,
#   2.89244527e-03+0.j, -2.58554667e-03+0.j, -4.67560338e-03+0.j,
#  -1.73192547e-02+0.j, -5.03127881e-03+0.j, -1.45370221e-02+0.j,
#  -4.19582267e-03+0.j, -6.00208804e-03+0.j, -1.36381360e-02+0.j,
#  -1.57073551e-02+0.j, -8.56154091e-03+0.j, -2.30936328e-03+0.j,
#  -1.40057756e-02+0.j, -1.42321128e-02+0.j, -1.13138184e-02+0.j,
#  -8.43046930e-03+0.j, -4.65352610e-03+0.j, -5.91905171e-03+0.j,
#  -6.11576278e-03+0.j, -2.30699177e-02+0.j, -1.87934605e-02+0.j,
#  -3.86157592e-04+0.j, -9.55209729e-03+0.j,  4.94307857e-03+0.j,
#  -1.27992189e-02+0.j, -1.09004077e-02+0.j,  2.48270824e-03+0.j,
#  -1.13592440e-02+0.j, -1.13653000e-02+0.j, -1.07993329e-02+0.j,
#   5.64839932e-04+0.j, -6.59376277e-03+0.j, -1.40964032e-02+0.j,
#  -7.07620198e-03+0.j, -1.16929042e-02+0.j, -1.09684002e-02+0.j,
#   5.69255103e-03+0.j,  5.44577684e-04+0.j, -2.16572885e-03+0.j,
#  -8.51541012e-03+0.j,  1.04685447e-02+0.j, -8.32370419e-03+0.j,
#  -5.75111939e-03+0.j,  7.63552285e-04+0.j,  6.42546809e-03+0.j,
#   5.05024159e-03+0.j, -2.51261239e-03+0.j,  5.04614747e-03+0.j,
#  -2.50760719e-03+0.j, -1.56208062e-02+0.j, -4.60145381e-03+0.j,
#  -6.92825033e-03+0.j, -4.73872682e-03+0.j,  8.05852593e-03+0.j,
#   3.06604980e-03+0.j, -3.92962463e-04+0.j, -5.21220765e-03+0.j,
#   3.48884023e-03+0.j,  8.31537539e-03+0.j,  1.35852016e-03+0.j,
#   2.08278143e-03+0.j, -1.98945632e-02+0.j, -1.28878294e-02+0.j,
#  -6.15611599e-03+0.j, -7.53586360e-03+0.j,  5.63054328e-03+0.j,
#  -3.78498861e-03+0.j, -2.88282083e-03+0.j, -1.94841917e-03+0.j,
#   4.23816871e-03+0.j,  1.34463668e-03+0.j,  6.08621306e-03+0.j,
#   2.66041925e-03+0.j, -7.49790844e-03+0.j, -8.53633827e-03+0.j,
#  -8.74863288e-03+0.j,  1.26500660e-04+0.j, -3.25712630e-02+0.j,
#  -1.73698217e-02+0.j, -1.06323688e-02+0.j, -1.47652238e-03+0.j,
#  -3.93677444e-03+0.j, -7.50773479e-03+0.j, -1.38681963e-02+0.j,
#  -2.37840296e-02+0.j, -1.87054019e-02+0.j,  3.23544435e-03+0.j,
#  -1.39646450e-02+0.j, -1.49055083e-02+0.j, -6.48743574e-03+0.j,
#  -5.03158036e-03+0.j,  3.62621453e-04+0.j, -1.82311089e-02+0.j,
#  -1.01891557e-02+0.j, -1.72340009e-02+0.j, -1.73207147e-02+0.j,
#   2.32513350e-03+0.j,  4.16055808e-03+0.j,  1.16474254e-02+0.j,
#   8.72450107e-03+0.j,  1.07643222e-02+0.j,  8.75422892e-03+0.j,
#   1.23194137e-02+0.j, -8.81325386e-03+0.j, -8.87278454e-03+0.j,
#  -1.20746441e-02+0.j, -8.32190605e-03+0.j, -1.09882042e-02+0.j,
#   3.19435541e-03+0.j, -7.17100251e-03+0.j, -1.01134295e-02+0.j,
#  -1.55155060e-02+0.j, -2.75081946e-02+0.j, -3.42910887e-03+0.j,
#   1.05388583e-03+0.j,  7.61718372e-03+0.j, -1.61273279e-04+0.j,
#  -5.46553082e-03+0.j, -5.63176267e-03+0.j, -1.70481908e-02+0.j,
#   6.76685413e-03+0.j,  1.20720381e-03+0.j,  9.74387298e-05+0.j,
#  -5.86715328e-03+0.j, -1.69019487e-02+0.j, -1.63098592e-02+0.j,
#   8.06249399e-03+0.j,  4.19515190e-05+0.j,  1.25035820e-02+0.j,
#   2.14893439e-04+0.j, -4.53918281e-03+0.j,  6.91514193e-03+0.j,
#   7.14004916e-03+0.j, -3.52533934e-03+0.j, -8.21688562e-03+0.j,
#  -8.49257243e-03+0.j, -6.86909397e-03+0.j, -8.48209098e-03+0.j,
#  -1.26237110e-02+0.j, -1.35419177e-02+0.j, -1.49011539e-02+0.j])

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_aer import AerSimulator
from qiskit.circuit.library import EfficientSU2
from qiskit.circuit import QuantumCircuit
from qiskit.compiler import transpile
import numpy as np

# --- 1. Configuration (Example values) ---
num_qubits = kl_div_mat_qubo.shape[0]
reps = 1
entanglement = 'circular'  # linear sca circular pairwise reverse_linear full

# --- 2. Ansatz Creation ---
ansatz = EfficientSU2( num_qubits=num_qubits, entanglement=entanglement, reps=reps)

basis_gates = ['u', 'cx'] 
# 2. Transpile the circuit to decompose it into the basis gates.
expanded_ansatz = transpile(
    ansatz, 
    basis_gates = basis_gates, 
    optimization_level = 0  # Set to 0 to minimize changes beyond decomposition
)

# To run on hardware, select the backend with the fewest number of jobs in the queue
backend = AerSimulator()
#backend = service.least_busy(operational=True, simulator=False)
expanded_ansatz.draw()
# Out:
# C:\Users\ssromerogon\AppData\Local\Temp\ipykernel_35520\4128365459.py:14: DeprecationWarning: The class ``qiskit.circuit.library.n_local.efficient_su2.EfficientSU2`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.efficient_su2 instead.
#   ansatz = EfficientSU2( num_qubits=num_qubits, entanglement=entanglement, reps=reps)
# global phase: -θ[30]/2 - θ[31]/2 - θ[32]/2 - θ[33]/2 - θ[34]/2 - θ[35]/2 - θ[36]/2 - θ[37]/2 - θ[38]/2 - θ[39]/2 - θ[40]/2 - θ[41]/2 - θ[42]/2 - θ[43]/2 - θ[44]/2 - θ[45]/2 - θ[46]/2 - θ[47]/2 - θ[48]/2 - θ[49]/2 - θ[50]/2 - θ[51]/2 - θ[52]/2 - θ[53]/2 - θ[54]/2 - θ[55]/2 - θ[56]/2 - θ[57]/2 - θ[58]/2 - θ[59]/2 - θ[90]/2 - θ[91]/2 - θ[92]/2 - θ[93]/2 - θ[94]/2 - θ[95]/2 - θ[96]/2 - θ[97]/2 - θ[98]/2 - θ[99]/2 - θ[100]/2 - θ[101]/2 - θ[102]/2 - θ[103]/2 - θ[104]/2 - θ[105]/2 - θ[106]/2 - θ[107]/2 - θ[108]/2 - θ[109]/2 - θ[110]/2 - θ[111]/2 - θ[112]/2 - θ[113]/2 - θ[114]/2 - θ[115]/2 - θ[116]/2 - θ[117]/2 - θ[118]/2 - θ[119]/2
#       ┌─────────────┐ ┌──────────────┐┌───┐     ┌──────────────┐»
#  q_0: ┤ U(θ[0],0,0) ├─┤ U(0,0,θ[30]) ├┤ X ├──■──┤ U(θ[60],0,0) ├»
#       ├─────────────┤ ├──────────────┤└─┬─┘┌─┴─┐└──────────────┘»
#  q_1: ┤ U(θ[1],0,0) ├─┤ U(0,0,θ[31]) ├──┼──┤ X ├───────■────────»
#       ├─────────────┤ ├──────────────┤  │  └───┘     ┌─┴─┐      »
#  q_2: ┤ U(θ[2],0,0) ├─┤ U(0,0,θ[32]) ├──┼────────────┤ X ├──────»
#       ├─────────────┤ ├──────────────┤  │            └───┘      »
#  q_3: ┤ U(θ[3],0,0) ├─┤ U(0,0,θ[33]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_4: ┤ U(θ[4],0,0) ├─┤ U(0,0,θ[34]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_5: ┤ U(θ[5],0,0) ├─┤ U(0,0,θ[35]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_6: ┤ U(θ[6],0,0) ├─┤ U(0,0,θ[36]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_7: ┤ U(θ[7],0,0) ├─┤ U(0,0,θ[37]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_8: ┤ U(θ[8],0,0) ├─┤ U(0,0,θ[38]) ├──┼───────────────────────»
#       ├─────────────┤ ├──────────────┤  │                       »
#  q_9: ┤ U(θ[9],0,0) ├─┤ U(0,0,θ[39]) ├──┼───────────────────────»
#       ├─────────────┴┐├──────────────┤  │                       »
# q_10: ┤ U(θ[10],0,0) ├┤ U(0,0,θ[40]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_11: ┤ U(θ[11],0,0) ├┤ U(0,0,θ[41]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_12: ┤ U(θ[12],0,0) ├┤ U(0,0,θ[42]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_13: ┤ U(θ[13],0,0) ├┤ U(0,0,θ[43]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_14: ┤ U(θ[14],0,0) ├┤ U(0,0,θ[44]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_15: ┤ U(θ[15],0,0) ├┤ U(0,0,θ[45]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_16: ┤ U(θ[16],0,0) ├┤ U(0,0,θ[46]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_17: ┤ U(θ[17],0,0) ├┤ U(0,0,θ[47]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_18: ┤ U(θ[18],0,0) ├┤ U(0,0,θ[48]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_19: ┤ U(θ[19],0,0) ├┤ U(0,0,θ[49]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_20: ┤ U(θ[20],0,0) ├┤ U(0,0,θ[50]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_21: ┤ U(θ[21],0,0) ├┤ U(0,0,θ[51]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_22: ┤ U(θ[22],0,0) ├┤ U(0,0,θ[52]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_23: ┤ U(θ[23],0,0) ├┤ U(0,0,θ[53]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_24: ┤ U(θ[24],0,0) ├┤ U(0,0,θ[54]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_25: ┤ U(θ[25],0,0) ├┤ U(0,0,θ[55]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_26: ┤ U(θ[26],0,0) ├┤ U(0,0,θ[56]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_27: ┤ U(θ[27],0,0) ├┤ U(0,0,θ[57]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_28: ┤ U(θ[28],0,0) ├┤ U(0,0,θ[58]) ├──┼───────────────────────»
#       ├──────────────┤├──────────────┤  │                       »
# q_29: ┤ U(θ[29],0,0) ├┤ U(0,0,θ[59]) ├──■───────────────────────»
#       └──────────────┘└──────────────┘                          »
# «      ┌──────────────┐                                                »
# « q_0: ┤ U(0,0,θ[90]) ├────────────────────────────────────────────────»
# «      ├──────────────┤┌──────────────┐                                »
# « q_1: ┤ U(θ[61],0,0) ├┤ U(0,0,θ[91]) ├────────────────────────────────»
# «      └──────────────┘├──────────────┤┌──────────────┐                »
# « q_2: ───────■────────┤ U(θ[62],0,0) ├┤ U(0,0,θ[92]) ├────────────────»
# «           ┌─┴─┐      └──────────────┘├──────────────┤┌──────────────┐»
# « q_3: ─────┤ X ├─────────────■────────┤ U(θ[63],0,0) ├┤ U(0,0,θ[93]) ├»
# «           └───┘           ┌─┴─┐      └──────────────┘├──────────────┤»
# « q_4: ─────────────────────┤ X ├─────────────■────────┤ U(θ[64],0,0) ├»
# «                           └───┘           ┌─┴─┐      └──────────────┘»
# « q_5: ─────────────────────────────────────┤ X ├─────────────■────────»
# «                                           └───┘           ┌─┴─┐      »
# « q_6: ─────────────────────────────────────────────────────┤ X ├──────»
# «                                                           └───┘      »
# « q_7: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# « q_8: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# « q_9: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_10: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_11: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_12: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_13: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_14: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_15: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_16: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_17: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_18: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_19: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_20: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_21: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_22: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_23: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_24: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_25: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_26: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_27: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_28: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_29: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                      »
# « q_0: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# « q_1: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# « q_2: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# « q_3: ────────────────────────────────────────────────────────────────»
# «      ┌──────────────┐                                                »
# « q_4: ┤ U(0,0,θ[94]) ├────────────────────────────────────────────────»
# «      ├──────────────┤┌──────────────┐                                »
# « q_5: ┤ U(θ[65],0,0) ├┤ U(0,0,θ[95]) ├────────────────────────────────»
# «      └──────────────┘├──────────────┤┌──────────────┐                »
# « q_6: ───────■────────┤ U(θ[66],0,0) ├┤ U(0,0,θ[96]) ├────────────────»
# «           ┌─┴─┐      └──────────────┘├──────────────┤┌──────────────┐»
# « q_7: ─────┤ X ├─────────────■────────┤ U(θ[67],0,0) ├┤ U(0,0,θ[97]) ├»
# «           └───┘           ┌─┴─┐      └──────────────┘├──────────────┤»
# « q_8: ─────────────────────┤ X ├─────────────■────────┤ U(θ[68],0,0) ├»
# «                           └───┘           ┌─┴─┐      └──────────────┘»
# « q_9: ─────────────────────────────────────┤ X ├─────────────■────────»
# «                                           └───┘           ┌─┴─┐      »
# «q_10: ─────────────────────────────────────────────────────┤ X ├──────»
# «                                                           └───┘      »
# «q_11: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_12: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_13: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_14: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_15: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_16: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_17: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_18: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_19: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_20: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_21: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_22: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_23: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_24: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_25: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_26: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_27: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_28: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_29: ────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                        »
# « q_0: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_1: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_2: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_3: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_4: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_5: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_6: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_7: ──────────────────────────────────────────────────────────────────»
# «      ┌──────────────┐                                                  »
# « q_8: ┤ U(0,0,θ[98]) ├──────────────────────────────────────────────────»
# «      ├──────────────┤┌──────────────┐                                  »
# « q_9: ┤ U(θ[69],0,0) ├┤ U(0,0,θ[99]) ├──────────────────────────────────»
# «      └──────────────┘├──────────────┤┌───────────────┐                 »
# «q_10: ───────■────────┤ U(θ[70],0,0) ├┤ U(0,0,θ[100]) ├─────────────────»
# «           ┌─┴─┐      └──────────────┘└┬──────────────┤┌───────────────┐»
# «q_11: ─────┤ X ├─────────────■─────────┤ U(θ[71],0,0) ├┤ U(0,0,θ[101]) ├»
# «           └───┘           ┌─┴─┐       └──────────────┘└┬──────────────┤»
# «q_12: ─────────────────────┤ X ├──────────────■─────────┤ U(θ[72],0,0) ├»
# «                           └───┘            ┌─┴─┐       └──────────────┘»
# «q_13: ──────────────────────────────────────┤ X ├──────────────■────────»
# «                                            └───┘            ┌─┴─┐      »
# «q_14: ───────────────────────────────────────────────────────┤ X ├──────»
# «                                                             └───┘      »
# «q_15: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_16: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_17: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_18: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_19: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_20: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_21: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_22: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_23: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_24: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_25: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_26: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_27: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_28: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_29: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ────────────────────────────────────────────────────────────────────»
# «      ┌───────────────┐                                                   »
# «q_12: ┤ U(0,0,θ[102]) ├───────────────────────────────────────────────────»
# «      └┬──────────────┤┌───────────────┐                                  »
# «q_13: ─┤ U(θ[73],0,0) ├┤ U(0,0,θ[103]) ├──────────────────────────────────»
# «       └──────────────┘└┬──────────────┤┌───────────────┐                 »
# «q_14: ────────■─────────┤ U(θ[74],0,0) ├┤ U(0,0,θ[104]) ├─────────────────»
# «            ┌─┴─┐       └──────────────┘└┬──────────────┤┌───────────────┐»
# «q_15: ──────┤ X ├──────────────■─────────┤ U(θ[75],0,0) ├┤ U(0,0,θ[105]) ├»
# «            └───┘            ┌─┴─┐       └──────────────┘└┬──────────────┤»
# «q_16: ───────────────────────┤ X ├──────────────■─────────┤ U(θ[76],0,0) ├»
# «                             └───┘            ┌─┴─┐       └──────────────┘»
# «q_17: ────────────────────────────────────────┤ X ├──────────────■────────»
# «                                              └───┘            ┌─┴─┐      »
# «q_18: ─────────────────────────────────────────────────────────┤ X ├──────»
# «                                                               └───┘      »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_20: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_21: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_22: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_23: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_24: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_25: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_26: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_27: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_28: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_29: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_12: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_13: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_14: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_15: ────────────────────────────────────────────────────────────────────»
# «      ┌───────────────┐                                                   »
# «q_16: ┤ U(0,0,θ[106]) ├───────────────────────────────────────────────────»
# «      └┬──────────────┤┌───────────────┐                                  »
# «q_17: ─┤ U(θ[77],0,0) ├┤ U(0,0,θ[107]) ├──────────────────────────────────»
# «       └──────────────┘└┬──────────────┤┌───────────────┐                 »
# «q_18: ────────■─────────┤ U(θ[78],0,0) ├┤ U(0,0,θ[108]) ├─────────────────»
# «            ┌─┴─┐       └──────────────┘└┬──────────────┤┌───────────────┐»
# «q_19: ──────┤ X ├──────────────■─────────┤ U(θ[79],0,0) ├┤ U(0,0,θ[109]) ├»
# «            └───┘            ┌─┴─┐       └──────────────┘└┬──────────────┤»
# «q_20: ───────────────────────┤ X ├──────────────■─────────┤ U(θ[80],0,0) ├»
# «                             └───┘            ┌─┴─┐       └──────────────┘»
# «q_21: ────────────────────────────────────────┤ X ├──────────────■────────»
# «                                              └───┘            ┌─┴─┐      »
# «q_22: ─────────────────────────────────────────────────────────┤ X ├──────»
# «                                                               └───┘      »
# «q_23: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_24: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_25: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_26: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_27: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_28: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_29: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_12: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_13: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_14: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_15: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_16: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_17: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_18: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «      ┌───────────────┐                                                   »
# «q_20: ┤ U(0,0,θ[110]) ├───────────────────────────────────────────────────»
# «      └┬──────────────┤┌───────────────┐                                  »
# «q_21: ─┤ U(θ[81],0,0) ├┤ U(0,0,θ[111]) ├──────────────────────────────────»
# «       └──────────────┘└┬──────────────┤┌───────────────┐                 »
# «q_22: ────────■─────────┤ U(θ[82],0,0) ├┤ U(0,0,θ[112]) ├─────────────────»
# «            ┌─┴─┐       └──────────────┘└┬──────────────┤┌───────────────┐»
# «q_23: ──────┤ X ├──────────────■─────────┤ U(θ[83],0,0) ├┤ U(0,0,θ[113]) ├»
# «            └───┘            ┌─┴─┐       └──────────────┘└┬──────────────┤»
# «q_24: ───────────────────────┤ X ├──────────────■─────────┤ U(θ[84],0,0) ├»
# «                             └───┘            ┌─┴─┐       └──────────────┘»
# «q_25: ────────────────────────────────────────┤ X ├──────────────■────────»
# «                                              └───┘            ┌─┴─┐      »
# «q_26: ─────────────────────────────────────────────────────────┤ X ├──────»
# «                                                               └───┘      »
# «q_27: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_28: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_29: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_12: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_13: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_14: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_15: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_16: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_17: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_18: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_20: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_21: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_22: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_23: ────────────────────────────────────────────────────────────────────»
# «      ┌───────────────┐                                                   »
# «q_24: ┤ U(0,0,θ[114]) ├───────────────────────────────────────────────────»
# «      └┬──────────────┤┌───────────────┐                                  »
# «q_25: ─┤ U(θ[85],0,0) ├┤ U(0,0,θ[115]) ├──────────────────────────────────»
# «       └──────────────┘└┬──────────────┤┌───────────────┐                 »
# «q_26: ────────■─────────┤ U(θ[86],0,0) ├┤ U(0,0,θ[116]) ├─────────────────»
# «            ┌─┴─┐       └──────────────┘└┬──────────────┤┌───────────────┐»
# «q_27: ──────┤ X ├──────────────■─────────┤ U(θ[87],0,0) ├┤ U(0,0,θ[117]) ├»
# «            └───┘            ┌─┴─┐       └──────────────┘└┬──────────────┤»
# «q_28: ───────────────────────┤ X ├──────────────■─────────┤ U(θ[88],0,0) ├»
# «                             └───┘            ┌─┴─┐       ├──────────────┤»
# «q_29: ────────────────────────────────────────┤ X ├───────┤ U(θ[89],0,0) ├»
# «                                              └───┘       └──────────────┘»
# «
# « q_0: ─────────────────
# «
# « q_1: ─────────────────
# «
# « q_2: ─────────────────
# «
# « q_3: ─────────────────
# «
# « q_4: ─────────────────
# «
# « q_5: ─────────────────
# «
# « q_6: ─────────────────
# «
# « q_7: ─────────────────
# «
# « q_8: ─────────────────
# «
# « q_9: ─────────────────
# «
# «q_10: ─────────────────
# «
# «q_11: ─────────────────
# «
# «q_12: ─────────────────
# «
# «q_13: ─────────────────
# «
# «q_14: ─────────────────
# «
# «q_15: ─────────────────
# «
# «q_16: ─────────────────
# «
# «q_17: ─────────────────
# «
# «q_18: ─────────────────
# «
# «q_19: ─────────────────
# «
# «q_20: ─────────────────
# «
# «q_21: ─────────────────
# «
# «q_22: ─────────────────
# «
# «q_23: ─────────────────
# «
# «q_24: ─────────────────
# «
# «q_25: ─────────────────
# «
# «q_26: ─────────────────
# «
# «q_27: ─────────────────
# «      ┌───────────────┐
# «q_28: ┤ U(0,0,θ[118]) ├
# «      ├───────────────┤
# «q_29: ┤ U(0,0,θ[119]) ├
# «      └───────────────┘

# %%
from quantum_functions import vqe_solver
result, optimized_params, cost_values = vqe_solver(
    expanded_ansatz,
    hamiltonian,
    backend,
    optimizer_method="COBYLA", # COBYLA | L-BFGS-B 
    niter= 200
)

# Plot the cost function values
plt.figure(figsize=(5, 4))
plt.plot(cost_values)
plt.xlabel("Optimization Iteration")
plt.ylabel("Cost Function Value (Energy)")
plt.title("Energy Minimization Curve")
plt.grid(True)
plt.tight_layout()
#plt.savefig('vqe_opt_curve_qmat.svg', bbox_inches='tight')
plt.show()
# Out:
# Starting optimization with method: COBYLA
# Iteration 0: Current cost: -0.03500687076170307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 from quantum_functions import vqe_solver
# ----> 2 result, optimized_params, cost_values = vqe_solver(
#       3     expanded_ansatz,
#       4     hamiltonian,
#       5     backend,
#       6     optimizer_method="COBYLA", # COBYLA | L-BFGS-B
#       7     niter= 200
#       8 )
#      10 # Plot the cost function values
#      11 plt.figure(figsize=(5, 4))
#
# File ~\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions\quantum_functions.py:1806, in vqe_solver(ansatz, hamiltonian, backend, optimizer_method, niter)
#    1804 # 6. Call minimize with args
#    1805 print(f"Starting optimization with method: {optimizer_method}")
# -> 1806 result_interaction = minimize(
#    1807     cost_func_wrapper,
#    1808     x0_interaction,
#    1809     # IMPORTANT: Pass static_params and variable_param_objects as fixed arguments
#    1810     # The cost_func_wrapper will use xk (the first argument) with these to bind parameters.
#    1811     args=(ansatz_isa, hamiltonian, estimator),
#    1812     method=optimizer_method, # Use the passed optimizer_method
#    1813     callback=callback_func, # Use the defined callback function
#    1814     options=options,
#    1815 )
#    1817 print("\nOptimization Result:")
#    1818 print(result_interaction)
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions\quantum_functions.py:1784, in vqe_solver.<locals>.cost_func_wrapper(xk, ansatz, hamiltonian, estimator)
#    1783 def cost_func_wrapper(xk, ansatz, hamiltonian, estimator):
# -> 1784     return  cost_func_vqe(xk, ansatz, hamiltonian, estimator)
#
# File ~\Documents\vscode_working_dir\QuantumXCT\python\cc_grn_functions\quantum_functions.py:1778, in vqe_solver.<locals>.cost_func_vqe(params, ansatz, hamiltonian, estimator)
#    1766 """Return estimate of energy from estimator
#    1767 Parameters:
#    1768     params (ndarray): Array of ansatz parameters
#    (...)
#    1775     float: Energy estimate
#    1776 """
#    1777 pub = (ansatz, [hamiltonian], [params])
# -> 1778 result = estimator.run(pubs=[pub]).result()
#    1779 energy = result[0].data.evs[0]
#    1781 return energy
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\site-packages\qiskit\primitives\primitive_job.py:65, in PrimitiveJob.result(self)
#      63 if self._result is None:
#      64     self._check_submitted()
# ---> 65     self._result = self._future.result()
#      66 return self._result
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File c:\Local_install\miniconda3\envs\qiskit-env\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
from quantum_functions import evaluate_and_plot_ansatz

counts, bound_circuit = evaluate_and_plot_ansatz(
    ansatz=expanded_ansatz, 
    params=optimized_params, 
    backend=backend,
    shots=1024,
    title="VQE Opt. Histogram for QUBO",
    show_plot=True  # Explicitly show the plot
)
#bound_circuit.draw(output="mpl", style="clifford", fold=40)  # Show the circuit plot

# %%
# ==============================================================================
# --- CALL THE VQE HYBRID SEARCH AND DISPLAY RESULTS ---
# ==============================================================================
from quantum_functions import run_vqe_hybrid_search
# Assume these variables are defined from your previous notebook cells:
# - counts: The dictionary of measurement results from your VQE run.
# - initial_cnot_config: The full list of CNOT candidates used for the VQE QUBO.
# - circ1, circ2: Your two base quantum circuits.
# - normalized_joint_counts_ct1_mo, normalized_joint_counts_ct2_mo: Initial states.
# - normalized_joint_counts_ct1_co, normalized_joint_counts_ct2_co: Target states.
# - thresh: The threshold for density matrix analysis (if used).

# Call the main search function
best_cnot_sequence, min_kl_sum, best_solution_rank = run_vqe_hybrid_search(
    vqe_counts=counts,
    initial_cnot_config=initial_cnot_config,
    circ1=circ1,
    circ2=circ2,
    state_probs_initial1=normalized_joint_counts_ct1_mo,
    state_probs_initial2=normalized_joint_counts_ct2_mo,
    state_vec_probs_target1=normalized_joint_counts_ct1_co,
    state_vec_probs_target2=normalized_joint_counts_ct2_co,
    num_solutions_to_test=3,
    nshots=5000,
    threshold=thresh,
    search_mode="pos",
    kl_tol=0.1,
    ratio_kl_tol=0.6,
    max_greedy_depth=30
)

# --- FINAL SUMMARY: Display the Overall Best Solution ---
print("\n" + "="*60)
print("--- OVERALL BEST SOLUTION AFTER HYBRID SEARCH ---")
print("="*60)

if best_solution_rank is not None:
    print(f"The best solution originated from the VQE's result at Rank {best_solution_rank}.")
    print(f"\nFinal optimal CNOT sequence found with {len(best_cnot_sequence)} CNOTs:")
    if best_cnot_sequence:
        for cnot in best_cnot_sequence:
            print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    else:
        print("  (The best solution found was to use no CNOTs)")

    print(f"\nWith a minimum combined KL Divergence of: {min_kl_sum:.6f}")

    # Re-create and draw the final, absolute best circuit
    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("No VQE solution led to a greedy search result that improved upon the initial baseline.")
    print("The best configuration is the baseline circuit with no CNOTs.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))

print("="*60 + "\n")
# Out:
# ============================================================
# --- Preparing to test Top 3 VQE solutions in REVERSE order ---
# ============================================================
#
# --- Testing VQE Solution (Rank 3/3) ---
# This VQE Solution corresponds to a candidate subset of 4 CNOTs:
#   q[0] -> q[3]
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 4 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 4
# Initial KL divergence (baseline): 4.772028
#
# --- Starting Epoch 1/4 (Addition) with CNOT: (3, 0) (KL: 3.718154) ---
#     --> Found a better KL on this path: 3.291250 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.109045 at depth 3 with added CNOT (3, 6)
#   Epoch 1 best KL Sum: 1.109045
#   --> Epoch 1 found a new overall best KL Sum: 1.109045
#
# --- Starting Epoch 2/4 (Addition) with CNOT: (3, 4) (KL: 4.377288) ---
#     --> Found a better KL on this path: 2.155265 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.035514 at depth 3 with added CNOT (3, 0)
#   Epoch 2 best KL Sum: 1.035514
#   --> Epoch 2 found a new overall best KL Sum: 1.035514
#
# --- Starting Epoch 3/4 (Addition) with CNOT: (3, 6) (KL: 4.870995) ---
#   Skipping epoch: Single CNOT KL (4.870995) does not improve over baseline (4.772028).
#
# --- Starting Epoch 4/4 (Addition) with CNOT: (0, 3) (KL: 4.798578) ---
#   Skipping epoch: Single CNOT KL (4.798578) does not improve over baseline (4.772028).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.035514)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 3.39 seconds.
#
# Result for (Rank 3): Final KL Sum = 1.035514
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.035514
#   Origin: VQE solution at rank 3
#
# --- Testing VQE Solution (Rank 2/3) ---
# This VQE Solution corresponds to a candidate subset of 3 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 3 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 3
# Initial KL divergence (baseline): 4.717957
#
# --- Starting Epoch 1/3 (Addition) with CNOT: (3, 0) (KL: 3.695946) ---
#     --> Found a better KL on this path: 3.254132 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.049776 at depth 3 with added CNOT (3, 6)
#   Epoch 1 best KL Sum: 1.049776
#   --> Epoch 1 found a new overall best KL Sum: 1.049776
#
# --- Starting Epoch 2/3 (Addition) with CNOT: (3, 4) (KL: 4.373700) ---
#     --> Found a better KL on this path: 2.185265 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.074147 at depth 3 with added CNOT (3, 0)
#   Epoch 2 best KL Sum: 1.074147
#
# --- Starting Epoch 3/3 (Addition) with CNOT: (3, 6) (KL: 4.837115) ---
#   Skipping epoch: Single CNOT KL (4.837115) does not improve over baseline (4.717957).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.049776)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 2.22 seconds.
#
# Result for (Rank 2): Final KL Sum = 1.049776
#   This result (1.049776) did not beat the current best (1.035514).
#
# --- Testing VQE Solution (Rank 1/3) ---
# This VQE Solution corresponds to a candidate subset of 6 CNOTs:
#   q[0] -> q[3]
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[4] -> q[3]
#   q[6] -> q[3]
#
# Setting number of greedy search epochs to 6 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 6
# Initial KL divergence (baseline): 4.759051
#
# --- Starting Epoch 1/6 (Addition) with CNOT: (0, 3) (KL: 4.817690) ---
#   Skipping epoch: Single CNOT KL (4.817690) does not improve over baseline (4.759051).
#
# --- Starting Epoch 2/6 (Addition) with CNOT: (4, 3) (KL: 4.774096) ---
#   Skipping epoch: Single CNOT KL (4.774096) does not improve over baseline (4.759051).
#
# --- Starting Epoch 3/6 (Addition) with CNOT: (3, 6) (KL: 4.914878) ---
#   Skipping epoch: Single CNOT KL (4.914878) does not improve over baseline (4.759051).
#
# --- Starting Epoch 4/6 (Addition) with CNOT: (3, 0) (KL: 3.705690) ---
#     --> Found a better KL on this path: 3.268805 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.037700 at depth 3 with added CNOT (3, 6)
#   Epoch 4 best KL Sum: 1.037700
#   --> Epoch 4 found a new overall best KL Sum: 1.037700
#
# --- Starting Epoch 5/6 (Addition) with CNOT: (3, 4) (KL: 4.331219) ---
#     --> Found a better KL on this path: 2.159180 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.038532 at depth 3 with added CNOT (3, 0)
#   Epoch 5 best KL Sum: 1.038532
#
# --- Starting Epoch 6/6 (Addition) with CNOT: (6, 3) (KL: 4.825340) ---
#   Skipping epoch: Single CNOT KL (4.825340) does not improve over baseline (4.759051).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.037700)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 5.94 seconds.
#
# Result for (Rank 1): Final KL Sum = 1.037700
#   This result (1.037700) did not beat the current best (1.035514).
#
# ============================================================
# --- OVERALL BEST SOLUTION AFTER HYBRID SEARCH ---
# ============================================================
# The best solution originated from the VQE's result at Rank 3.
#
# Final optimal CNOT sequence found with 3 CNOTs:
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[3] -> q[0]
#
# With a minimum combined KL Divergence of: 1.035514
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 4/»
#               »
# c_measure2: 3/»
#               »
# «              ┌──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_0: ┤0                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_1: ┤1                                                                                                                                                     ├»
# «              │  Initialize(0.22375,0.014855,0.021354,0,0.020425,0.00092842,0.067775,0.0064989,0.91357,0.0882,0.083558,0.0046421,0.075202,0.011141,0.29709,0.027853) │»
# «         q_2: ┤2                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_3: ┤3                                                                                                                                                     ├»
# «              └────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────┘»
# «         q_4: ─────────────────────────────────────┤0                                                                           ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_5: ─────────────────────────────────────┤1 Initialize(0.97212,0.085592,0.19832,0.022268,0.086287,0.01183,0.015309,0) ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_6: ─────────────────────────────────────┤2                                                                           ├─────────────────────────────────────»
# «                                                   └────────────────────────────────────────────────────────────────────────────┘                                     »
# «c_measure1: 4/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «c_measure2: 3/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «                              ┌───┐   ┌─┐
# «         q_0: ────────────────┤ X ├───┤M├───
# «                   ┌─┐        └─┬─┘   └╥┘
# «         q_1: ─────┤M├──────────┼──────╫────
# «                   └╥┘┌─┐       │      ║
# «         q_2: ──────╫─┤M├───────┼──────╫────
# «                    ║ └╥┘       │      ║ ┌─┐
# «         q_3: ──■───╫──╫───■────■──────╫─┤M├
# «              ┌─┴─┐ ║  ║   │   ┌─┐     ║ └╥┘
# «         q_4: ┤ X ├─╫──╫───┼───┤M├─────╫──╫─
# «              └┬─┬┘ ║  ║   │   └╥┘     ║  ║
# «         q_5: ─┤M├──╫──╫───┼────╫──────╫──╫─
# «               └╥┘  ║  ║ ┌─┴─┐  ║  ┌─┐ ║  ║
# «         q_6: ──╫───╫──╫─┤ X ├──╫──┤M├─╫──╫─
# «                ║   ║  ║ └───┘  ║  └╥┘ ║  ║
# «c_measure1: 4/══╬═══╩══╩════════╬═══╬══╩══╩═
# «                ║   1  2        ║   ║  0  3
# «c_measure2: 3/══╩═══════════════╩═══╩═══════
# «                1               0   2
# ============================================================

# %%
# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_best_circuit_search, nshots=5000, title_prefix="VQE + Epoch search Optimized Circuit")
final_best_circuit_search
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=1.2)
# Out:
# --- Running circuit for: VQE + Epoch search Optimized Circuit ---
# Counts for c_measure1: {'1001': 4208, '1111': 424, '0000': 241, '0110': 22, '1101': 23, '1011': 38, '1110': 4, '1000': 33, '0010': 2, '0100': 5}
# Counts for c_measure2: {'101': 4482, '111': 186, '000': 259, '001': 25, '100': 33, '010': 9, '110': 3, '011': 3}

# %%
# ==============================================================================
# --- STAGE 1: RUN QAOA TO GET CANDIDATE SOLUTIONS ---
# ==============================================================================
# This is your existing QAOA setup code
import numpy as np
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.algorithms import (
    MinimumEigenOptimizer,
    OptimizationResultStatus,
    RecursiveMinimumEigenOptimizer,
    SolutionSample,
)
from qiskit_optimization.minimum_eigensolvers import QAOA, NumPyMinimumEigensolver
from qiskit_optimization.optimizers import COBYLA
from qiskit_optimization.utils import algorithm_globals
num_qubits = kl_div_mat_qubo.shape[0]
# --- 1. Define the Quadratic Program (QUBO) ---
qp = QuadraticProgram(name="CnotOptimization")
# Add binary variables: one for each CNOT candidate (0 to 41)
for i in range(num_qubits):
    qp.binary_var(name=f'x{i}')
qp.minimize(quadratic=kl_div_mat_qubo)
# kl_vec = np.diag(kl_div_mat_qubo).copy()
# np.fill_diagonal(kl_div_mat_qubo, 0.0)
#qp.minimize(quadratic=kl_div_mat_qubo, linear=kl_vec)
op, offset = qp.to_ising()
print("offset: {}".format(offset))
print(qp.prettyprint())
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import SamplerV2
algorithm_globals.random_seed = 10598
pass_manager = generate_preset_pass_manager(optimization_level=2, backend=AerSimulator())
qaoa_set = QAOA(
    sampler=SamplerV2(seed=123, default_shots=2000),
    optimizer=COBYLA(maxiter=200),
    initial_point=[1, 1],
    pass_manager=pass_manager,
    reps=1
)
meo_set = MinimumEigenOptimizer(qaoa_set)
qaoa_result = meo_set.solve(qp)
print(qaoa_result.prettyprint())
# Out:
# offset: -1.2286898002604456
# Problem name: CnotOptimization
#
# Minimize
#   -0.04498941997598216*x0^2 + 0.06716818733505026*x0*x1
#   - 0.020838611857410427*x0*x2 + 0.04851631623977326*x0*x3
#   + 0.09227350411036195*x0*x4 + 0.1460788495363996*x0*x5
#   - 1.0246668767873919*x1^2 - 0.05702844639295135*x1*x2
#   - 0.10858539825283753*x1*x3 - 0.11073910222129868*x1*x4
#   + 0.020767292569592755*x1*x5 - 0.4225514457390034*x2^2
#   - 2.357159444827426*x2*x3 + 0.0005864312608006017*x2*x4
#   - 0.0005725267407354906*x2*x5 + 0.1458257625969921*x3^2
#   - 0.02672827448260673*x3*x4 + 0.013990034903336834*x3*x5
#   + 0.05546157665515761*x4^2 - 0.013892389648062498*x4*x5
#   - 0.013377408036657101*x5^2
#
# Subject to
#   No constraints
#
#   Binary variables (6)
#     x0 x1 x2 x3 x4 x5
#
# objective function value: -3.905585218190565
# variable values: x0=0.0, x1=1.0, x2=1.0, x3=1.0, x4=1.0, x5=0.0
# status: SUCCESS

# %%
# CORRECTED HELPER FUNCTION
from qiskit_optimization.algorithms import SolutionSample 
from typing import List, Dict

def convert_qaoa_samples_to_counts(
    samples: List[SolutionSample], 
    total_shots_equivalent: int = 10000
) -> Dict[str, int]:
    """
    Converts a list of QAOA SolutionSample objects into a VQE-style counts dictionary.

    This is necessary to use the QAOA results with functions designed for VQE/Sampler output.
    It preserves the relative probabilities of the solutions by converting them to integer counts.

    Args:
        samples (List[SolutionSample]): The list of samples from a Qiskit Optimization result.
        total_shots_equivalent (int): A scaling factor to convert probabilities into
                                      integer counts. The exact value doesn't matter as
                                      long as it preserves the order.

    Returns:
        Dict[str, int]: A dictionary where keys are big-endian bitstrings and values are
                        the corresponding "counts", compatible with the hybrid search function.
    """
    qaoa_counts = {}
    for s in samples:
        # QAOA sample.x is an array like [1., 0., 1.]. Convert to a string '101'.
        # We reverse it to create a big-endian string '101' -> ...x2x1x0, which is
        # a common Qiskit convention and consistent with our VQE helpers.
        bitstring = "".join(str(int(v)) for v in reversed(s.x))
        
        # Convert the solution's probability to an integer count
        count = int(s.probability * total_shots_equivalent)
        
        # Only add solutions with a non-zero chance
        if count > 0:
            qaoa_counts[bitstring] = count
            
    return qaoa_counts

# %%
# ==============================================================================
# --- STAGE 2: CONVERT QAOA RESULTS AND RUN HYBRID SEARCH ---
# ==============================================================================

# 1. Convert the QAOA samples list into a VQE-style counts dictionary
qaoa_counts = convert_qaoa_samples_to_counts(qaoa_result.samples)
print(f"\nConverted QAOA results into a counts dictionary with {len(qaoa_counts)} entries.")

# 2. Call the main hybrid search function, using the QAOA counts as input
best_cnot_sequence, min_kl_sum, best_solution_rank = run_vqe_hybrid_search(
    vqe_counts=qaoa_counts,  # <-- Using the converted QAOA results here!
    initial_cnot_config=initial_cnot_config,
    circ1=circ1,
    circ2=circ2,
    state_probs_initial1=normalized_joint_counts_ct1_mo,
    state_probs_initial2=normalized_joint_counts_ct2_mo,
    state_vec_probs_target1=normalized_joint_counts_ct1_co,
    state_vec_probs_target2=normalized_joint_counts_ct2_co,
    num_solutions_to_test=3,  # We will test the top 3 solutions from QAOA
    nshots=5000,
    threshold=thresh,
    kl_tol=0.1,
    ratio_kl_tol=0.6,
    max_greedy_depth=30,
    min_cnot_depth=1 # You can adjust this as needed
)

# ==============================================================================
# --- STAGE 3: DISPLAY THE FINAL, OVERALL BEST SOLUTION ---
# ==============================================================================
print("\n" + "="*60)
print("--- OVERALL BEST SOLUTION AFTER QAOA + HYBRID SEARCH ---")
print("="*60)

if best_solution_rank is not None:
    print(f"The best solution originated from the QAOA's result at Rank {best_solution_rank}.")
    print(f"\nFinal optimal CNOT sequence found with {len(best_cnot_sequence)} CNOTs:")
    if best_cnot_sequence:
        for cnot in best_cnot_sequence:
            print(f"  q[{cnot[0]}] -> q[{cnot[1]}]")
    else:
        print("  (The best solution found was to use no CNOTs)")

    print(f"\nWith a minimum combined KL Divergence of: {min_kl_sum:.6f}")

    ng_circ1_for_search = circ1.num_qubits
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, ng_circ1_for_search, best_cnot_sequence
    )
    print("\n--- Final Optimized Circuit ---")
    print(final_best_circuit_search.draw('text'))
else:
    print("No QAOA solution led to a greedy search result that improved upon the initial baseline.")
    print("The best configuration is the baseline circuit with no CNOTs.")
    print(f"Baseline KL Divergence: {min_kl_sum:.6f}")
    base_combined_circuit_search = concatenate_circuits_with_separate_measurements(circ1, circ2)
    final_best_circuit_search = add_cnots_and_measurements_to_circuit(
        base_combined_circuit_search, circ1.num_qubits, []
    )
    print("\n--- Baseline Circuit (No CNOTs) ---")
    print(final_best_circuit_search.draw('text'))

print("="*60 + "\n")
# Out:
# Converted QAOA results into a counts dictionary with 50 entries.
# ============================================================
# --- Preparing to test Top 3 VQE solutions in REVERSE order ---
# ============================================================
#
# --- Testing VQE Solution (Rank 3/3) ---
# This VQE Solution corresponds to a candidate subset of 4 CNOTs:
#   q[0] -> q[3]
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 4 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 4
# Initial KL divergence (baseline): 4.789146
#
# --- Starting Epoch 1/4 (Addition) with CNOT: (0, 3) (KL: 4.819736) ---
#   Skipping epoch: Single CNOT KL (4.819736) does not improve over baseline (4.789146).
#
# --- Starting Epoch 2/4 (Addition) with CNOT: (3, 6) (KL: 4.847292) ---
#   Skipping epoch: Single CNOT KL (4.847292) does not improve over baseline (4.789146).
#
# --- Starting Epoch 3/4 (Addition) with CNOT: (3, 4) (KL: 4.292987) ---
#     --> Found a better KL on this path: 2.183854 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.062435 at depth 3 with added CNOT (3, 0)
#   Epoch 3 best KL Sum: 1.062435
#   --> Epoch 3 found a new overall best KL Sum: 1.062435
#
# --- Starting Epoch 4/4 (Addition) with CNOT: (3, 0) (KL: 3.740064) ---
#     --> Found a better KL on this path: 3.281870 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.120152 at depth 3 with added CNOT (3, 6)
#   Epoch 4 best KL Sum: 1.120152
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.062435)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 3.52 seconds.
#
# Result for (Rank 3): Final KL Sum = 1.062435
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.062435
#   Origin: VQE solution at rank 3
#
# --- Testing VQE Solution (Rank 2/3) ---
# This VQE Solution corresponds to a candidate subset of 3 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# Setting number of greedy search epochs to 3 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 3
# Initial KL divergence (baseline): 4.820033
#
# --- Starting Epoch 1/3 (Addition) with CNOT: (3, 4) (KL: 4.295982) ---
#     --> Found a better KL on this path: 2.135486 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.128085 at depth 3 with added CNOT (3, 0)
#   Epoch 1 best KL Sum: 1.128085
#   --> Epoch 1 found a new overall best KL Sum: 1.128085
#
# --- Starting Epoch 2/3 (Addition) with CNOT: (3, 6) (KL: 4.852074) ---
#   Skipping epoch: Single CNOT KL (4.852074) does not improve over baseline (4.820033).
#
# --- Starting Epoch 3/3 (Addition) with CNOT: (3, 0) (KL: 3.660631) ---
#     --> Found a better KL on this path: 3.326624 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.097431 at depth 3 with added CNOT (3, 6)
#   Epoch 3 best KL Sum: 1.097431
#   --> Epoch 3 found a new overall best KL Sum: 1.097431
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.097431)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 2.23 seconds.
#
# Result for (Rank 2): Final KL Sum = 1.097431
#   This result (1.097431) did not beat the current best (1.062435).
#
# --- Testing VQE Solution (Rank 1/3) ---
# This VQE Solution corresponds to a candidate subset of 4 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#   q[6] -> q[3]
#
# Setting number of greedy search epochs to 4 (one for each candidate).
#
# --- Starting Multi-Epoch Refined Search ---
#
# --- Using provided CNOT candidate list for the search. ---
# Number of candidates to be searched: 4
# Initial KL divergence (baseline): 4.726786
#
# --- Starting Epoch 1/4 (Addition) with CNOT: (3, 4) (KL: 4.344885) ---
#     --> Found a better KL on this path: 2.123228 at depth 2 with added CNOT (3, 6)
#     --> Found a better KL on this path: 1.100594 at depth 3 with added CNOT (3, 0)
#   Epoch 1 best KL Sum: 1.100594
#   --> Epoch 1 found a new overall best KL Sum: 1.100594
#
# --- Starting Epoch 2/4 (Addition) with CNOT: (3, 0) (KL: 3.672662) ---
#     --> Found a better KL on this path: 3.273173 at depth 2 with added CNOT (3, 4)
#     --> Found a better KL on this path: 1.009368 at depth 3 with added CNOT (3, 6)
#   Epoch 2 best KL Sum: 1.009368
#   --> Epoch 2 found a new overall best KL Sum: 1.009368
#
# --- Starting Epoch 3/4 (Addition) with CNOT: (3, 6) (KL: 4.900948) ---
#   Skipping epoch: Single CNOT KL (4.900948) does not improve over baseline (4.726786).
#
# --- Starting Epoch 4/4 (Addition) with CNOT: (6, 3) (KL: 4.797861) ---
#   Skipping epoch: Single CNOT KL (4.797861) does not improve over baseline (4.726786).
#
# --- Starting Greedy CNOT Removal Search on Best Found Sequence ---
#   Starting removal search with 3 CNOTs (KL Sum: 1.009368)
#   No CNOT removal improved the score. Stopping removal search.
#
# Total search took: 3.56 seconds.
#
# Result for (Rank 1): Final KL Sum = 1.009368
#   >>> NEW OVERALL BEST SOLUTION FOUND! <<<
#   New best KL sum: 1.009368
#   Origin: VQE solution at rank 1
#
# ============================================================
# --- OVERALL BEST SOLUTION AFTER QAOA + HYBRID SEARCH ---
# ============================================================
# The best solution originated from the QAOA's result at Rank 1.
#
# Final optimal CNOT sequence found with 3 CNOTs:
#   q[3] -> q[0]
#   q[3] -> q[4]
#   q[3] -> q[6]
#
# With a minimum combined KL Divergence of: 1.009368
#
# --- Final Optimized Circuit ---
#               »
#          q_0: »
#               »
#          q_1: »
#               »
#          q_2: »
#               »
#          q_3: »
#               »
#          q_4: »
#               »
#          q_5: »
#               »
#          q_6: »
#               »
# c_measure1: 4/»
#               »
# c_measure2: 3/»
#               »
# «              ┌──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «         q_0: ┤0                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_1: ┤1                                                                                                                                                     ├»
# «              │  Initialize(0.22375,0.014855,0.021354,0,0.020425,0.00092842,0.067775,0.0064989,0.91357,0.0882,0.083558,0.0046421,0.075202,0.011141,0.29709,0.027853) │»
# «         q_2: ┤2                                                                                                                                                     ├»
# «              │                                                                                                                                                      │»
# «         q_3: ┤3                                                                                                                                                     ├»
# «              └────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────┘»
# «         q_4: ─────────────────────────────────────┤0                                                                           ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_5: ─────────────────────────────────────┤1 Initialize(0.97212,0.085592,0.19832,0.022268,0.086287,0.01183,0.015309,0) ├─────────────────────────────────────»
# «                                                   │                                                                            │                                     »
# «         q_6: ─────────────────────────────────────┤2                                                                           ├─────────────────────────────────────»
# «                                                   └────────────────────────────────────────────────────────────────────────────┘                                     »
# «c_measure1: 4/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «c_measure2: 3/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                                                                      »
# «              ┌───┐           ┌─┐
# «         q_0: ┤ X ├───────────┤M├──────────────
# «              └─┬─┘┌─┐        └╥┘
# «         q_1: ──┼──┤M├─────────╫───────────────
# «                │  └╥┘┌─┐      ║
# «         q_2: ──┼───╫─┤M├──────╫───────────────
# «                │   ║ └╥┘      ║         ┌─┐
# «         q_3: ──■───╫──╫───■───╫───■─────┤M├───
# «                    ║  ║ ┌─┴─┐ ║   │  ┌─┐└╥┘
# «         q_4: ──────╫──╫─┤ X ├─╫───┼──┤M├─╫────
# «               ┌─┐  ║  ║ └───┘ ║   │  └╥┘ ║
# «         q_5: ─┤M├──╫──╫───────╫───┼───╫──╫────
# «               └╥┘  ║  ║       ║ ┌─┴─┐ ║  ║ ┌─┐
# «         q_6: ──╫───╫──╫───────╫─┤ X ├─╫──╫─┤M├
# «                ║   ║  ║       ║ └───┘ ║  ║ └╥┘
# «c_measure1: 4/══╬═══╩══╩═══════╩═══════╬══╩══╬═
# «                ║   1  2       0       ║  3  ║
# «c_measure2: 3/══╩══════════════════════╩═════╩═
# «                1                      0     2
# ============================================================

# %%
# Plot histograms for the CRX optimized circuit
measure_counts1, measure_counts2 = plot_measurement_histograms(final_best_circuit_search, nshots=5000, title_prefix="VQE + Epoch search Optimized Circuit")
final_best_circuit_search
final_best_circuit_search.draw(output="mpl", style="clifford", fold=40, scale=0.5)
# Out:
# --- Running circuit for: VQE + Epoch search Optimized Circuit ---
# Counts for c_measure1: {'1001': 4227, '1000': 35, '1111': 413, '0000': 236, '0110': 23, '1011': 41, '1101': 19, '1110': 2, '0001': 2, '0100': 2}
# Counts for c_measure2: {'101': 4496, '000': 245, '111': 177, '100': 41, '001': 28, '010': 11, '011': 1, '110': 1}
